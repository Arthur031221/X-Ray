# %% [markdown]
# ### Imort something

# %%
! pip install joblib==1.1.0
# Out:
# Collecting joblib==1.1.0
#   Using cached joblib-1.1.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Using cached joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.12.4 requires joblib>=1.1.1, but you have joblib 1.1.0 which is incompatible.
# scikit-learn 1.5.2 requires joblib>=1.2.0, but you have joblib 1.1.0 which is incompatible.
# Successfully installed joblib-1.1.0

# %%
#Check GPU version
! /usr/local/cuda/bin/nvcc --version
! nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# Sat Nov 30 16:28:38 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import urllib.request

# URLs for the zip files
links = [
  'https://nihcc.box.com/shared/static/vfk49d74nhbxq3nqjg0900w5nvkorp5c.gz',
  'https://nihcc.box.com/shared/static/i28rlmbvmfjbl8p2n3ril0pptcmcu9d1.gz',
  'https://nihcc.box.com/shared/static/f1t00wrtdk94satdfb9olcolqx20z2jp.gz',
	'https://nihcc.box.com/shared/static/0aowwzs5lhjrceb3qp67ahp0rd1l1etg.gz',
  'https://nihcc.box.com/shared/static/v5e3goj22zr6h8tzualxfsqlqaygfbsn.gz',
	'https://nihcc.box.com/shared/static/asi7ikud9jwnkrnkj99jnpfkjdes7l6l.gz',
	'https://nihcc.box.com/shared/static/jn1b4mw4n6lnh74ovmcjb8y48h8xj07n.gz',
  'https://nihcc.box.com/shared/static/tvpxmn7qyrgl0w8wfh9kqfjskv6nmm1j.gz',
	'https://nihcc.box.com/shared/static/upyy3ml7qdumlgk2rfcvlb9k6gvqq2pj.gz',
	'https://nihcc.box.com/shared/static/l6nilvfa9cg3s28tqv1qc1olm3gnz54p.gz',
	'https://nihcc.box.com/shared/static/hhq8fkdgvcari67vfhs7ppg2w6ni4jze.gz',
	'https://nihcc.box.com/shared/static/ioqwiy20ihqwyr8pf4c24eazhh281pbu.gz'
]

for idx, link in enumerate(links):
    fn = 'images_%02d.tar.gz' % (idx+1)
    print('downloading'+fn+'...')
    urllib.request.urlretrieve(link, fn)  # download the zip file
# Out:
# downloadingimages_01.tar.gz...
# downloadingimages_02.tar.gz...
# downloadingimages_03.tar.gz...
# downloadingimages_04.tar.gz...
# downloadingimages_05.tar.gz...
# downloadingimages_06.tar.gz...
# downloadingimages_07.tar.gz...
# downloadingimages_08.tar.gz...
# downloadingimages_09.tar.gz...
# downloadingimages_10.tar.gz...
# downloadingimages_11.tar.gz...
# downloadingimages_12.tar.gz...

# %%
#Make dictionary to save data
#! mkdir /content/drive/MyDrive/ML
#! mkdir /content/drive/MyDrive/ML/data
#! mkdir /content/drive/MyDrive/ML/history_model
#! mkdir /content/drive/MyDrive/ML/data/images
#! mkdir /content/drive/MyDrive/ML/history_model/run_dir

# %%
#Unzip file
! tar -xzvf images_01.tar.gz -C /content
! rm images_01.tar.gz
! tar -xzvf images_02.tar.gz -C /content
! rm images_02.tar.gz
! tar -xzvf images_03.tar.gz -C /content
! rm images_03.tar.gz
! tar -xzvf images_04.tar.gz -C /content
! rm images_04.tar.gz
! tar -xzvf images_05.tar.gz -C /content
! rm images_05.tar.gz
! tar -xzvf images_06.tar.gz -C /content
! rm images_06.tar.gz
! tar -xzvf images_07.tar.gz -C /content
! rm images_07.tar.gz
! tar -xzvf images_08.tar.gz -C /content
! rm images_08.tar.gz
! tar -xzvf images_09.tar.gz -C /content
! rm images_09.tar.gz
! tar -xzvf images_10.tar.gz -C /content
! rm images_10.tar.gz
! tar -xzvf images_11.tar.gz -C /content
! rm images_11.tar.gz
! tar -xzvf images_12.tar.gz -C /content
! rm images_12.tar.gz
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# images/00030152_007.png
# images/00029217_004.png
# images/00030742_000.png
# images/00030561_002.png
# images/00030313_000.png
# images/00029727_002.png
# images/00030077_004.png
# images/00028518_025.png
# images/00028715_002.png
# images/00030642_000.png
# images/00028253_006.png
# images/00028341_002.png
# images/00030158_002.png
# images/00029808_000.png
# images/00029470_012.png
# images/00028888_001.png
# images/00029041_012.png
# images/00029118_007.png
# images/00028422_000.png
# images/00030239_000.png
# images/00029708_000.png
# images/00029880_010.png
# images/00028523_031.png
# images/00028211_013.png
# images/00028751_000.png
# images/00028322_000.png
# images/00030568_000.png
# images/00030079_038.png
# images/00030139_000.png
# images/00028939_010.png
# images/00030059_005.png
# images/00028651_000.png
# images/00029234_000.png
# images/00029701_002.png
# images/00030468_000.png
# images/00030039_000.png
# images/00028980_000.png
# images/00029563_000.png
# images/00030797_000.png
# images/00029134_000.png
# images/00028652_003.png
# images/00029445_001.png
# images/00028552_003.png
# images/00029892_000.png
# images/00029464_003.png
# images/00029463_000.png
# images/00028285_015.png
# images/00029688_011.png
# images/00029135_003.png
# images/00028304_001.png
# images/00029189_000.png
# images/00029792_000.png
# images/00030753_001.png
# images/00029035_003.png
# images/00029105_014.png
# images/00028477_000.png
# images/00030606_002.png
# images/00029839_006.png
# images/00028377_000.png
# images/00030542_000.png
# images/00028876_011.png
# images/00028765_024.png
# images/00029389_000.png
# images/00028882_006.png
# images/00028523_017.png
# images/00028459_001.png
# images/00029763_014.png
# images/00029809_017.png
# images/00029950_007.png
# images/00029289_000.png
# images/00028963_004.png
# images/00029016_001.png
# images/00029813_020.png
# images/00028454_009.png
# images/00030213_000.png
# images/00029774_001.png
# images/00029259_011.png
# images/00030442_000.png
# images/00029502_005.png
# images/00029017_004.png
# images/00030113_000.png
# images/00030573_020.png
# images/00029159_011.png
# images/00028788_001.png
# images/00028864_007.png
# images/00028359_001.png
# images/00030408_008.png
# images/00029034_000.png
# images/00028725_000.png
# images/00029608_000.png
# images/00030079_066.png
# images/00029912_003.png
# images/00028222_000.png
# images/00030287_002.png
# images/00029937_000.png
# images/00029508_000.png
# images/00029676_007.png
# images/00028551_000.png
# images/00029837_000.png
# images/00030368_000.png
# images/00030697_000.png
# images/00028290_007.png
# images/00029328_005.png
# images/00029408_000.png
# images/00028880_000.png
# images/00028589_004.png
# images/00028451_000.png
# images/00030424_001.png
# images/00030268_000.png
# images/00029813_006.png
# images/00028780_000.png
# images/00029363_000.png
# images/00028899_002.png
# images/00030597_000.png
# images/00028317_008.png
# images/00029919_001.png
# images/00029692_000.png
# images/00030637_022.png
# images/00029263_000.png
# images/00028987_012.png
# images/00030573_006.png
# images/00028177_000.png
# images/00029819_001.png
# images/00029592_000.png
# images/00030679_001.png
# images/00029991_011.png
# images/00028433_001.png
# images/00028211_027.png
# images/00028277_000.png
# images/00030280_004.png
# images/00030342_000.png
# images/00028762_001.png
# images/00028808_004.png
# images/00029869_009.png
# images/00029631_005.png
# images/00030039_014.png
# images/00030499_006.png
# images/00029245_001.png
# images/00029401_002.png
# images/00029165_006.png
# images/00029089_000.png
# images/00028628_009.png
# images/00028582_006.png
# images/00029911_000.png
# images/00030013_000.png
# images/00028270_002.png
# images/00028876_025.png
# images/00028844_002.png
# images/00030771_000.png
# images/00030636_005.png
# images/00029208_000.png
# images/00029811_000.png
# images/00029105_028.png
# images/00029146_004.png
# images/00028925_000.png
# images/00030242_000.png
# images/00029943_023.png
# images/00030637_008.png
# images/00028483_009.png
# images/00030162_005.png
# images/00029966_000.png
# images/00028825_000.png
# images/00028974_005.png
# images/00029308_000.png
# images/00030561_016.png
# images/00028626_003.png
# images/00029985_002.png
# images/00029737_000.png
# images/00029861_008.png
# images/00028509_021.png
# images/00029259_025.png
# images/00029813_034.png
# images/00028351_000.png
# images/00030324_001.png
# images/00030168_000.png
# images/00029637_000.png
# images/00028580_000.png
# images/00029532_008.png
# images/00028680_000.png
# images/00030497_000.png
# images/00028251_000.png
# images/00030300_007.png
# images/00030068_000.png
# images/00029163_000.png
# images/00029159_025.png
# images/00028807_001.png
# images/00029052_013.png
# images/00030397_000.png
# images/00030038_011.png
# images/00029492_000.png
# images/00029063_000.png
# images/00029392_000.png
# images/00028844_030.png
# images/00029943_009.png
# images/00028481_003.png
# images/00029514_009.png
# images/00029358_008.png
# images/00030635_002.png
# images/00029948_001.png
# images/00030206_002.png
# images/00030571_000.png
# images/00029519_001.png
# images/00029393_003.png
# images/00030716_000.png
# images/00030535_002.png
# images/00030379_001.png
# images/00028526_003.png
# images/00029474_001.png
# images/00029201_002.png
# images/00030616_000.png
# images/00030536_005.png
# images/00028509_007.png
# images/00029711_000.png
# images/00028861_012.png
# images/00029374_001.png
# images/00030162_033.png
# images/00028644_002.png
# images/00028876_053.png
# images/00030142_000.png
# images/00029611_000.png
# images/00030471_000.png
# images/00028544_002.png
# images/00028433_015.png
# images/00029998_009.png
# images/00029008_000.png
# images/00030042_000.png
# images/00029866_000.png
# images/00029108_000.png
# images/00028873_002.png
# images/00028625_000.png
# images/00030260_013.png
# images/00030371_000.png
# images/00029437_000.png
# images/00028954_000.png
# images/00029537_000.png
# images/00028525_000.png
# images/00028874_005.png
# images/00029276_007.png
# images/00029685_002.png
# images/00028480_000.png
# images/00028924_011.png
# images/00028774_005.png
# images/00028844_016.png
# images/00029513_006.png
# images/00029357_005.png
# images/00030636_019.png
# images/00030297_000.png
# images/00029766_000.png
# images/00028380_000.png
# images/00029943_037.png
# images/00030197_000.png
# images/00030162_019.png
# images/00028876_039.png
# images/00028936_001.png
# images/00029292_000.png
# images/00028856_006.png
# images/00030323_012.png
# images/00030106_002.png
# images/00029192_000.png
# images/00030410_005.png
# images/00030279_001.png
# images/00030006_002.png
# images/00028974_019.png
# images/00028837_004.png
# images/00030516_000.png
# images/00028509_035.png
# images/00028325_000.png
# images/00029088_011.png
# images/00028918_002.png
# images/00029274_001.png
# images/00029207_011.png
# images/00030416_000.png
# images/00029649_004.png
# images/00029940_000.png
# images/00030745_000.png
# images/00029511_000.png
# images/00028818_002.png
# images/00029174_001.png
# images/00030701_001.png
# images/00028444_002.png
# images/00030190_002.png
# images/00029840_000.png
# images/00028407_001.png
# images/00029411_000.png
# images/00029995_000.png
# images/00029469_009.png
# images/00028591_001.png
# images/00030271_000.png
# images/00028357_023.png
# images/00029740_000.png
# images/00028754_000.png
# images/00028180_000.png
# images/00028854_000.png
# images/00029075_004.png
# images/00028425_000.png
# images/00030137_008.png
# images/00030171_000.png
# images/00028774_033.png
# images/00028307_001.png
# images/00029039_020.png
# images/00029337_000.png
# images/00029156_002.png
# images/00028911_004.png
# images/00028499_002.png
# images/00029822_001.png
# images/00030218_006.png
# images/00029666_000.png
# images/00029237_000.png
# images/00029566_000.png
# images/00030682_001.png
# images/00028280_000.png
# images/00030323_040.png
# images/00030253_001.png
# images/00030097_000.png
# images/00028897_010.png
# images/00028811_004.png
# images/00028544_016.png
# images/00028655_003.png
# images/00030582_001.png
# images/00030153_001.png
# images/00029895_000.png
# images/00028873_016.png
# images/00030709_002.png
# images/00029092_000.png
# images/00029866_014.png
# images/00029704_002.png
# images/00028208_004.png
# images/00029648_001.png
# images/00030720_003.png
# images/00029548_001.png
# images/00029977_001.png
# images/00030079_001.png
# images/00028308_004.png
# images/00030235_002.png
# images/00029796_003.png
# images/00029437_014.png
# images/00029074_001.png
# images/00028774_019.png
# images/00028526_017.png
# images/00029039_006.png
# images/00030316_000.png
# images/00029877_001.png
# images/00029705_005.png
# images/00030801_001.png
# images/00030645_000.png
# images/00028457_009.png
# images/00030216_000.png
# images/00029817_023.png
# images/00030111_008.png
# images/00028890_012.png
# images/00029311_000.png
# images/00030323_026.png
# images/00030545_000.png
# images/00030621_006.png
# images/00028357_009.png
# images/00029959_002.png
# images/00029640_000.png
# images/00029211_000.png
# images/00028392_004.png
# images/00028300_003.png
# images/00030071_000.png
# images/00029540_000.png
# images/00029460_005.png
# images/00028948_005.png
# images/00028654_000.png
# images/00029056_002.png
# images/00028225_000.png
# images/00028710_001.png
# images/00028554_000.png
# images/00028983_000.png
# images/00029385_002.png
# images/00029137_000.png
# images/00030527_001.png
# images/00029631_010.png
# images/00028883_000.png
# images/00029466_000.png
# images/00029088_025.png
# images/00029037_000.png
# images/00029795_000.png
# images/00030053_001.png
# images/00029522_001.png
# images/00029366_000.png
# images/00029448_001.png
# images/00028611_004.png
# images/00030609_002.png
# images/00028207_001.png
# images/00029695_000.png
# images/00029817_009.png
# images/00028940_004.png
# images/00028784_003.png
# images/00029075_018.png
# images/00029821_012.png
# images/00028774_047.png
# images/00029267_003.png
# images/00029423_004.png
# images/00028208_032.png
# images/00028357_037.png
# images/00028436_001.png
# images/00029579_007.png
# images/00029933_002.png
# images/00029596_003.png
# images/00029504_002.png
# images/00029672_009.png
# images/00030183_004.png
# images/00030520_003.png
# images/00029903_013.png
# images/00030116_000.png
# images/00030323_054.png
# images/00028499_016.png
# images/00029597_006.png
# images/00028766_004.png
# images/00028518_002.png
# images/00030445_000.png
# images/00029914_000.png
# images/00030016_000.png
# images/00030674_000.png
# images/00029111_000.png
# images/00030774_000.png
# images/00030501_001.png
# images/00030345_000.png
# images/00028292_004.png
# images/00029915_003.png
# images/00029440_000.png
# images/00028928_000.png
# images/00029548_015.png
# images/00029011_000.png
# images/00028996_007.png
# images/00030159_010.png
# images/00030346_003.png
# images/00030079_015.png
# images/00028828_000.png
# images/00029340_000.png
# images/00028208_018.png
# images/00028454_000.png
# images/00030427_001.png
# images/00028783_000.png
# images/00028683_000.png
# images/00029479_007.png
# images/00028829_003.png
# images/00028354_000.png
# images/00030393_002.png
# images/00030247_006.png
# images/00029266_000.png
# images/00029670_003.png
# images/00029422_001.png
# images/00028572_013.png
# images/00030656_001.png
# images/00030389_013.png
# images/00028330_006.png
# images/00029595_000.png
# images/00029570_003.png
# images/00029322_001.png
# images/00029166_000.png
# images/00028684_003.png
# images/00028549_008.png
# images/00028958_003.png
# images/00029495_000.png
# images/00029617_009.png
# images/00028765_001.png
# images/00029142_006.png
# images/00028903_003.png
# images/00029669_000.png
# images/00028628_014.png
# images/00029404_002.png
# images/00028505_009.png
# images/00028665_001.png
# images/00028191_001.png
# images/00030209_002.png
# images/00029981_004.png
# images/00028518_030.png
# images/00028902_000.png
# images/00030719_000.png
# images/00028822_005.png
# images/00028666_004.png
# images/00028485_006.png
# images/00030320_003.png
# images/00029814_000.png
# images/00029048_001.png
# images/00029477_001.png
# images/00028995_004.png
# images/00028611_018.png
# images/00030609_016.png
# images/00030245_000.png
# images/00029714_000.png
# images/00030064_002.png
# images/00030145_000.png
# images/00029478_004.png
# images/00028803_003.png
# images/00030079_043.png
# images/00030574_000.png
# images/00030650_006.png
# images/00030059_010.png
# images/00028931_000.png
# images/00029715_003.png
# images/00028728_000.png
# images/00029240_000.png
# images/00029459_002.png
# images/00030474_000.png
# images/00028219_005.png
# images/00029863_005.png
# images/00030146_003.png
# images/00029596_017.png
# images/00029140_000.png
# images/00028628_000.png
# images/00028173_016.png
# images/00028254_000.png
# images/00029969_000.png
# images/00030046_003.png
# images/00028518_016.png
# images/00028583_000.png
# images/00029279_007.png
# images/00030375_003.png
# images/00029066_000.png
# images/00029869_000.png
# images/00028831_000.png
# images/00029041_003.png
# images/00029470_003.png
# images/00029222_001.png
# images/00028483_000.png
# images/00029377_001.png
# images/00029395_000.png
# images/00029551_001.png
# images/00028523_022.png
# images/00028640_004.png
# images/00030079_029.png
# images/00029950_012.png
# images/00028211_004.png
# images/00029880_001.png
# images/00029451_001.png
# images/00028939_001.png
# images/00029295_000.png
# images/00030786_004.png
# images/00028454_014.png
# images/00030408_013.png
# images/00029881_004.png
# images/00029900_004.png
# images/00028802_000.png
# images/00028465_001.png
# images/00030619_000.png
# images/00029105_005.png
# images/00028365_001.png
# images/00029040_000.png
# images/00030079_071.png
# images/00028702_000.png
# images/00029196_003.png
# images/00030519_000.png
# images/00028285_006.png
# images/00030439_005.png
# images/00029843_000.png
# images/00029614_000.png
# images/00029433_002.png
# images/00029277_001.png
# images/00028795_004.png
# images/00029762_002.png
# images/00029943_000.png
# images/00030339_005.png
# images/00030045_000.png
# images/00029514_000.png
# images/00028876_002.png
# images/00028765_015.png
# images/00029278_004.png
# images/00030374_000.png
# images/00028523_008.png
# images/00030101_001.png
# images/00029763_005.png
# images/00029809_008.png
# images/00028957_000.png
# images/00029688_002.png
# images/00028528_000.png
# images/00029813_011.png
# images/00030274_000.png
# images/00028857_000.png
# images/00029844_003.png
# images/00029663_005.png
# images/00029259_002.png
# images/00028317_013.png
# images/00028428_000.png
# images/00030573_011.png
# images/00028677_005.png
# images/00029769_000.png
# images/00029744_003.png
# images/00029588_002.png
# images/00028757_000.png
# images/00029159_002.png
# images/00028429_003.png
# images/00028383_000.png
# images/00030685_001.png
# images/00029825_001.png
# images/00029532_013.png
# images/00029589_005.png
# images/00028211_032.png
# images/00028939_015.png
# images/00028283_000.png
# images/00030412_002.png
# images/00029998_000.png
# images/00030637_013.png
# images/00028265_001.png
# images/00029863_019.png
# images/00029351_001.png
# images/00029195_000.png
# images/00028253_011.png
# images/00029414_000.png
# images/00029041_017.png
# images/00028739_001.png
# images/00029680_001.png
# images/00028582_011.png
# images/00029165_011.png
# images/00029095_000.png
# images/00028502_000.png
# images/00030561_007.png
# images/00030338_002.png
# images/00029807_002.png
# images/00030077_009.png
# images/00030636_010.png
# images/00028602_000.png
# images/00028421_002.png
# images/00030419_000.png
# images/00028341_007.png
# images/00028750_002.png
# images/00029808_005.png
# images/00029470_017.png
# images/00030748_000.png
# images/00029177_001.png
# images/00030319_000.png
# images/00030162_010.png
# images/00028876_030.png
# images/00030606_007.png
# images/00029481_004.png
# images/00030561_021.png
# images/00030648_000.png
# images/00028211_018.png
# images/00030219_000.png
# images/00029991_002.png
# images/00029743_000.png
# images/00030174_000.png
# images/00029314_000.png
# images/00029259_030.png
# images/00028974_010.png
# images/00028247_002.png
# images/00029643_000.png
# images/00030039_005.png
# images/00028913_001.png
# images/00029861_013.png
# images/00028328_000.png
# images/00030300_012.png
# images/00029972_000.png
# images/00030074_000.png
# images/00029898_000.png
# images/00028657_000.png
# images/00029943_014.png
# images/00028228_000.png
# images/00028304_006.png
# images/00029358_013.png
# images/00028986_000.png
# images/00029569_000.png
# images/00028557_000.png
# images/00029464_008.png
# images/00029105_019.png
# images/00029035_008.png
# images/00028183_000.png
# images/00028876_016.png
# images/00029469_000.png
# images/00028765_029.png
# images/00028987_003.png
# images/00030212_002.png
# images/00029798_000.png
# images/00030541_002.png
# images/00028639_001.png
# images/00030722_000.png
# images/00028458_003.png
# images/00029813_025.png
# images/00029774_006.png
# images/00029526_004.png
# images/00029259_016.png
# images/00030622_000.png
# images/00029159_016.png
# images/00029380_001.png
# images/00028509_012.png
# images/00028402_000.png
# images/00029052_004.png
# images/00030448_000.png
# images/00030286_004.png
# images/00030038_002.png
# images/00028550_002.png
# images/00028433_020.png
# images/00028731_000.png
# images/00028302_000.png
# images/00030548_000.png
# images/00030119_000.png
# images/00029891_002.png
# images/00030604_001.png
# images/00029214_000.png
# images/00028631_000.png
# images/00029362_002.png
# images/00029114_000.png
# images/00028874_010.png
# images/00030019_000.png
# images/00028960_000.png
# images/00029543_000.png
# images/00029276_012.png
# images/00030777_000.png
# images/00028961_003.png
# images/00028844_021.png
# images/00029918_003.png
# images/00029872_000.png
# images/00028774_010.png
# images/00029443_000.png
# images/00030636_024.png
# images/00030753_006.png
# images/00028376_002.png
# images/00029772_000.png
# images/00030030_001.png
# images/00029919_006.png
# images/00028886_000.png
# images/00028861_003.png
# images/00028457_000.png
# images/00028276_002.png
# images/00030162_024.png
# images/00028876_044.png
# images/00028786_000.png
# images/00029369_000.png
# images/00028357_000.png
# images/00028433_006.png
# images/00029698_000.png
# images/00029425_001.png
# images/00029269_000.png
# images/00030039_019.png
# images/00030260_004.png
# images/00028974_024.png
# images/00029598_000.png
# images/00029146_000.png
# images/00029169_000.png
# images/00030770_002.png
# images/00030522_000.png
# images/00028258_003.png
# images/00028509_040.png
# images/00029326_004.png
# images/00029755_004.png
# images/00028924_002.png
# images/00029280_001.png
# images/00028844_007.png
# images/00030422_000.png
# images/00030652_003.png
# images/00030167_002.png
# images/00029984_004.png
# images/00029180_001.png
# images/00028202_000.png
# images/00030267_002.png
# images/00028431_000.png
# images/00029943_028.png
# images/00029917_000.png
# images/00029469_014.png
# images/00028987_017.png
# images/00030348_000.png
# images/00028531_000.png
# images/00028350_002.png
# images/00030323_003.png
# images/00029817_000.png
# images/00029014_000.png
# images/00028860_000.png
# images/00030677_000.png
# images/00030496_002.png
# images/00029813_039.png
# images/00030248_000.png
# images/00029343_000.png
# images/00028760_000.png
# images/00030733_001.png
# images/00030577_000.png
# images/00030497_005.png
# images/00030249_003.png
# images/00029672_000.png
# images/00029243_000.png
# images/00028509_026.png
# images/00028513_001.png
# images/00030305_004.png
# images/00029572_000.png
# images/00028686_000.png
# images/00029088_002.png
# images/00029244_003.png
# images/00028661_003.png
# images/00030659_001.png
# images/00028257_000.png
# images/00029300_004.png
# images/00028586_000.png
# images/00030635_007.png
# images/00029810_002.png
# images/00030206_007.png
# images/00029654_001.png
# images/00029498_000.png
# images/00028486_000.png
# images/00029069_000.png
# images/00030751_000.png
# images/00028357_014.png
# images/00029039_011.png
# images/00028774_024.png
# images/00029398_000.png
# images/00029474_006.png
# images/00029201_007.png
# images/00030570_002.png
# images/00030322_000.png
# images/00029883_001.png
# images/00030222_000.png
# images/00028905_000.png
# images/00028876_058.png
# images/00030651_000.png
# images/00028644_007.png
# images/00030111_013.png
# images/00028805_000.png
# images/00029207_002.png
# images/00028897_001.png
# images/00030323_031.png
# images/00030551_000.png
# images/00028725_005.png
# images/00028544_007.png
# images/00030471_005.png
# images/00029717_000.png
# images/00029866_005.png
# images/00028705_000.png
# images/00028873_007.png
# images/00028331_000.png
# images/00029865_002.png
# images/00030148_000.png
# images/00029617_000.png
# images/00028606_003.png
# images/00028231_000.png
# images/00028660_000.png
# images/00029108_005.png
# images/00030477_000.png
# images/00029946_000.png
# images/00030048_000.png
# images/00028560_000.png
# images/00029437_005.png
# images/00029143_000.png
# images/00030377_000.png
# images/00028526_008.png
# images/00029417_000.png
# images/00029472_000.png
# images/00029043_000.png
# images/00028357_028.png
# images/00028380_005.png
# images/00029666_005.png
# images/00030459_001.png
# images/00029200_004.png
# images/00029372_000.png
# images/00028890_003.png
# images/00028642_001.png
# images/00030615_002.png
# images/00030323_017.png
# images/00029817_014.png
# images/00030106_007.png
# images/00028971_001.png
# images/00029373_003.png
# images/00029125_001.png
# images/00028386_000.png
# images/00029025_001.png
# images/00030279_006.png
# images/00030122_000.png
# images/00029610_002.png
# images/00028871_001.png
# images/00029298_000.png
# images/00030688_001.png
# images/00028286_000.png
# images/00029274_006.png
# images/00029672_014.png
# images/00029783_001.png
# images/00029075_009.png
# images/00029198_000.png
# images/00028918_007.png
# images/00028624_002.png
# images/00030689_004.png
# images/00030370_002.png
# images/00029683_001.png
# images/00029940_005.png
# images/00030023_003.png
# images/00028368_001.png
# images/00029920_000.png
# images/00029088_016.png
# images/00030451_000.png
# images/00028187_003.png
# images/00030022_000.png
# images/00028605_000.png
# images/00030780_000.png
# images/00029007_002.png
# images/00030351_000.png
# images/00029336_002.png
# images/00029517_000.png
# images/00028934_000.png
# images/00028774_038.png
# images/00028505_000.png
# images/00030196_002.png
# images/00030079_020.png
# images/00029846_000.png
# images/00029821_003.png
# images/00029579_012.png
# images/00029746_000.png
# images/00028498_004.png
# images/00028208_023.png
# images/00028460_000.png
# images/00030277_000.png
# images/00029902_001.png
# images/00028916_001.png
# images/00029822_006.png
# images/00028330_011.png
# images/00028679_002.png
# images/00028360_000.png
# images/00030247_011.png
# images/00030177_000.png
# images/00029903_004.png
# images/00028897_015.png
# images/00030323_045.png
# images/00029272_000.png
# images/00028579_002.png
# images/00028499_007.png
# images/00028180_005.png
# images/00030178_003.png
# images/00028516_001.png
# images/00029172_000.png
# images/00029976_003.png
# images/00028989_000.png
# images/00029142_011.png
# images/00028591_006.png
# images/00029464_013.png
# images/00028186_000.png
# images/00030159_001.png
# images/00029866_019.png
# images/00030079_006.png
# images/00029548_006.png
# images/00029098_000.png
# images/00028509_003.png
# images/00030488_001.png
# images/00028208_009.png
# images/00029310_002.png
# images/00030725_000.png
# images/00029820_000.png
# images/00028611_023.png
# images/00029483_001.png
# images/00030609_021.png
# images/00030680_000.png
# images/00028572_004.png
# images/00030389_004.png
# images/00030251_000.png
# images/00029720_000.png
# images/00028902_005.png
# images/00028834_000.png
# images/00028405_000.png
# images/00030580_000.png
# images/00030152_003.png
# images/00030151_000.png
# images/00029317_000.png
# images/00028734_000.png
# images/00028305_000.png
# images/00028397_001.png
# images/00029863_010.png
# images/00029596_022.png
# images/00029802_001.png
# images/00029646_000.png
# images/00029465_002.png
# images/00029217_000.png
# images/00030233_001.png
# images/00029117_000.png
# images/00028260_000.png
# images/00029975_000.png
# images/00030077_000.png
# images/00029546_000.png
# images/00028518_021.png
# images/00030381_003.png
# images/00028479_002.png
# images/00030608_004.png
# images/00029072_000.png
# images/00029875_000.png
# images/00029703_004.png
# images/00029795_005.png
# images/00029165_002.png
# images/00028535_003.png
# images/00029118_003.png
# images/00028611_009.png
# images/00030609_007.png
# images/00029876_003.png
# images/00029628_001.png
# images/00028889_000.png
# images/00030079_034.png
# images/00028242_001.png
# images/00029821_017.png
# images/00030059_001.png
# images/00029528_001.png
# images/00028789_000.png
# images/00028208_037.png
# images/00030388_001.png
# images/00029221_003.png
# images/00029596_008.png
# images/00029054_001.png
# images/00030625_000.png
# images/00029422_006.png
# images/00028634_000.png
# images/00029903_018.png
# images/00030380_000.png
# images/00028765_020.png
# images/00030525_000.png
# images/00028285_011.png
# images/00028518_007.png
# images/00029520_000.png
# images/00029105_010.png
# images/00029620_000.png
# images/00028927_002.png
# images/00029283_001.png
# images/00028205_000.png
# images/00029446_000.png
# images/00030480_000.png
# images/00029839_002.png
# images/00030051_000.png
# images/00030159_015.png
# images/00030607_001.png
# images/00028882_002.png
# images/00028523_013.png
# images/00028453_002.png
# images/00029809_013.png
# images/00029763_010.png
# images/00029950_003.png
# images/00029663_010.png
# images/00028963_000.png
# images/00028534_000.png
# images/00028454_005.png
# images/00028197_001.png
# images/00029339_002.png
# images/00029346_000.png
# images/00029602_001.png
# images/00028863_000.png
# images/00029503_004.png
# images/00029017_000.png
# images/00029831_001.png
# images/00030146_008.png
# images/00029775_000.png
# images/00029502_001.png
# images/00029594_002.png
# images/00029670_008.png
# images/00028864_003.png
# images/00030791_001.png
# images/00028416_001.png
# images/00030408_004.png
# images/00029570_008.png
# images/00029675_000.png
# images/00030079_062.png
# images/00028920_004.png
# images/00028764_003.png
# images/00028628_005.png
# images/00028689_000.png
# images/00030262_001.png
# images/00030425_000.png
# images/00029676_003.png
# images/00029428_001.png
# images/00029247_003.png
# images/00028765_006.png
# images/00029863_024.png
# images/00028290_003.png
# images/00029669_005.png
# images/00028846_004.png
# images/00029328_001.png
# images/00028589_000.png
# images/00029404_007.png
# images/00030209_007.png
# images/00030344_002.png
# images/00030188_001.png
# images/00029813_002.png
# images/00029981_009.png
# images/00029228_001.png
# images/00028271_001.png
# images/00030325_000.png
# images/00028341_012.png
# images/00028317_004.png
# images/00029808_010.png
# images/00029420_000.png
# images/00030654_000.png
# images/00028876_021.png
# images/00030754_000.png
# images/00030573_002.png
# images/00028434_000.png
# images/00030606_012.png
# images/00029739_002.png
# images/00028211_023.png
# images/00028908_000.png
# images/00028727_002.png
# images/00029129_004.png
# images/00030079_048.png
# images/00030280_000.png
# images/00028939_020.png
# images/00028583_005.png
# images/00028808_000.png
# images/00029320_000.png
# images/00030499_002.png
# images/00028682_002.png
# images/00028253_002.png
# images/00030039_010.png
# images/00030180_000.png
# images/00028173_007.png
# images/00029246_000.png
# images/00028992_000.png
# images/00028763_000.png
# images/00028582_002.png
# images/00028334_000.png
# images/00030307_001.png
# images/00030080_000.png
# images/00030046_008.png
# images/00029650_003.png
# images/00029402_001.png
# images/00028663_000.png
# images/00030636_001.png
# images/00028234_000.png
# images/00028664_003.png
# images/00029041_008.png
# images/00029869_005.png
# images/00029575_000.png
# images/00029105_024.png
# images/00029470_008.png
# images/00030637_004.png
# images/00028483_005.png
# images/00030162_001.png
# images/00029631_001.png
# images/00029475_000.png
# images/00029688_007.png
# images/00028523_027.png
# images/00030561_012.png
# images/00028640_009.png
# images/00028211_009.png
# images/00029950_017.png
# images/00029880_006.png
# images/00029476_003.png
# images/00028939_006.png
# images/00029813_030.png
# images/00028489_000.png
# images/00028216_001.png
# images/00028974_001.png
# images/00029259_021.png
# images/00029713_002.png
# images/00029532_004.png
# images/00028876_035.png
# images/00028389_000.png
# images/00030300_003.png
# images/00029886_001.png
# images/00029861_004.png
# images/00029159_021.png
# images/00029843_005.png
# images/00029358_004.png
# images/00030408_018.png
# images/00030519_005.png
# images/00030225_000.png
# images/00030573_016.png
# images/00028708_000.png
# images/00029433_007.png
# images/00028795_009.png
# images/00030554_000.png
# images/00029450_003.png
# images/00030125_000.png
# images/00029943_005.png
# images/00030783_000.png
# images/00029514_005.png
# images/00029220_000.png
# images/00028876_007.png
# images/00030454_000.png
# images/00028463_000.png
# images/00030101_006.png
# images/00028608_000.png
# images/00029120_000.png
# images/00030753_011.png
# images/00030026_003.png
# images/00029813_016.png
# images/00029949_000.png
# images/00029768_002.png
# images/00028937_000.png
# images/00029159_007.png
# images/00029259_007.png
# images/00028563_000.png
# images/00030536_001.png
# images/00030107_001.png
# images/00029849_000.png
# images/00029744_008.png
# images/00028892_000.png
# images/00029202_001.png
# images/00029046_000.png
# images/00029531_001.png
# images/00028433_011.png
# images/00028792_000.png
# images/00029375_000.png
# images/00029102_001.png
# images/00029998_005.png
# images/00029431_001.png
# images/00029275_000.png
# images/00030000_003.png
# images/00028545_001.png
# images/00028911_000.png
# images/00028844_012.png
# images/00028628_019.png
# images/00028874_001.png
# images/00029276_003.png
# images/00028601_002.png
# images/00028289_000.png
# images/00030191_001.png
# images/00029357_001.png
# images/00029807_007.png
# images/00029513_002.png
# images/00028774_001.png
# images/00030636_015.png
# images/00028189_000.png
# images/00030419_005.png
# images/00028265_006.png
# images/00030025_000.png
# images/00029943_033.png
# images/00030637_018.png
# images/00030162_015.png
# images/00029923_000.png
# images/00029742_002.png
# images/00029586_001.png
# images/00028856_002.png
# images/00029481_009.png
# images/00030254_000.png
# images/00030354_000.png
# images/00029823_000.png
# images/00029991_007.png
# images/00029020_000.png
# images/00028912_003.png
# images/00028508_000.png
# images/00030683_000.png
# images/00030410_001.png
# images/00029058_004.png
# images/00028380_010.png
# images/00029532_018.png
# images/00028974_015.png
# images/00028837_000.png
# images/00028408_000.png
# images/00030583_000.png
# images/00029175_000.png
# images/00028509_031.png
# images/00029749_000.png
# images/00028737_000.png
# images/00029897_002.png
# images/00028363_000.png
# images/00030336_001.png
# images/00029805_001.png
# images/00029649_000.png
# images/00028987_008.png
# images/00028692_000.png
# images/00028263_000.png
# images/00030484_003.png
# images/00029978_000.png
# images/00029943_019.png
# images/00028592_000.png
# images/00028819_001.png
# images/00029469_005.png
# images/00029150_003.png
# images/00029878_000.png
# images/00030206_012.png
# images/00030802_000.png
# images/00029075_000.png
# images/00028593_003.png
# images/00030137_004.png
# images/00028509_017.png
# images/00029526_009.png
# images/00028674_001.png
# images/00028550_007.png
# images/00030218_002.png
# images/00028876_063.png
# images/00030628_000.png
# images/00029313_002.png
# images/00030728_000.png
# images/00030547_002.png
# images/00029052_009.png
# images/00028811_000.png
# images/00030038_007.png
# images/00028544_012.png
# images/00029213_002.png
# images/00028731_005.png
# images/00028774_015.png
# images/00029039_002.png
# images/00029723_000.png
# images/00028873_012.png
# images/00029778_000.png
# images/00030154_000.png
# images/00030310_001.png
# images/00030640_004.png
# images/00028844_026.png
# images/00029623_000.png
# images/00028961_008.png
# images/00029387_004.png
# images/00029866_010.png
# images/00030483_000.png
# images/00028308_000.png
# images/00029952_000.png
# images/00030054_000.png
# images/00029437_010.png
# images/00028885_002.png
# images/00028637_000.png
# images/00028526_013.png
# images/00028208_000.png
# images/00030383_000.png
# images/00028966_000.png
# images/00030030_006.png
# images/00029705_001.png
# images/00029549_000.png
# images/00028537_000.png
# images/00028861_008.png
# images/00028876_049.png
# images/00028457_005.png
# images/00030162_029.png
# images/00030111_004.png
# images/00029449_000.png
# images/00030323_022.png
# images/00030621_002.png
# images/00028492_000.png
# images/00028357_005.png
# images/00028392_000.png
# images/00030036_001.png
# images/00029349_000.png
# images/00030702_000.png
# images/00028619_001.png
# images/00030279_011.png
# images/00030365_001.png
# images/00030260_009.png
# images/00029460_001.png
# images/00028948_001.png
# images/00030602_000.png
# images/00029244_008.png
# images/00028301_002.png
# images/00028258_008.png
# images/00029755_009.png
# images/00028924_007.png
# images/00030695_004.png
# images/00029916_002.png
# images/00029088_021.png
# images/00028711_000.png
# images/00028374_001.png
# images/00030528_000.png
# images/00029817_005.png
# images/00029984_009.png
# images/00028611_000.png
# images/00030323_050.png
# images/00030428_000.png
# images/00030733_006.png
# images/00029523_000.png
# images/00030323_008.png
# images/00029771_002.png
# images/00028940_000.png
# images/00030757_000.png
# images/00029075_014.png
# images/00029852_000.png
# images/00028774_043.png
# images/00028208_014.png
# images/00029822_011.png
# images/00029423_000.png
# images/00028785_002.png
# images/00028512_003.png
# images/00030283_000.png
# images/00029666_010.png
# images/00029752_000.png
# images/00028766_000.png
# images/00029672_005.png
# images/00028866_000.png
# images/00030183_000.png
# images/00028437_000.png
# images/00028256_002.png
# images/00029597_002.png
# images/00028897_020.png
# images/00029572_005.png
# images/00028357_033.png
# images/00028499_012.png
# images/00028337_000.png
# images/00028661_008.png
# images/00029088_007.png
# images/00030184_003.png
# images/00029678_000.png
# images/00029405_001.png
# images/00029249_000.png
# images/00028292_000.png
# images/00029578_000.png
# images/00029149_000.png
# images/00028996_003.png
# images/00030502_000.png
# images/00028192_000.png
# images/00030079_011.png
# images/00029548_011.png
# images/00028774_029.png
# images/00029579_003.png
# images/00029039_016.png
# images/00030402_000.png
# images/00028357_019.png
# images/00029883_006.png
# images/00029479_003.png
# images/00030731_000.png
# images/00030651_005.png
# images/00030247_002.png
# images/00028897_006.png
# images/00030323_036.png
# images/00028511_000.png
# images/00029207_007.png
# images/00028330_002.png
# images/00030328_000.png
# images/00029889_001.png
# images/00028549_004.png
# images/00028840_000.png
# images/00030657_000.png
# images/00028411_000.png
# images/00030228_000.png
# images/00029323_000.png
# images/00029617_005.png
# images/00028740_000.png
# images/00029142_002.png
# images/00030557_000.png
# images/00029652_000.png
# images/00030129_003.png
# images/00029223_000.png
# images/00030083_000.png
# images/00029981_000.png
# images/00029552_000.png
# images/00028666_000.png
# images/00028566_000.png
# images/00028822_001.png
# images/00030639_001.png
# images/00028485_002.png
# images/00028237_000.png
# images/00029881_000.png
# images/00028611_014.png
# images/00028890_008.png
# images/00028995_000.png
# images/00028722_001.png
# images/00030609_012.png
# images/00029049_000.png
# images/00030394_001.png
# images/00029817_019.png
# images/00029478_000.png
# images/00028895_000.png
# images/00029297_002.png
# images/00028466_000.png
# images/00030650_002.png
# images/00028386_005.png
# images/00030065_001.png
# images/00029378_000.png
# images/00030302_000.png
# images/00029025_006.png
# images/00030550_002.png
# images/00028219_001.png
# images/00029863_001.png
# images/00029596_013.png
# images/00028977_001.png
# images/00030631_000.png
# images/00028548_001.png
# images/00029903_023.png
# images/00030202_000.png
# images/00028628_010.png
# images/00030531_000.png
# images/00029279_003.png
# images/00028518_012.png
# images/00028448_001.png
# images/00029745_002.png
# images/00028505_005.png
# images/00028540_000.png
# images/00028311_000.png
# images/00030128_000.png
# images/00029845_002.png
# images/00030079_025.png
# images/00029123_000.png
# images/00028640_000.png
# images/00028211_000.png
# images/00030457_000.png
# images/00029926_000.png
# images/00030028_000.png
# images/00029821_008.png
# images/00030786_000.png
# images/00028454_010.png
# images/00028208_028.png
# images/00030357_000.png
# images/00028266_000.png
# images/00029452_000.png
# images/00030686_000.png
# images/00029023_000.png
# images/00029781_000.png
# images/00030358_003.png
# images/00029827_003.png
# images/00029670_013.png
# images/00029903_009.png
# images/00029352_000.png
# images/00029809_004.png
# images/00030439_001.png
# images/00028285_002.png
# images/00028366_000.png
# images/00029681_000.png
# images/00030178_008.png
# images/00029097_002.png
# images/00028795_000.png
# images/00029105_001.png
# images/00029278_000.png
# images/00030339_001.png
# images/00029909_004.png
# images/00029976_008.png
# images/00028765_011.png
# images/00028851_001.png
# images/00028695_000.png
# images/00028523_004.png
# images/00029763_001.png
# images/00030450_002.png
# images/00028186_005.png
# images/00030159_006.png
# images/00029581_000.png
# images/00029334_001.png
# images/00029178_000.png
# images/00029165_007.png
# images/00030209_012.png
# images/00030350_002.png
# images/00030102_000.png
# images/00029663_001.png
# images/00029235_004.png
# images/00028777_001.png
# images/00030431_000.png
# images/00028348_001.png
# images/00029900_000.png
# images/00030002_000.png
# images/00030609_026.png
# images/00028677_001.png
# images/00030760_000.png
# images/00028572_009.png
# images/00030331_000.png
# images/00029901_003.png
# images/00030389_009.png
# images/00028914_000.png
# images/00029589_001.png
# images/00030079_053.png
# images/00029801_003.png
# images/00030805_000.png
# images/00029826_000.png
# images/00030151_005.png
# images/00029863_015.png
# images/00028173_012.png
# images/00028715_003.png
# images/00028440_000.png
# images/00030413_001.png
# images/00030257_000.png
# images/00029726_000.png
# images/00030152_008.png
# images/00028340_000.png
# images/00029217_005.png
# images/00030586_000.png
# images/00030561_003.png
# images/00030157_000.png
# images/00030077_005.png
# images/00029727_003.png
# images/00028518_026.png
# images/00029252_000.png
# images/00030486_000.png
# images/00029869_010.png
# images/00028341_003.png
# images/00030158_003.png
# images/00029808_001.png
# images/00029470_013.png
# images/00029152_000.png
# images/00029041_013.png
# images/00028876_012.png
# images/00029118_008.png
# images/00029481_000.png
# images/00028523_032.png
# images/00028969_000.png
# images/00029880_011.png
# images/00028595_000.png
# images/00028211_014.png
# images/00030079_039.png
# images/00030139_001.png
# images/00028939_011.png
# images/00030059_006.png
# images/00028414_000.png
# images/00029078_000.png
# images/00028495_000.png
# images/00029464_004.png
# images/00028304_002.png
# images/00030039_001.png
# images/00029563_001.png
# images/00028980_001.png
# images/00030705_000.png
# images/00029134_001.png
# images/00028652_004.png
# images/00029259_012.png
# images/00030660_000.png
# images/00029800_000.png
# images/00030231_000.png
# images/00029463_001.png
# images/00030606_003.png
# images/00028552_004.png
# images/00029135_004.png
# images/00028285_016.png
# images/00029035_004.png
# images/00029700_000.png
# images/00029389_001.png
# images/00029955_000.png
# images/00028814_000.png
# images/00029105_015.png
# images/00030560_000.png
# images/00029943_010.png
# images/00030131_000.png
# images/00029514_010.png
# images/00029839_007.png
# images/00028765_025.png
# images/00028714_000.png
# images/00028523_018.png
# images/00029809_018.png
# images/00029950_008.png
# images/00029626_000.png
# images/00029289_001.png
# images/00029016_002.png
# images/00029813_021.png
# images/00028240_000.png
# images/00029774_002.png
# images/00030057_000.png
# images/00029526_000.png
# images/00029052_000.png
# images/00029189_001.png
# images/00028614_000.png
# images/00029017_005.png
# images/00030386_000.png
# images/00029855_000.png
# images/00029381_000.png
# images/00029159_012.png
# images/00029502_006.png
# images/00028788_002.png
# images/00028864_008.png
# images/00028359_002.png
# images/00030286_000.png
# images/00030408_009.png
# images/00028869_000.png
# images/00030079_067.png
# images/00029813_007.png
# images/00028769_000.png
# images/00029998_010.png
# images/00029912_004.png
# images/00029281_000.png
# images/00029676_008.png
# images/00028395_000.png
# images/00028808_005.png
# images/00028290_008.png
# images/00029408_001.png
# images/00028880_001.png
# images/00029328_006.png
# images/00030605_000.png
# images/00028295_000.png
# images/00030268_001.png
# images/00028211_028.png
# images/00030637_023.png
# images/00030636_020.png
# images/00029600_000.png
# images/00030753_002.png
# images/00030505_000.png
# images/00028195_000.png
# images/00028317_009.png
# images/00029919_002.png
# images/00029692_001.png
# images/00030499_007.png
# images/00030460_000.png
# images/00030162_020.png
# images/00028876_040.png
# images/00030573_007.png
# images/00029819_002.png
# images/00030031_000.png
# images/00029500_000.png
# images/00028433_002.png
# images/00029991_012.png
# images/00030679_002.png
# images/00030039_015.png
# images/00030360_000.png
# images/00030280_005.png
# images/00029532_023.png
# images/00028943_000.png
# images/00028762_002.png
# images/00028514_000.png
# images/00030260_000.png
# images/00028253_007.png
# images/00028974_020.png
# images/00028844_031.png
# images/00028843_000.png
# images/00029426_000.png
# images/00029245_002.png
# images/00028582_007.png
# images/00028588_002.png
# images/00029984_000.png
# images/00029755_000.png
# images/00029105_029.png
# images/00029326_000.png
# images/00028844_003.png
# images/00030637_009.png
# images/00030636_006.png
# images/00030342_001.png
# images/00030186_000.png
# images/00029655_000.png
# images/00029146_005.png
# images/00029943_024.png
# images/00028876_026.png
# images/00028825_001.png
# images/00030162_006.png
# images/00029631_006.png
# images/00030086_000.png
# images/00029469_010.png
# images/00028987_013.png
# images/00029181_000.png
# images/00028669_000.png
# images/00030561_017.png
# images/00029052_014.png
# images/00029985_003.png
# images/00028569_000.png
# images/00028998_000.png
# images/00029308_001.png
# images/00029081_000.png
# images/00029813_035.png
# images/00030300_008.png
# images/00028974_006.png
# images/00029259_026.png
# images/00029532_009.png
# images/00030497_001.png
# images/00030405_000.png
# images/00028509_022.png
# images/00030068_001.png
# images/00029861_009.png
# images/00029159_026.png
# images/00028626_004.png
# images/00030734_000.png
# images/00030305_000.png
# images/00030038_012.png
# images/00029400_000.png
# images/00030634_000.png
# images/00029555_000.png
# images/00029226_000.png
# images/00029817_010.png
# images/00028644_003.png
# images/00030160_000.png
# images/00029300_000.png
# images/00028314_000.png
# images/00029358_009.png
# images/00030635_003.png
# images/00029948_002.png
# images/00030206_003.png
# images/00030571_001.png
# images/00029519_002.png
# images/00028861_013.png
# images/00028743_000.png
# images/00030535_003.png
# images/00030162_034.png
# images/00030379_002.png
# images/00030060_000.png
# images/00028774_020.png
# images/00029474_002.png
# images/00028643_000.png
# images/00029201_003.png
# images/00028214_000.png
# images/00030536_006.png
# images/00029711_001.png
# images/00028457_010.png
# images/00028972_000.png
# images/00029126_000.png
# images/00030789_000.png
# images/00028509_008.png
# images/00028876_054.png
# images/00028433_016.png
# images/00029884_000.png
# images/00028480_001.png
# images/00029455_000.png
# images/00028357_010.png
# images/00028725_001.png
# images/00028544_003.png
# images/00030471_001.png
# images/00029784_000.png
# images/00028898_000.png
# images/00028873_003.png
# images/00028469_000.png
# images/00028874_006.png
# images/00029108_001.png
# images/00029537_001.png
# images/00028798_000.png
# images/00029276_008.png
# images/00028369_000.png
# images/00029357_006.png
# images/00029866_001.png
# images/00028844_017.png
# images/00028924_012.png
# images/00029437_001.png
# images/00028698_000.png
# images/00028774_006.png
# images/00028526_004.png
# images/00030079_002.png
# images/00030205_000.png
# images/00028543_000.png
# images/00030534_000.png
# images/00028380_001.png
# images/00029943_038.png
# images/00030105_000.png
# images/00029292_001.png
# images/00029192_001.png
# images/00030323_013.png
# images/00029200_000.png
# images/00028856_007.png
# images/00030434_000.png
# images/00028772_000.png
# images/00030106_003.png
# images/00028837_005.png
# images/00030763_000.png
# images/00029100_000.png
# images/00030410_006.png
# images/00030279_002.png
# images/00029929_000.png
# images/00030006_003.png
# images/00028917_000.png
# images/00029026_000.png
# images/00028818_003.png
# images/00029672_010.png
# images/00030582_002.png
# images/00028443_000.png
# images/00029829_000.png
# images/00028509_036.png
# images/00028872_000.png
# images/00028918_003.png
# images/00029274_002.png
# images/00030689_000.png
# images/00030416_001.png
# images/00029511_001.png
# images/00029940_001.png
# images/00029088_012.png
# images/00029649_005.png
# images/00029355_000.png
# images/00029174_002.png
# images/00030589_000.png
# images/00028444_003.png
# images/00029840_001.png
# images/00030190_003.png
# images/00029684_000.png
# images/00030334_000.png
# images/00029255_000.png
# images/00028357_024.png
# images/00029740_001.png
# images/00029584_000.png
# images/00029705_006.png
# images/00029796_004.png
# images/00029075_005.png
# images/00028425_001.png
# images/00028269_000.png
# images/00028774_034.png
# images/00030137_009.png
# images/00029039_021.png
# images/00028598_000.png
# images/00029156_003.png
# images/00029237_001.png
# images/00030389_000.png
# images/00028180_001.png
# images/00029822_002.png
# images/00029666_001.png
# images/00029617_010.png
# images/00028911_005.png
# images/00028498_000.png
# images/00030005_000.png
# images/00028544_017.png
# images/00029903_000.png
# images/00028897_011.png
# images/00030323_041.png
# images/00028499_003.png
# images/00028811_005.png
# images/00028655_004.png
# images/00028407_002.png
# images/00030153_002.png
# images/00029803_000.png
# images/00029729_000.png
# images/00028873_017.png
# images/00029000_000.png
# images/00030663_000.png
# images/00029866_015.png
# images/00030234_000.png
# images/00030645_001.png
# images/00028717_000.png
# images/00030235_003.png
# images/00028817_000.png
# images/00030563_000.png
# images/00029704_003.png
# images/00028308_005.png
# images/00029977_002.png
# images/00029548_002.png
# images/00028526_018.png
# images/00029039_007.png
# images/00028591_002.png
# images/00030720_004.png
# images/00028343_000.png
# images/00028208_005.png
# images/00029877_002.png
# images/00029629_000.png
# images/00028572_000.png
# images/00028243_000.png
# images/00028672_000.png
# images/00029074_002.png
# images/00030489_000.png
# images/00029958_000.png
# images/00030111_009.png
# images/00029529_000.png
# images/00029311_001.png
# images/00029155_000.png
# images/00030701_002.png
# images/00030323_027.png
# images/00029817_024.png
# images/00029959_003.png
# images/00029484_000.png
# images/00029055_000.png
# images/00028392_005.png
# images/00028300_004.png
# images/00030071_001.png
# images/00029384_000.png
# images/00028774_048.png
# images/00028654_001.png
# images/00029056_003.png
# images/00028940_005.png
# images/00029532_014.png
# images/00029487_000.png
# images/00029385_003.png
# images/00030708_000.png
# images/00028398_000.png
# images/00029861_014.png
# images/00029037_001.png
# images/00028454_001.png
# images/00029088_026.png
# images/00030608_000.png
# images/00028298_000.png
# images/00030463_000.png
# images/00029703_000.png
# images/00029795_001.png
# images/00029423_005.png
# images/00028611_005.png
# images/00030609_003.png
# images/00028207_002.png
# images/00030134_000.png
# images/00029603_000.png
# images/00029903_014.png
# images/00028505_010.png
# images/00028784_004.png
# images/00030079_030.png
# images/00029932_000.png
# images/00029821_013.png
# images/00030034_000.png
# images/00028617_000.png
# images/00029448_002.png
# images/00028208_033.png
# images/00030792_000.png
# images/00028436_002.png
# images/00030363_000.png
# images/00028946_000.png
# images/00030077_010.png
# images/00029504_003.png
# images/00029596_004.png
# images/00028518_003.png
# images/00028517_000.png
# images/00030289_000.png
# images/00030520_004.png
# images/00030183_005.png
# images/00029858_000.png
# images/00030323_055.png
# images/00029429_000.png
# images/00029597_007.png
# images/00028472_000.png
# images/00028499_017.png
# images/00029914_001.png
# images/00029433_003.png
# images/00029758_000.png
# images/00029329_000.png
# images/00030146_004.png
# images/00028372_000.png
# images/00030189_000.png
# images/00028292_005.png
# images/00028939_002.png
# images/00028996_008.png
# images/00029284_000.png
# images/00028765_030.png
# images/00030159_011.png
# images/00030346_004.png
# images/00030079_016.png
# images/00029340_001.png
# images/00029184_000.png
# images/00029579_008.png
# images/00028902_001.png
# images/00030427_002.png
# images/00028208_019.png
# images/00028330_007.png
# images/00028876_003.png
# images/00029832_000.png
# images/00028198_000.png
# images/00028354_001.png
# images/00030508_000.png
# images/00029670_004.png
# images/00030059_011.png
# images/00030247_007.png
# images/00029422_002.png
# images/00028572_014.png
# images/00028683_001.png
# images/00030408_000.png
# images/00030389_014.png
# images/00029503_000.png
# images/00028822_006.png
# images/00029570_004.png
# images/00028920_000.png
# images/00030737_000.png
# images/00028684_004.png
# images/00028549_009.png
# images/00029129_000.png
# images/00028875_000.png
# images/00029403_000.png
# ...
# images/00028773_000.png
# images/00028344_000.png
# images/00030206_014.png
# images/00030090_000.png
# images/00028673_000.png
# images/00029256_000.png
# images/00029075_002.png
# images/00028244_000.png
# images/00028774_031.png
# images/00030137_006.png
# images/00029585_000.png
# images/00029156_000.png
# images/00029817_021.png
# images/00030218_004.png
# images/00028326_001.png
# images/00029313_004.png
# images/00029485_000.png
# images/00028911_002.png
# images/00028509_019.png
# images/00028876_065.png
# images/00030547_004.png
# images/00030038_009.png
# images/00028811_002.png
# images/00028544_014.png
# images/00028499_000.png
# images/00028655_001.png
# images/00029213_004.png
# images/00030628_002.png
# images/00029866_012.png
# images/00028873_014.png
# images/00029567_001.png
# images/00030709_000.png
# images/00028399_000.png
# images/00029230_000.png
# images/00029804_000.png
# images/00029038_001.png
# images/00030720_001.png
# images/00029039_004.png
# images/00029387_006.png
# images/00029796_001.png
# images/00028308_002.png
# images/00030235_000.png
# images/00029704_000.png
# images/00029437_012.png
# images/00028844_028.png
# images/00028774_017.png
# images/00028526_015.png
# images/00030564_000.png
# images/00028208_002.png
# images/00030135_000.png
# images/00028457_007.png
# images/00029705_003.png
# images/00030464_000.png
# images/00028718_000.png
# images/00028380_012.png
# images/00028618_000.png
# images/00030323_024.png
# images/00030111_006.png
# images/00029878_002.png
# images/00028890_010.png
# images/00029130_000.png
# images/00030793_000.png
# images/00028400_001.png
# images/00030621_004.png
# images/00028357_007.png
# images/00029959_000.png
# images/00029778_002.png
# images/00028947_000.png
# images/00028392_002.png
# images/00028573_000.png
# images/00028300_001.png
# images/00030279_013.png
# images/00029859_000.png
# images/00028948_003.png
# images/00029460_003.png
# images/00028473_000.png
# images/00029056_000.png
# images/00029267_001.png
# images/00029970_001.png
# images/00029385_000.png
# images/00028924_009.png
# images/00030693_000.png
# images/00029870_001.png
# images/00029088_023.png
# images/00029285_000.png
# images/00030509_000.png
# images/00029862_000.png
# images/00028512_005.png
# images/00029075_016.png
# images/00029817_007.png
# images/00028611_002.png
# images/00030609_000.png
# images/00028299_000.png
# images/00028766_002.png
# images/00028784_001.png
# images/00030035_000.png
# images/00028940_002.png
# images/00029604_000.png
# images/00028774_045.png
# images/00028199_000.png
# images/00029821_010.png
# images/00028256_004.png
# images/00029852_002.png
# images/00029423_002.png
# images/00028208_030.png
# images/00028785_004.png
# images/00029903_011.png
# images/00028866_002.png
# images/00029504_000.png
# images/00029933_000.png
# images/00029666_012.png
# images/00029596_001.png
# images/00029672_007.png
# images/00030364_000.png
# images/00030520_001.png
# images/00030183_002.png
# images/00029833_000.png
# images/00030323_052.png
# images/00028357_035.png
# images/00029597_004.png
# images/00029088_009.png
# images/00029030_000.png
# images/00030178_010.png
# images/00030264_000.png
# images/00029085_000.png
# images/00029659_000.png
# images/00028847_000.png
# images/00028418_000.png
# images/00030593_000.png
# images/00029976_010.png
# images/00028292_002.png
# images/00029915_001.png
# images/00029759_000.png
# images/00028747_000.png
# images/00029670_001.png
# images/00030246_001.png
# images/00028373_000.png
# images/00030346_001.png
# images/00030079_013.png
# images/00029548_013.png
# images/00028996_005.png
# images/00029579_005.png
# images/00029039_018.png
# images/00028208_016.png
# images/00028273_000.png
# images/00029988_000.png
# images/00028829_001.png
# images/00029479_005.png
# images/00029185_000.png
# images/00029888_000.png
# images/00030651_007.png
# images/00030247_004.png
# images/00030323_038.png
# images/00030389_011.png
# images/00028572_011.png
# images/00028897_008.png
# images/00029207_009.png
# images/00028330_004.png
# images/00029889_003.png
# images/00029570_001.png
# images/00030220_001.png
# images/00028684_001.png
# images/00028549_006.png
# images/00030409_000.png
# images/00029404_000.png
# images/00029617_007.png
# images/00028921_000.png
# images/00029142_004.png
# images/00030738_000.png
# images/00030309_000.png
# images/00029496_001.png
# images/00030209_000.png
# images/00029652_002.png
# images/00028821_000.png
# images/00029223_002.png
# images/00030638_000.png
# images/00029733_000.png
# images/00028318_000.png
# images/00029981_002.png
# images/00028903_001.png
# images/00030164_000.png
# images/00029304_000.png
# images/00028822_003.png
# images/00028666_002.png
# images/00028485_004.png
# images/00030320_001.png
# images/00029881_002.png
# images/00029633_000.png
# images/00030079_041.png
# images/00028995_002.png
# images/00028611_016.png
# images/00030609_014.png
# images/00030493_000.png
# images/00029962_000.png
# images/00030064_000.png
# images/00029297_004.png
# images/00029478_002.png
# images/00028803_001.png
# images/00028647_000.png
# images/00030393_000.png
# images/00030650_004.png
# images/00028976_000.png
# images/00029715_001.png
# images/00029559_000.png
# images/00030550_004.png
# images/00028547_000.png
# images/00029863_003.png
# images/00030394_003.png
# images/00028219_003.png
# images/00030146_001.png
# images/00029596_015.png
# images/00029459_000.png
# images/00028548_003.png
# images/00030046_001.png
# images/00029788_000.png
# images/00029279_005.png
# images/00029359_000.png
# images/00028518_014.png
# images/00030712_000.png
# images/00030375_001.png
# images/00030612_000.png
# images/00028958_001.png
# images/00029470_001.png
# images/00028529_001.png
# images/00029041_001.png
# images/00029809_020.png
# images/00030128_002.png
# images/00028721_000.png
# images/00028523_020.png
# images/00029950_010.png
# images/00028640_002.png
# images/00028505_007.png
# images/00028211_002.png
# images/00030079_027.png
# images/00028421_000.png
# images/00028523_006.png
# images/00030538_000.png
# images/00028454_012.png
# images/00030786_002.png
# images/00028384_001.png
# images/00028876_000.png
# images/00030109_000.png
# images/00028621_000.png
# images/00029196_001.png
# images/00029433_000.png
# images/00029204_000.png
# images/00030438_000.png
# images/00030009_000.png
# images/00028950_000.png
# images/00029533_000.png
# images/00029104_000.png
# images/00030767_000.png
# images/00030408_011.png
# images/00028285_004.png
# images/00030439_003.png
# images/00030120_001.png
# images/00030293_000.png
# images/00029762_000.png
# images/00030275_001.png
# images/00028795_002.png
# images/00029105_003.png
# images/00028366_002.png
# images/00030339_003.png
# images/00029676_010.png
# images/00028447_000.png
# images/00028765_013.png
# images/00029278_002.png
# images/00028290_010.png
# images/00029763_003.png
# images/00030193_000.png
# images/00029809_006.png
# images/00030159_008.png
# images/00028932_001.png
# images/00028776_000.png
# images/00028347_000.png
# images/00029688_000.png
# images/00029844_001.png
# images/00030102_002.png
# images/00029663_003.png
# images/00029415_001.png
# images/00029259_000.png
# images/00028317_011.png
# images/00029235_006.png
# images/00029900_002.png
# images/00029744_001.png
# images/00029588_000.png
# images/00028429_001.png
# images/00029159_000.png
# images/00028677_003.png
# images/00030512_000.png
# images/00029589_003.png
# images/00028961_001.png
# images/00029745_004.png
# images/00028211_030.png
# images/00030079_055.png
# images/00030412_000.png
# images/00029470_015.png
# images/00030637_011.png
# images/00028173_014.png
# images/00029907_000.png
# images/00028750_000.png
# images/00030413_003.png
# images/00029863_017.png
# images/00030338_000.png
# images/00028628_012.png
# images/00030561_005.png
# images/00028521_000.png
# images/00029217_007.png
# images/00028184_001.png
# images/00030157_002.png
# images/00029807_000.png
# images/00030077_007.png
# images/00029004_000.png
# images/00028850_000.png
# images/00028518_028.png
# images/00030667_000.png
# images/00028341_005.png
# images/00030238_000.png
# images/00030158_005.png
# images/00029808_003.png
# images/00029333_000.png
# images/00029152_002.png
# images/00029041_015.png
# images/00030567_000.png
# images/00029105_017.png
# images/00029662_000.png
# images/00029481_002.png
# images/00029233_000.png
# images/00030093_000.png
# images/00028211_016.png
# images/00029991_000.png
# images/00029562_000.png
# images/00028939_013.png
# images/00030059_008.png
# images/00029774_004.png
# images/00028676_000.png
# images/00028247_000.png
# images/00030039_003.png
# images/00029532_011.png
# images/00030300_010.png
# images/00029134_003.png
# images/00028576_000.png
# images/00028765_027.png
# images/00029861_011.png
# images/00029488_000.png
# images/00028476_000.png
# images/00029059_000.png
# images/00029135_006.png
# images/00028304_004.png
# images/00030606_005.png
# images/00030312_000.png
# images/00029544_001.png
# images/00029388_000.png
# images/00029464_006.png
# images/00030741_000.png
# images/00029035_006.png
# images/00029943_012.png
# images/00028876_014.png
# images/00029358_011.png
# images/00029839_009.png
# images/00028987_001.png
# images/00030641_000.png
# images/00028558_001.png
# images/00030212_000.png
# images/00029133_000.png
# images/00028974_022.png
# images/00030286_002.png
# images/00030038_000.png
# images/00028458_001.png
# images/00030541_000.png
# images/00029813_023.png
# images/00028240_002.png
# images/00029707_000.png
# images/00029799_001.png
# images/00029526_002.png
# images/00029259_014.png
# images/00028221_000.png
# images/00030012_000.png
# images/00028321_000.png
# images/00030138_000.png
# images/00029607_000.png
# images/00029699_001.png
# images/00029159_014.png
# images/00028509_010.png
# images/00028650_000.png
# images/00029052_002.png
# images/00030467_000.png
# images/00029936_000.png
# images/00029998_012.png
# images/00030796_000.png
# images/00030079_069.png
# images/00028550_000.png
# images/00030523_001.png
# images/00030367_000.png
# images/00029891_000.png
# images/00029462_000.png
# images/00029033_000.png
# images/00030696_000.png
# images/00029736_000.png
# images/00029469_012.png
# images/00028987_015.png
# images/00029791_000.png
# images/00029276_010.png
# images/00029362_000.png
# images/00028880_003.png
# images/00028632_001.png
# images/00030678_001.png
# images/00028203_001.png
# images/00029918_001.png
# images/00029691_000.png
# images/00029813_009.png
# images/00030636_022.png
# images/00030753_004.png
# images/00029115_001.png
# images/00028376_000.png
# images/00028195_002.png
# images/00029919_004.png
# images/00029288_000.png
# images/00028861_001.png
# images/00028276_000.png
# images/00028876_042.png
# images/00029015_001.png
# images/00030162_022.png
# images/00030573_009.png
# images/00029532_025.png
# images/00029188_000.png
# images/00029507_000.png
# images/00028433_004.png
# images/00029991_014.png
# images/00030112_000.png
# images/00028253_009.png
# images/00030441_000.png
# images/00028582_009.png
# images/00028358_001.png
# images/00030260_002.png
# images/00029910_000.png
# images/00030039_017.png
# images/00030770_000.png
# images/00030341_000.png
# images/00028687_001.png
# images/00028258_001.png
# images/00029165_009.png
# images/00029599_001.png
# images/00029755_002.png
# images/00028924_000.png
# images/00029326_002.png
# images/00028844_005.png
# images/00029836_000.png
# images/00030636_008.png
# images/00029081_002.png
# images/00028876_028.png
# images/00030267_000.png
# images/00029407_000.png
# images/00028350_000.png
# images/00028450_000.png
# images/00029146_007.png
# images/00029943_026.png
# images/00029984_002.png
# images/00030162_008.png
# images/00029631_008.png
# images/00029307_000.png
# images/00030596_000.png
# images/00030561_019.png
# images/00030323_001.png
# images/00030167_000.png
# images/00030652_001.png
# images/00029262_000.png
# images/00029813_037.png
# images/00030496_000.png
# images/00030137_011.png
# images/00028979_000.png
# images/00028974_008.png
# images/00029591_000.png
# images/00029259_028.png
# images/00029162_000.png
# images/00030249_001.png
# images/00030497_003.png
# images/00029159_028.png
# images/00030068_003.png
# images/00029491_000.png
# images/00028509_024.png
# images/00028626_006.png
# images/00030305_002.png
# images/00028176_000.png
# images/00028935_001.png
# images/00028661_001.png
# images/00029244_001.png
# images/00029088_000.png
# images/00029144_001.png
# images/00030471_003.png
# images/00029300_002.png
# images/00030715_000.png
# images/00030635_005.png
# images/00030206_005.png
# images/00029810_000.png
# images/00029474_004.png
# images/00028844_033.png
# images/00030670_000.png
# images/00030241_000.png
# images/00029710_000.png
# images/00028774_022.png
# images/00028526_020.png
# images/00028824_000.png
# images/00029201_005.png
# images/00030570_000.png
# images/00029579_010.png
# images/00030141_000.png
# images/00030111_011.png
# images/00028861_015.png
# images/00028724_000.png
# images/00028457_012.png
# images/00028644_005.png
# images/00028876_056.png
# images/00028544_005.png
# images/00029207_000.png
# images/00029636_000.png
# images/00029455_002.png
# images/00028357_012.png
# images/00028725_003.png
# images/00028433_018.png
# images/00028250_000.png
# images/00029965_000.png
# images/00030067_000.png
# images/00029536_000.png
# images/00028873_005.png
# images/00029107_000.png
# images/00028606_001.png
# images/00028774_008.png
# images/00030396_000.png
# images/00029865_000.png
# images/00029062_000.png
# images/00029537_003.png
# images/00028874_008.png
# images/00029108_003.png
# images/00028844_019.png
# images/00030296_000.png
# images/00029437_003.png
# images/00029866_003.png
# images/00028879_000.png
# images/00029391_000.png
# images/00028698_002.png
# images/00029357_008.png
# images/00028526_006.png
# images/00028232_001.png
# images/00028774_050.png
# images/00028779_000.png
# images/00029291_000.png
# images/00028380_003.png
# images/00030105_002.png
# images/00030434_002.png
# images/00028996_010.png
# images/00028890_001.png
# images/00029200_002.png
# images/00030615_000.png
# images/00030323_015.png
# images/00029817_012.png
# images/00030106_005.png
# images/00028187_001.png
# images/00029373_001.png
# images/00029192_003.png
# images/00030515_000.png
# images/00030410_008.png
# images/00030279_004.png
# images/00029610_000.png
# images/00029510_000.png
# images/00028837_007.png
# images/00028524_000.png
# images/00030470_000.png
# images/00029672_012.png
# images/00030041_000.png
# images/00029274_004.png
# images/00028509_038.png
# images/00028918_005.png
# images/00028624_000.png
# images/00030689_002.png
# images/00030370_000.png
# images/00029940_003.png
# images/00029199_001.png
# images/00028953_000.png
# images/00029088_014.png
# images/00029174_004.png
# images/00029666_003.png
# images/00030270_000.png
# images/00028853_000.png
# images/00029436_000.png
# images/00028424_000.png
# images/00029007_000.png
# images/00029665_000.png
# images/00029765_000.png
# images/00030023_001.png
# images/00029336_000.png
# images/00029747_001.png
# images/00029075_007.png
# images/00028425_003.png
# images/00029821_001.png
# images/00030196_000.png
# images/00028774_036.png
# images/00029191_000.png
# images/00030323_043.png
# images/00028208_021.png
# images/00029156_005.png
# images/00029994_000.png
# images/00030252_001.png
# images/00030096_000.png
# images/00029822_004.png
# images/00028579_000.png
# images/00028911_007.png
# images/00028679_000.png
# images/00028498_002.png
# images/00028811_007.png
# images/00029647_001.png
# images/00029903_002.png
# images/00029091_000.png
# images/00028897_013.png
# images/00029318_001.png
# images/00028357_026.png
# images/00030178_001.png
# images/00028499_005.png
# images/00028180_003.png
# images/00030153_004.png
# images/00028690_001.png
# images/00028549_011.png
# images/00028873_019.png
# images/00029976_001.png
# images/00030415_000.png
# images/00030234_002.png
# images/00030744_000.png
# images/00030315_000.png
# images/00029548_004.png
# images/00029866_017.png
# images/00030079_004.png
# images/00029410_000.png
# images/00030644_000.png
# images/00028591_004.png
# images/00029039_009.png
# images/00028208_007.png
# images/00029310_000.png
# images/00028611_021.png
# images/00029155_002.png
# images/00030170_000.png
# images/00029817_026.png
# images/00028572_002.png
# images/00029311_003.png
# images/00028753_000.png
# images/00028324_000.png
# images/00030323_029.png
# images/00030389_002.png
# images/00030070_000.png
# images/00029959_005.png
# images/00029236_000.png
# images/00028653_000.png
# images/00029876_001.png
# images/00028224_000.png
# images/00028300_006.png
# images/00029565_000.png
# images/00028982_000.png
# images/00029136_000.png
# images/00030799_000.png
# images/00030152_001.png
# images/00029056_005.png
# images/00029596_020.png
# images/00029894_000.png
# images/00029465_000.png
# images/00029385_005.png
# images/00030381_001.png
# images/00030481_001.png

# %%
from __future__ import division
from __future__ import print_function

import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import os
import sys
import pprint
import warnings
import json
from torch.optim import lr_scheduler
from torch.autograd import Variable
from torchvision.models import densenet121 as torch_densenet121

#from densenet import densenet121
#import util

# %% [markdown]
# ### DenseNet

# %%
import torch.nn.functional as F
import torch.utils.model_zoo as model_zoo
from collections import OrderedDict

__all__ = ['DenseNet', 'densenet121', 'densenet169', 'densenet201', 'densenet161']


model_urls = {
    'densenet121': 'https://download.pytorch.org/models/densenet121-a639ec97.pth',
    'densenet169': 'https://download.pytorch.org/models/densenet169-b2777c0a.pth',
    'densenet201': 'https://download.pytorch.org/models/densenet201-c1103571.pth',
    'densenet161': 'https://download.pytorch.org/models/densenet161-8d451a50.pth',
}


def densenet121(pretrained=False, **kwargs):
    r"""Densenet-121 model from
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_
    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
    """
    #model = DenseNet(num_init_features=64, growth_rate=32, block_config=(6, 12, 24, 16), **kwargs)
    model = torch_densenet121(weights="IMAGENET1K_V1" if pretrained else None)  # 使用 PyTorch 預訓練的模型
    """
    if pretrained:
        model.load_state_dict(model_zoo.load_url(model_urls['densenet121']))
    """
    return model


def densenet169(pretrained=False, **kwargs):
    r"""Densenet-169 model from
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_
    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
    """
    model = DenseNet(num_init_features=64, growth_rate=32, block_config=(6, 12, 32, 32),
                     **kwargs)
    if pretrained:
        model.load_state_dict(model_zoo.load_url(model_urls['densenet169']))
    return model


def densenet201(pretrained=False, **kwargs):
    r"""Densenet-201 model from
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_
    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
    """
    model = DenseNet(num_init_features=64, growth_rate=32, block_config=(6, 12, 48, 32),
                     **kwargs)
    if pretrained:
        model.load_state_dict(model_zoo.load_url(model_urls['densenet201']))
    return model


def densenet161(pretrained=False, **kwargs):
    r"""Densenet-161 model from
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_
    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
    """
    model = DenseNet(num_init_features=96, growth_rate=48, block_config=(6, 12, 36, 24),
                     **kwargs)
    if pretrained:
        model.load_state_dict(model_zoo.load_url(model_urls['densenet161']))
    return model


class _DenseLayer(nn.Sequential):
    def __init__(self, num_input_features, growth_rate, bn_size, drop_rate):
        super(_DenseLayer, self).__init__()
        self.add_module('norm.1', nn.BatchNorm2d(num_input_features)),
        self.add_module('relu.1', nn.ReLU(inplace=True)),
        self.add_module('conv.1', nn.Conv2d(num_input_features, bn_size *
                        growth_rate, kernel_size=1, stride=1, bias=False)),
        self.add_module('norm.2', nn.BatchNorm2d(bn_size * growth_rate)),
        self.add_module('relu.2', nn.ReLU(inplace=True)),
        self.add_module('conv.2', nn.Conv2d(bn_size * growth_rate, growth_rate,
                        kernel_size=3, stride=1, padding=1, bias=False)),
        self.drop_rate = drop_rate

    def forward(self, x):
        new_features = super(_DenseLayer, self).forward(x)
        if self.drop_rate > 0:
            new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
        return torch.cat([x, new_features], 1)


class _DenseBlock(nn.Sequential):
    def __init__(self, num_layers, num_input_features, bn_size, growth_rate, drop_rate):
        super(_DenseBlock, self).__init__()
        for i in range(num_layers):
            layer = _DenseLayer(num_input_features + i * growth_rate, growth_rate, bn_size, drop_rate)
            self.add_module('denselayer%d' % (i + 1), layer)


class _Transition(nn.Sequential):
    def __init__(self, num_input_features, num_output_features):
        super(_Transition, self).__init__()
        self.add_module('norm', nn.BatchNorm2d(num_input_features))
        self.add_module('relu', nn.ReLU(inplace=True))
        self.add_module('conv', nn.Conv2d(num_input_features, num_output_features,
                                          kernel_size=1, stride=1, bias=False))
        self.add_module('pool', nn.AvgPool2d(kernel_size=2, stride=2))


class DenseNet(nn.Module):
    r"""Densenet-BC model class, based on
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_
    Args:
        growth_rate (int) - how many filters to add each layer (`k` in paper)
        block_config (list of 4 ints) - how many layers in each pooling block
        num_init_features (int) - the number of filters to learn in the first convolution layer
        bn_size (int) - multiplicative factor for number of bottle neck layers
          (i.e. bn_size * k features in the bottleneck layer)
        drop_rate (float) - dropout rate after each dense layer
        num_classes (int) - number of classification classes
    """
    def __init__(self, growth_rate=32, block_config=(6, 12, 24, 16),
                 num_init_features=64, bn_size=4, drop_rate=0, num_classes=1000):

        super(DenseNet, self).__init__()

        # First convolution
        self.features = nn.Sequential(OrderedDict([
            ('conv0', nn.Conv2d(3, num_init_features, kernel_size=7, stride=2, padding=3, bias=False)),
            ('norm0', nn.BatchNorm2d(num_init_features)),
            ('relu0', nn.ReLU(inplace=True)),
            ('pool0', nn.MaxPool2d(kernel_size=3, stride=2, padding=1)),
        ]))

        # Each denseblock
        num_features = num_init_features
        for i, num_layers in enumerate(block_config):
            block = _DenseBlock(num_layers=num_layers, num_input_features=num_features,
                                bn_size=bn_size, growth_rate=growth_rate, drop_rate=drop_rate)
            self.features.add_module('denseblock%d' % (i + 1), block)
            num_features = num_features + num_layers * growth_rate
            if i != len(block_config) - 1:
                trans = _Transition(num_input_features=num_features, num_output_features=num_features // 2)
                self.features.add_module('transition%d' % (i + 1), trans)
                num_features = num_features // 2

        # Final batch norm
        self.features.add_module('norm5', nn.BatchNorm2d(num_features))

        self.gap = nn.AdaptiveAvgPool2d(1)

        # Linear layer
        self.classifier = nn.Linear(num_features, num_classes)

    def forward(self, x):
        features = self.features(x)
        out = F.relu(features, inplace=True)
        out = self.gap(out).view(features.size(0), -1)
        out = self.classifier(out)
        return out

# %% [markdown]
# ### util

# %%
import pandas as pd
import torch.utils.data as data
import torchvision.transforms as transforms
import sklearn.metrics
import argparse
import os

from torch.autograd import Variable
from PIL import Image


def get_parser():
    parser = argparse.ArgumentParser()
    parser.add_argument("--model", default="densenet", type=str)
    parser.add_argument("--optimizer", default="adam", type=str)
    parser.add_argument("--lr", default=0.0001, type=float)
    parser.add_argument("--weight_decay", default=0.0, type=float)
    parser.add_argument("--drop_rate", default=0.0, type=float)
    parser.add_argument("--epochs", default=15, type=int)
    parser.add_argument("--batch_size", default=16, type=int)
    parser.add_argument("--workers", default=8, type=int)
    parser.add_argument("--seed", default=123456, type=int)
    parser.add_argument("--tag", default="", type=str)
    parser.add_argument("--toy", action="store_true")
    parser.add_argument("--save_path", default=None, type=str)
    parser.add_argument("--scale", default=224, type=int)
    parser.add_argument("--horizontal_flip", action="store_true")
    parser.add_argument("--verbose", action="store_true")
    parser.add_argument("--scratch", action="store_true")
    parser.add_argument("--train_weighted", action="store_true")
    parser.add_argument("--valid_weighted", action="store_true")
    parser.add_argument("--size", default=None, type=str)
    return parser



class Dataset(data.Dataset):
    def __init__(self, args, data_split):
        super(Dataset, self).__init__()

        if args.tag:
            tag = "_"+args.tag
            df = pd.read_csv(os.path.join("/content/drive/MyDrive/ML/data/%s%s.csv" % (data_split, tag)))
        else:
            df = pd.read_csv(os.path.join("/content/drive/MyDrive/ML/data/%s.csv" % (data_split)))

        if args.toy:
            df = df.sample(frac=0.01)

        self.df = df
        self.img_paths = df["Path"].tolist()
        self.pathologies = [col for col in df.columns.values if col != "Path"]

        self.labels = df[self.pathologies].values.astype(int)

        self.n_classes = self.labels.shape[1]

        normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        if data_split == "train":
            transforms_lst = [
                transforms.Resize((args.scale, args.scale)),
                transforms.RandomHorizontalFlip() if args.horizontal_flip else None,
                transforms.ToTensor(),
                normalize,
            ]
            self.transform = transforms.Compose([t for t in transforms_lst if t])
        else:
            self.transform = transforms.Compose([
                transforms.Resize((args.scale, args.scale)),
                transforms.ToTensor(),
                normalize,
            ])
        self.df = df


        if (data_split == "train" and args.train_weighted) or (data_split == "valid" and args.valid_weighted):
            self.get_weights(args, data_split)


    def get_weights(self, args, data_split):

        self.use_gpu = torch.cuda.is_available()
        p_count = (self.labels == 1).sum(axis = 0)
        self.p_count = p_count
        n_count = (self.labels == 0).sum(axis = 0)
        total = p_count + n_count

        # invert *opposite* weights to obtain weighted loss
        # (positives weighted higher, all weights same across batches, and p_weight + n_weight == 1)
        p_weight = n_count / total
        n_weight = p_count / total

        self.p_weight_loss = Variable(torch.FloatTensor(p_weight), requires_grad=False)
        self.n_weight_loss = Variable(torch.FloatTensor(n_weight), requires_grad=False)

        print ("Positive %s Loss weight:" % data_split, self.p_weight_loss.data.numpy())
        print ("Negative %s Loss weight:" % data_split, self.n_weight_loss.data.numpy())
        random_loss = sum((p_weight[i] * p_count[i] + n_weight[i] * n_count[i]) *\
                                               -np.log(0.5) / total[i] for i in range(self.n_classes)) / self.n_classes
        print ("Random %s Loss:" % data_split, random_loss)


    def __getitem__(self, index):
        img = Image.open(self.img_paths[index]).convert("RGB")
        label = self.labels[index]

        return self.transform(img), torch.LongTensor(label)

    def __len__(self):
        return len(self.img_paths)

    def weighted_loss(self, preds, target, epoch=1):

        weights = target.type(torch.FloatTensor) * (self.p_weight_loss.expand_as(target)) + \
                  (target == 0).type(torch.FloatTensor) * (self.n_weight_loss.expand_as(target))
        if self.use_gpu:
            weights = weights.cuda()
        loss = 0.0
        for i in range(self.n_classes):
            loss += nn.functional.binary_cross_entropy_with_logits(preds[:,i], target[:,i], weight=weights[:,i])
        return loss / self.n_classes


def evaluate(gts, probabilities, pathologies, use_only_index = None):
    assert(np.all(probabilities >= 0) == True)
    assert(np.all(probabilities <= 1) == True)

    def compute_metrics_for_class(i):
         p, r, t = sklearn.metrics.precision_recall_curve(gts[:, i], probabilities[:, i])
         PR_AUC = sklearn.metrics.auc(r, p)
         ROC_AUC = sklearn.metrics.roc_auc_score(gts[:, i], probabilities[:, i])
         F1 = sklearn.metrics.f1_score(gts[:, i], preds[:, i])
         acc = sklearn.metrics.accuracy_score(gts[:, i], preds[:, i])
         count = np.sum(gts[:, i])
         return PR_AUC, ROC_AUC, F1, acc, count

    PR_AUCs = []
    ROC_AUCs = []
    F1s = []
    accs = []
    counts = []
    preds = probabilities >= 0.5

    classes = [use_only_index] if use_only_index is not None else range(len(gts[0]))

    for i in classes:
        try:
            PR_AUC, ROC_AUC, F1, acc, count = compute_metrics_for_class(i)
        except ValueError:
            continue
        PR_AUCs.append(PR_AUC)
        ROC_AUCs.append(ROC_AUC)
        F1s.append(F1)
        accs.append(acc)
        counts.append(count)
        print('Class: {!s} Count: {:d} PR AUC: {:.4f} ROC AUC: {:.4f} F1: {:.3f} Acc: {:.3f}'.format(pathologies[i], count, PR_AUC, ROC_AUC, F1, acc))

    avg_PR_AUC = np.average(PR_AUCs)
    avg_ROC_AUC = np.average(ROC_AUCs, weights=counts)
    avg_F1 = np.average(F1s, weights=counts)

    print('Avg PR AUC: {:.3f}'.format(avg_PR_AUC))
    print('Avg ROC AUC: {:.3f}'.format(avg_ROC_AUC))
    print('Avg F1: {:.3f}'.format(avg_F1))
    return avg_PR_AUC, avg_ROC_AUC, avg_F1


def loader_to_gts(data_loader):
    gts = []
    for (inputs, labels) in data_loader:
        for label in labels.cpu().numpy().tolist():
            gts.append(label)
    gts = np.array(gts)
    return gts


def load_data(args):

    train_dataset = Dataset(args, "train_young")
    valid_dataset = Dataset(args, "valid_young")

    train_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=args.batch_size, shuffle=True,
            num_workers=args.workers, pin_memory=True, sampler=None)

    valid_loader = torch.utils.data.DataLoader(
            valid_dataset, batch_size=args.batch_size, shuffle=False,
            num_workers=args.workers, pin_memory=True, sampler=None)

    return train_loader, valid_loader

# %% [markdown]
# ### train

# %%
import matplotlib.pyplot as plt
import time
class DenseNet_train(nn.Module):
    def __init__(self, config, nclasses):
        super(DenseNet_train, self).__init__()
        self.model_ft = densenet121(pretrained=not config.scratch, drop_rate=config.drop_rate)
        num_ftrs = self.model_ft.classifier.in_features
        self.model_ft.classifier = nn.Linear(num_ftrs, nclasses)
        self.config = config
    def forward(self, x):
        return self.model_ft(x)

def transform_data(data, use_gpu, train=False):
    inputs, labels = data
    # GPU
    labels = labels.type(torch.FloatTensor)
    if use_gpu is True:
        inputs = inputs.cuda()
        labels = labels.cuda()
    #
    with torch.no_grad():
        inputs = Variable(inputs, requires_grad=False)
        labels = Variable(labels, requires_grad=False)
    return inputs, labels

# %%
def train_epoch(epoch, args, model, loader, criterion, optimizer):
    model.train()
    batch_losses = []
    start_time = time.time() #記錄初始時間

    for batch_idx, data in enumerate(loader):
        batch_start_time = time.time()  #每個batch開始時間
        inputs, labels = transform_data(data, True, train=True)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels, epoch=epoch)
        loss.backward()
        optimizer.step()

        #計算累計時間
        cumulative_time = time.time() - start_time
        print("Epoch: {:d} Batch: {:d} ({:d}) Train Loss: {:.6f} Time Elapsed: {:.2f} seconds".format(
            epoch, batch_idx, args.batch_size, loss.data, cumulative_time))
        sys.stdout.flush()

        #batch_losses.append(loss.data) #CPU
        batch_losses.append(loss.data.cpu().numpy()) #GPU
    train_loss = np.mean(batch_losses)
    print("Training Loss: {:.6f}".format(train_loss))
    return train_loss


def test_epoch(model, loader, criterion, epoch=1):
    """
    Returns: (AUC, ROC AUC, F1, validation loss)
    """
    model.eval()
    test_losses = []
    outs = []
    gts = []
    for data in loader:
        #for gt in data[1].numpy().tolist(): #CPU
        for gt in data[1].cpu().numpy().tolist(): #GPU
            gts.append(gt)
        inputs, labels = transform_data(data, True, train=False)
        outputs = model(inputs)
        loss = criterion(outputs, labels, epoch=epoch)
        #test_losses.append(loss.data) #CPU
        test_losses.append(loss.data.cpu().numpy()) #GPU
        out = torch.sigmoid(outputs).data.cpu().numpy()
        outs.extend(out)
    avg_loss = np.mean(test_losses)
    print("Validation Loss: {:.6f}".format(avg_loss))
    outs = np.array(outs)
    gts = np.array(gts)
    avg_pr_auc, avg_roc_auc, avg_f1 = evaluate(gts, outs, loader.dataset.pathologies)
    print(f"Validation AUC: PR AUC={avg_pr_auc:.3f}, ROC AUC={avg_roc_auc:.3f}, F1 Score={avg_f1:.3f}")
    return evaluate(gts, outs, loader.dataset.pathologies) + (avg_loss,)


def get_loss(dataset, weighted):

    criterion = nn.MultiLabelSoftMarginLoss()

    def loss(preds, target, epoch):

        if weighted:

            return dataset.weighted_loss(preds, target, epoch=epoch)

        else:

            return criterion(preds, target)

    return loss


def run(args):

    use_gpu = torch.cuda.is_available()
    model = None

    train, val = load_data(args)
    nclasses = train.dataset.n_classes
    print("Number of classes:", nclasses)

    if args.model == "densenet":
        model = DenseNet_train(args, nclasses)
    else:
        print("{} is not a valid model.".format(args.model))

    if use_gpu:
        model = model.cuda()

    train_criterion = get_loss(train.dataset, args.train_weighted)
    val_criterion = get_loss(val.dataset, args.valid_weighted)

    if args.optimizer == "adam":
        optimizer = optim.Adam(
                       filter(lambda p: p.requires_grad, model.model_ft.parameters()),
                       lr=args.lr,
                       weight_decay=args.weight_decay)
    elif args.optimizer == "rmsprop":
        optimizer = optim.RMSprop(
                       filter(lambda p: p.requires_grad, model.model_ft.parameters()),
                       lr=args.lr,
                       weight_decay=args.weight_decay)
    else:
        print("{} is not a valid optimizer.".format(args.optimizer))

    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, patience=1, threshold=0.001, factor=0.1)
    best_model_wts, best_loss = model.state_dict(), float("inf")

    #畫loss、AUC圖
    train_losses = []
    valid_losses = []
    roc_aucs = []
    elapsed_times = []
    start_time = time.time()

    plt.ion()
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    ax1.set_title("Training and Validation Loss Over Time")
    ax1.set_xlabel("Elapsed Time (s)")
    ax1.set_ylabel("Loss")
    ax2.set_title("Validation ROC AUC Over Time")
    ax2.set_xlabel("Elapsed Time (s)")
    ax2.set_ylabel("ROC AUC")

    ax1.plot([], [], label="Train Loss", color="blue")
    ax1.plot([], [], label="Validation Loss", color="orange")
    ax1.legend(loc='upper right')

    ax2.plot([], [], label="ROC AUC", color="green")
    ax2.legend(loc='upper right')


    counter = 0
    for epoch in range(1, args.epochs + 1):
        print("Epoch {}/{}".format(epoch, args.epochs))
        print("-" * 10)

        train_loss = train_epoch(epoch, args, model, train,train_criterion, optimizer)
        #picture
        train_losses.append(train_loss)

        _, epoch_auc, _, valid_loss = test_epoch(model, val, val_criterion, epoch)
        #picture
        valid_losses.append(valid_loss)
        roc_aucs.append(epoch_auc)
        elapsed_time = time.time() - start_time
        elapsed_times.append(elapsed_time)


        scheduler.step(valid_loss)

        if (valid_loss < best_loss):
            best_loss = valid_loss
            best_model_wts = model.state_dict()
            counter = 0
        else:
            counter += 1

        if counter > 3:
            break

        #即時更新圖
        ax1.plot(elapsed_times, train_losses, label="Train Loss", color="blue")
        ax1.plot(elapsed_times, valid_losses, label="Validation Loss", color="orange")

        ax2.plot(elapsed_times, roc_aucs, label="ROC AUC", color="green")

        fig.canvas.draw()
        plt.pause(0.01)

        torch.save(best_model_wts, os.path.join(args.save_path, "val%f_train%f_epoch%d" % (valid_loss, train_loss, epoch)))

    plt.ioff()
    plt.show()
    print("Best Validation Loss:", best_loss)

if __name__ == "__main__":
    """
    Usage
        Download the images data at https://nihcc.app.box.com/v/ChestXray-NIHCC
        To train on the original labels:
            python train.py --save_path run_dir --model densenet --batch_size 8 --horizontal_flip --epochs 10 --lr 0.0001 --train_weighted --valid_weighted --scale 512
        To train on the relabels:
            python train.py --save_path run_dir --model densenet --batch_size 8 --horizontal_flip --epochs 10 --lr 0.0001 --train_weighted --valid_weighted --scale 512 --tag relabeled
    """

    args = argparse.Namespace(
        model="densenet",
        optimizer="adam",
        lr=0.0001,
        weight_decay=0.0,
        drop_rate=0.0,
        epochs=10,
        batch_size=16,
        workers=4,
        seed = 123456,
        tag = "",
        toy = False,
        save_path="drive/MyDrive/ML/history_model/run_dir",  # 提供一個默認的保存路徑
        scale=224,
        horizontal_flip = False,
        verbose = False,
        scratch=False,  # 控制是否從頭開始訓練
        train_weighted=False,  # 是否加權訓練損失
        valid_weighted=False,  # 是否加權驗證損失
        size = None
    )
    """
    parser = get_parser()
    args = parser.parse_args()
    pp = pprint.PrettyPrinter()
    pp.pprint(vars(args))
    """

    if not os.path.isdir(args.save_path):
        os.makedirs(args.save_path)

    with open(os.path.join(args.save_path, "params.txt"), 'w') as out:
        json.dump(vars(args), out, indent=4)
    run(args)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Number of classes: 4
# Epoch 1/10
# ----------
# Epoch: 1 Batch: 0 (16) Train Loss: 0.712077 Time Elapsed: 2.36 seconds
# Epoch: 1 Batch: 1 (16) Train Loss: 0.709542 Time Elapsed: 2.63 seconds
# Epoch: 1 Batch: 2 (16) Train Loss: 0.661596 Time Elapsed: 2.91 seconds
# Epoch: 1 Batch: 3 (16) Train Loss: 0.656508 Time Elapsed: 3.19 seconds
# Epoch: 1 Batch: 4 (16) Train Loss: 0.694326 Time Elapsed: 3.46 seconds
# Epoch: 1 Batch: 5 (16) Train Loss: 0.641940 Time Elapsed: 3.63 seconds
# Epoch: 1 Batch: 6 (16) Train Loss: 0.603161 Time Elapsed: 3.90 seconds
# Epoch: 1 Batch: 7 (16) Train Loss: 0.610870 Time Elapsed: 4.11 seconds
# Epoch: 1 Batch: 8 (16) Train Loss: 0.630292 Time Elapsed: 4.38 seconds
# Epoch: 1 Batch: 9 (16) Train Loss: 0.588591 Time Elapsed: 4.66 seconds
# Epoch: 1 Batch: 10 (16) Train Loss: 0.588649 Time Elapsed: 4.97 seconds
# Epoch: 1 Batch: 11 (16) Train Loss: 0.531221 Time Elapsed: 5.23 seconds
# Epoch: 1 Batch: 12 (16) Train Loss: 0.601215 Time Elapsed: 5.55 seconds
# Epoch: 1 Batch: 13 (16) Train Loss: 0.511184 Time Elapsed: 5.90 seconds
# Epoch: 1 Batch: 14 (16) Train Loss: 0.565591 Time Elapsed: 6.18 seconds
# Epoch: 1 Batch: 15 (16) Train Loss: 0.478419 Time Elapsed: 6.46 seconds
# Epoch: 1 Batch: 16 (16) Train Loss: 0.448386 Time Elapsed: 6.92 seconds
# Epoch: 1 Batch: 17 (16) Train Loss: 0.488812 Time Elapsed: 7.12 seconds
# Epoch: 1 Batch: 18 (16) Train Loss: 0.511654 Time Elapsed: 7.38 seconds
# Epoch: 1 Batch: 19 (16) Train Loss: 0.497225 Time Elapsed: 7.65 seconds
# Epoch: 1 Batch: 20 (16) Train Loss: 0.466300 Time Elapsed: 8.64 seconds
# Epoch: 1 Batch: 21 (16) Train Loss: 0.472475 Time Elapsed: 9.03 seconds
# Epoch: 1 Batch: 22 (16) Train Loss: 0.465542 Time Elapsed: 9.45 seconds
# Epoch: 1 Batch: 23 (16) Train Loss: 0.554853 Time Elapsed: 9.87 seconds
# Epoch: 1 Batch: 24 (16) Train Loss: 0.435103 Time Elapsed: 10.88 seconds
# Epoch: 1 Batch: 25 (16) Train Loss: 0.478214 Time Elapsed: 11.31 seconds
# Epoch: 1 Batch: 26 (16) Train Loss: 0.480645 Time Elapsed: 11.78 seconds
# Epoch: 1 Batch: 27 (16) Train Loss: 0.385040 Time Elapsed: 12.28 seconds
# Epoch: 1 Batch: 28 (16) Train Loss: 0.471348 Time Elapsed: 13.14 seconds
# Epoch: 1 Batch: 29 (16) Train Loss: 0.489818 Time Elapsed: 13.60 seconds
# Epoch: 1 Batch: 30 (16) Train Loss: 0.470442 Time Elapsed: 14.06 seconds
# Epoch: 1 Batch: 31 (16) Train Loss: 0.458978 Time Elapsed: 14.57 seconds
# Epoch: 1 Batch: 32 (16) Train Loss: 0.404934 Time Elapsed: 15.70 seconds
# Epoch: 1 Batch: 33 (16) Train Loss: 0.431534 Time Elapsed: 16.23 seconds
# Epoch: 1 Batch: 34 (16) Train Loss: 0.424971 Time Elapsed: 16.72 seconds
# Epoch: 1 Batch: 35 (16) Train Loss: 0.449642 Time Elapsed: 17.20 seconds
# Epoch: 1 Batch: 36 (16) Train Loss: 0.444555 Time Elapsed: 17.88 seconds
# Epoch: 1 Batch: 37 (16) Train Loss: 0.482018 Time Elapsed: 18.38 seconds
# Epoch: 1 Batch: 38 (16) Train Loss: 0.334301 Time Elapsed: 18.85 seconds
# Epoch: 1 Batch: 39 (16) Train Loss: 0.465364 Time Elapsed: 19.31 seconds
# Epoch: 1 Batch: 40 (16) Train Loss: 0.526921 Time Elapsed: 20.30 seconds
# Epoch: 1 Batch: 41 (16) Train Loss: 0.464827 Time Elapsed: 20.85 seconds
# Epoch: 1 Batch: 42 (16) Train Loss: 0.369539 Time Elapsed: 21.32 seconds
# Epoch: 1 Batch: 43 (16) Train Loss: 0.381437 Time Elapsed: 21.80 seconds
# Epoch: 1 Batch: 44 (16) Train Loss: 0.349296 Time Elapsed: 22.54 seconds
# Epoch: 1 Batch: 45 (16) Train Loss: 0.374379 Time Elapsed: 22.96 seconds
# Epoch: 1 Batch: 46 (16) Train Loss: 0.576735 Time Elapsed: 23.42 seconds
# Epoch: 1 Batch: 47 (16) Train Loss: 0.503315 Time Elapsed: 23.80 seconds
# Epoch: 1 Batch: 48 (16) Train Loss: 0.478474 Time Elapsed: 24.69 seconds
# Epoch: 1 Batch: 49 (16) Train Loss: 0.307964 Time Elapsed: 25.06 seconds
# Epoch: 1 Batch: 50 (16) Train Loss: 0.549797 Time Elapsed: 25.53 seconds
# Epoch: 1 Batch: 51 (16) Train Loss: 0.475189 Time Elapsed: 25.97 seconds
# Epoch: 1 Batch: 52 (16) Train Loss: 0.553677 Time Elapsed: 26.72 seconds
# Epoch: 1 Batch: 53 (16) Train Loss: 0.398924 Time Elapsed: 27.02 seconds
# Epoch: 1 Batch: 54 (16) Train Loss: 0.441015 Time Elapsed: 27.19 seconds
# Epoch: 1 Batch: 55 (16) Train Loss: 0.404928 Time Elapsed: 27.49 seconds
# Epoch: 1 Batch: 56 (16) Train Loss: 0.335719 Time Elapsed: 28.00 seconds
# Epoch: 1 Batch: 57 (16) Train Loss: 0.311852 Time Elapsed: 28.34 seconds
# Epoch: 1 Batch: 58 (16) Train Loss: 0.464268 Time Elapsed: 28.61 seconds
# Epoch: 1 Batch: 59 (16) Train Loss: 0.361953 Time Elapsed: 28.88 seconds
# Epoch: 1 Batch: 60 (16) Train Loss: 0.374157 Time Elapsed: 29.21 seconds
# Epoch: 1 Batch: 61 (16) Train Loss: 0.450478 Time Elapsed: 29.49 seconds
# Epoch: 1 Batch: 62 (16) Train Loss: 0.482407 Time Elapsed: 29.80 seconds
# Epoch: 1 Batch: 63 (16) Train Loss: 0.309622 Time Elapsed: 30.08 seconds
# Epoch: 1 Batch: 64 (16) Train Loss: 0.344694 Time Elapsed: 30.57 seconds
# Epoch: 1 Batch: 65 (16) Train Loss: 0.389706 Time Elapsed: 30.80 seconds
# Epoch: 1 Batch: 66 (16) Train Loss: 0.410411 Time Elapsed: 31.10 seconds
# Epoch: 1 Batch: 67 (16) Train Loss: 0.341613 Time Elapsed: 31.47 seconds
# Epoch: 1 Batch: 68 (16) Train Loss: 0.351701 Time Elapsed: 31.77 seconds
# Epoch: 1 Batch: 69 (16) Train Loss: 0.353010 Time Elapsed: 32.07 seconds
# Epoch: 1 Batch: 70 (16) Train Loss: 0.563248 Time Elapsed: 32.53 seconds
# Epoch: 1 Batch: 71 (16) Train Loss: 0.393115 Time Elapsed: 32.94 seconds
# Epoch: 1 Batch: 72 (16) Train Loss: 0.382387 Time Elapsed: 33.59 seconds
# Epoch: 1 Batch: 73 (16) Train Loss: 0.390308 Time Elapsed: 34.04 seconds
# Epoch: 1 Batch: 74 (16) Train Loss: 0.472903 Time Elapsed: 34.62 seconds
# Epoch: 1 Batch: 75 (16) Train Loss: 0.310489 Time Elapsed: 34.99 seconds
# Epoch: 1 Batch: 76 (16) Train Loss: 0.435652 Time Elapsed: 35.72 seconds
# Epoch: 1 Batch: 77 (16) Train Loss: 0.455528 Time Elapsed: 36.13 seconds
# Epoch: 1 Batch: 78 (16) Train Loss: 0.380166 Time Elapsed: 36.75 seconds
# Epoch: 1 Batch: 79 (16) Train Loss: 0.444884 Time Elapsed: 37.19 seconds
# Epoch: 1 Batch: 80 (16) Train Loss: 0.549399 Time Elapsed: 37.80 seconds
# Epoch: 1 Batch: 81 (16) Train Loss: 0.307569 Time Elapsed: 38.16 seconds
# Epoch: 1 Batch: 82 (16) Train Loss: 0.454534 Time Elapsed: 38.90 seconds
# Epoch: 1 Batch: 83 (16) Train Loss: 0.388741 Time Elapsed: 39.34 seconds
# Epoch: 1 Batch: 84 (16) Train Loss: 0.411690 Time Elapsed: 39.89 seconds
# Epoch: 1 Batch: 85 (16) Train Loss: 0.405560 Time Elapsed: 40.38 seconds
# Epoch: 1 Batch: 86 (16) Train Loss: 0.379553 Time Elapsed: 41.01 seconds
# Epoch: 1 Batch: 87 (16) Train Loss: 0.406892 Time Elapsed: 41.50 seconds
# Epoch: 1 Batch: 88 (16) Train Loss: 0.415395 Time Elapsed: 42.05 seconds
# Epoch: 1 Batch: 89 (16) Train Loss: 0.338153 Time Elapsed: 42.48 seconds
# Epoch: 1 Batch: 90 (16) Train Loss: 0.251991 Time Elapsed: 42.89 seconds
# Epoch: 1 Batch: 91 (16) Train Loss: 0.284390 Time Elapsed: 43.15 seconds
# Epoch: 1 Batch: 92 (16) Train Loss: 0.275998 Time Elapsed: 43.50 seconds
# Epoch: 1 Batch: 93 (16) Train Loss: 0.343837 Time Elapsed: 43.73 seconds
# Epoch: 1 Batch: 94 (16) Train Loss: 0.368675 Time Elapsed: 44.21 seconds
# Epoch: 1 Batch: 95 (16) Train Loss: 0.489552 Time Elapsed: 44.50 seconds
# Epoch: 1 Batch: 96 (16) Train Loss: 0.260831 Time Elapsed: 44.87 seconds
# Epoch: 1 Batch: 97 (16) Train Loss: 0.339839 Time Elapsed: 45.21 seconds
# Epoch: 1 Batch: 98 (16) Train Loss: 0.539181 Time Elapsed: 45.43 seconds
# Epoch: 1 Batch: 99 (16) Train Loss: 0.323625 Time Elapsed: 45.71 seconds
# Epoch: 1 Batch: 100 (16) Train Loss: 0.489941 Time Elapsed: 46.11 seconds
# Epoch: 1 Batch: 101 (16) Train Loss: 0.278611 Time Elapsed: 46.42 seconds
# Epoch: 1 Batch: 102 (16) Train Loss: 0.333698 Time Elapsed: 46.81 seconds
# Epoch: 1 Batch: 103 (16) Train Loss: 0.418964 Time Elapsed: 47.06 seconds
# Epoch: 1 Batch: 104 (16) Train Loss: 0.389707 Time Elapsed: 47.40 seconds
# Epoch: 1 Batch: 105 (16) Train Loss: 0.373253 Time Elapsed: 47.65 seconds
# Epoch: 1 Batch: 106 (16) Train Loss: 0.432188 Time Elapsed: 48.17 seconds
# Epoch: 1 Batch: 107 (16) Train Loss: 0.338952 Time Elapsed: 48.46 seconds
# Epoch: 1 Batch: 108 (16) Train Loss: 0.334777 Time Elapsed: 48.72 seconds
# Epoch: 1 Batch: 109 (16) Train Loss: 0.326900 Time Elapsed: 49.01 seconds
# Epoch: 1 Batch: 110 (16) Train Loss: 0.368009 Time Elapsed: 49.38 seconds
# Epoch: 1 Batch: 111 (16) Train Loss: 0.498070 Time Elapsed: 49.63 seconds
# Epoch: 1 Batch: 112 (16) Train Loss: 0.453013 Time Elapsed: 49.97 seconds
# Epoch: 1 Batch: 113 (16) Train Loss: 0.356757 Time Elapsed: 50.23 seconds
# Epoch: 1 Batch: 114 (16) Train Loss: 0.406254 Time Elapsed: 50.65 seconds
# Epoch: 1 Batch: 115 (16) Train Loss: 0.385301 Time Elapsed: 50.91 seconds
# Epoch: 1 Batch: 116 (16) Train Loss: 0.493278 Time Elapsed: 51.31 seconds
# Epoch: 1 Batch: 117 (16) Train Loss: 0.403483 Time Elapsed: 51.60 seconds
# Epoch: 1 Batch: 118 (16) Train Loss: 0.247186 Time Elapsed: 51.92 seconds
# Epoch: 1 Batch: 119 (16) Train Loss: 0.510576 Time Elapsed: 52.23 seconds
# Epoch: 1 Batch: 120 (16) Train Loss: 0.378496 Time Elapsed: 52.53 seconds
# Epoch: 1 Batch: 121 (16) Train Loss: 0.385012 Time Elapsed: 52.91 seconds
# Epoch: 1 Batch: 122 (16) Train Loss: 0.279289 Time Elapsed: 53.27 seconds
# Epoch: 1 Batch: 123 (16) Train Loss: 0.323362 Time Elapsed: 53.64 seconds
# Epoch: 1 Batch: 124 (16) Train Loss: 0.388209 Time Elapsed: 54.66 seconds
# Epoch: 1 Batch: 125 (16) Train Loss: 0.287179 Time Elapsed: 55.07 seconds
# Epoch: 1 Batch: 126 (16) Train Loss: 0.309295 Time Elapsed: 55.53 seconds
# Epoch: 1 Batch: 127 (16) Train Loss: 0.438255 Time Elapsed: 55.96 seconds
# Epoch: 1 Batch: 128 (16) Train Loss: 0.512483 Time Elapsed: 56.76 seconds
# Epoch: 1 Batch: 129 (16) Train Loss: 0.340830 Time Elapsed: 57.23 seconds
# Epoch: 1 Batch: 130 (16) Train Loss: 0.470903 Time Elapsed: 57.70 seconds
# Epoch: 1 Batch: 131 (16) Train Loss: 0.391194 Time Elapsed: 58.16 seconds
# Epoch: 1 Batch: 132 (16) Train Loss: 0.405266 Time Elapsed: 59.00 seconds
# Epoch: 1 Batch: 133 (16) Train Loss: 0.347507 Time Elapsed: 59.38 seconds
# Epoch: 1 Batch: 134 (16) Train Loss: 0.438904 Time Elapsed: 59.96 seconds
# Epoch: 1 Batch: 135 (16) Train Loss: 0.252790 Time Elapsed: 60.30 seconds
# Epoch: 1 Batch: 136 (16) Train Loss: 0.188543 Time Elapsed: 61.36 seconds
# Epoch: 1 Batch: 137 (16) Train Loss: 0.396508 Time Elapsed: 61.82 seconds
# Epoch: 1 Batch: 138 (16) Train Loss: 0.239913 Time Elapsed: 62.32 seconds
# Epoch: 1 Batch: 139 (16) Train Loss: 0.311311 Time Elapsed: 62.75 seconds
# Epoch: 1 Batch: 140 (16) Train Loss: 0.406014 Time Elapsed: 63.27 seconds
# Epoch: 1 Batch: 141 (16) Train Loss: 0.466683 Time Elapsed: 63.53 seconds
# Epoch: 1 Batch: 142 (16) Train Loss: 0.366944 Time Elapsed: 63.79 seconds
# Epoch: 1 Batch: 143 (16) Train Loss: 0.510388 Time Elapsed: 64.04 seconds
# Epoch: 1 Batch: 144 (16) Train Loss: 0.235318 Time Elapsed: 64.63 seconds
# Epoch: 1 Batch: 145 (16) Train Loss: 0.347070 Time Elapsed: 64.90 seconds
# Epoch: 1 Batch: 146 (16) Train Loss: 0.534650 Time Elapsed: 65.15 seconds
# Epoch: 1 Batch: 147 (16) Train Loss: 0.271083 Time Elapsed: 65.38 seconds
# Epoch: 1 Batch: 148 (16) Train Loss: 0.440943 Time Elapsed: 65.82 seconds
# Epoch: 1 Batch: 149 (16) Train Loss: 0.319558 Time Elapsed: 66.12 seconds
# Epoch: 1 Batch: 150 (16) Train Loss: 0.408139 Time Elapsed: 66.42 seconds
# Epoch: 1 Batch: 151 (16) Train Loss: 0.357850 Time Elapsed: 66.67 seconds
# Epoch: 1 Batch: 152 (16) Train Loss: 0.310322 Time Elapsed: 67.17 seconds
# Epoch: 1 Batch: 153 (16) Train Loss: 0.510154 Time Elapsed: 67.45 seconds
# Epoch: 1 Batch: 154 (16) Train Loss: 0.184665 Time Elapsed: 67.72 seconds
# Epoch: 1 Batch: 155 (16) Train Loss: 0.390002 Time Elapsed: 68.00 seconds
# Epoch: 1 Batch: 156 (16) Train Loss: 0.366636 Time Elapsed: 68.44 seconds
# Epoch: 1 Batch: 157 (16) Train Loss: 0.282462 Time Elapsed: 68.75 seconds
# Epoch: 1 Batch: 158 (16) Train Loss: 0.364811 Time Elapsed: 68.97 seconds
# Epoch: 1 Batch: 159 (16) Train Loss: 0.412468 Time Elapsed: 69.23 seconds
# Epoch: 1 Batch: 160 (16) Train Loss: 0.290063 Time Elapsed: 69.65 seconds
# Epoch: 1 Batch: 161 (16) Train Loss: 0.393890 Time Elapsed: 69.85 seconds
# Epoch: 1 Batch: 162 (16) Train Loss: 0.270200 Time Elapsed: 70.17 seconds
# Epoch: 1 Batch: 163 (16) Train Loss: 0.225898 Time Elapsed: 70.45 seconds
# Epoch: 1 Batch: 164 (16) Train Loss: 0.445207 Time Elapsed: 70.88 seconds
# Epoch: 1 Batch: 165 (16) Train Loss: 0.420906 Time Elapsed: 71.12 seconds
# Epoch: 1 Batch: 166 (16) Train Loss: 0.359736 Time Elapsed: 71.44 seconds
# Epoch: 1 Batch: 167 (16) Train Loss: 0.322275 Time Elapsed: 71.68 seconds
# Epoch: 1 Batch: 168 (16) Train Loss: 0.504953 Time Elapsed: 72.05 seconds
# Epoch: 1 Batch: 169 (16) Train Loss: 0.269002 Time Elapsed: 72.30 seconds
# Epoch: 1 Batch: 170 (16) Train Loss: 0.402098 Time Elapsed: 72.63 seconds
# Epoch: 1 Batch: 171 (16) Train Loss: 0.223743 Time Elapsed: 72.94 seconds
# Epoch: 1 Batch: 172 (16) Train Loss: 0.320352 Time Elapsed: 73.58 seconds
# Epoch: 1 Batch: 173 (16) Train Loss: 0.325932 Time Elapsed: 73.96 seconds
# Epoch: 1 Batch: 174 (16) Train Loss: 0.441878 Time Elapsed: 74.35 seconds
# Epoch: 1 Batch: 175 (16) Train Loss: 0.418428 Time Elapsed: 74.77 seconds
# Epoch: 1 Batch: 176 (16) Train Loss: 0.413144 Time Elapsed: 75.50 seconds
# Epoch: 1 Batch: 177 (16) Train Loss: 0.407203 Time Elapsed: 75.97 seconds
# Epoch: 1 Batch: 178 (16) Train Loss: 0.198768 Time Elapsed: 76.35 seconds
# Epoch: 1 Batch: 179 (16) Train Loss: 0.427528 Time Elapsed: 76.73 seconds
# Epoch: 1 Batch: 180 (16) Train Loss: 0.306328 Time Elapsed: 77.69 seconds
# Epoch: 1 Batch: 181 (16) Train Loss: 0.316681 Time Elapsed: 78.17 seconds
# Epoch: 1 Batch: 182 (16) Train Loss: 0.312972 Time Elapsed: 78.63 seconds
# Epoch: 1 Batch: 183 (16) Train Loss: 0.355917 Time Elapsed: 79.05 seconds
# Epoch: 1 Batch: 184 (16) Train Loss: 0.433130 Time Elapsed: 79.88 seconds
# Epoch: 1 Batch: 185 (16) Train Loss: 0.311874 Time Elapsed: 80.40 seconds
# Epoch: 1 Batch: 186 (16) Train Loss: 0.454323 Time Elapsed: 80.85 seconds
# Epoch: 1 Batch: 187 (16) Train Loss: 0.421186 Time Elapsed: 81.26 seconds
# Epoch: 1 Batch: 188 (16) Train Loss: 0.368503 Time Elapsed: 82.11 seconds
# Epoch: 1 Batch: 189 (16) Train Loss: 0.308478 Time Elapsed: 82.59 seconds
# Epoch: 1 Batch: 190 (16) Train Loss: 0.247036 Time Elapsed: 83.07 seconds
# Epoch: 1 Batch: 191 (16) Train Loss: 0.409925 Time Elapsed: 83.54 seconds
# Epoch: 1 Batch: 192 (16) Train Loss: 0.355590 Time Elapsed: 84.09 seconds
# Epoch: 1 Batch: 193 (16) Train Loss: 0.379566 Time Elapsed: 84.40 seconds
# Epoch: 1 Batch: 194 (16) Train Loss: 0.404276 Time Elapsed: 84.67 seconds
# Epoch: 1 Batch: 195 (16) Train Loss: 0.432063 Time Elapsed: 84.97 seconds
# Epoch: 1 Batch: 196 (16) Train Loss: 0.299770 Time Elapsed: 85.36 seconds
# Epoch: 1 Batch: 197 (16) Train Loss: 0.276828 Time Elapsed: 85.62 seconds
# Epoch: 1 Batch: 198 (16) Train Loss: 0.338215 Time Elapsed: 85.90 seconds
# Epoch: 1 Batch: 199 (16) Train Loss: 0.347041 Time Elapsed: 86.17 seconds
# Epoch: 1 Batch: 200 (16) Train Loss: 0.328080 Time Elapsed: 86.61 seconds
# Epoch: 1 Batch: 201 (16) Train Loss: 0.436689 Time Elapsed: 86.86 seconds
# Epoch: 1 Batch: 202 (16) Train Loss: 0.360746 Time Elapsed: 87.11 seconds
# Epoch: 1 Batch: 203 (16) Train Loss: 0.290908 Time Elapsed: 87.41 seconds
# Epoch: 1 Batch: 204 (16) Train Loss: 0.451914 Time Elapsed: 87.88 seconds
# Epoch: 1 Batch: 205 (16) Train Loss: 0.313212 Time Elapsed: 88.14 seconds
# Epoch: 1 Batch: 206 (16) Train Loss: 0.496099 Time Elapsed: 88.39 seconds
# Epoch: 1 Batch: 207 (16) Train Loss: 0.280992 Time Elapsed: 88.67 seconds
# Epoch: 1 Batch: 208 (16) Train Loss: 0.256314 Time Elapsed: 89.11 seconds
# Epoch: 1 Batch: 209 (16) Train Loss: 0.330866 Time Elapsed: 89.46 seconds
# Epoch: 1 Batch: 210 (16) Train Loss: 0.399500 Time Elapsed: 89.72 seconds
# Epoch: 1 Batch: 211 (16) Train Loss: 0.361494 Time Elapsed: 89.99 seconds
# Epoch: 1 Batch: 212 (16) Train Loss: 0.327209 Time Elapsed: 90.37 seconds
# Epoch: 1 Batch: 213 (16) Train Loss: 0.350500 Time Elapsed: 90.63 seconds
# Epoch: 1 Batch: 214 (16) Train Loss: 0.361351 Time Elapsed: 90.90 seconds
# Epoch: 1 Batch: 215 (16) Train Loss: 0.402714 Time Elapsed: 91.21 seconds
# Epoch: 1 Batch: 216 (16) Train Loss: 0.467756 Time Elapsed: 91.68 seconds
# Epoch: 1 Batch: 217 (16) Train Loss: 0.308025 Time Elapsed: 91.94 seconds
# Epoch: 1 Batch: 218 (16) Train Loss: 0.393907 Time Elapsed: 92.19 seconds
# Epoch: 1 Batch: 219 (16) Train Loss: 0.330572 Time Elapsed: 92.46 seconds
# Epoch: 1 Batch: 220 (16) Train Loss: 0.268836 Time Elapsed: 92.89 seconds
# Epoch: 1 Batch: 221 (16) Train Loss: 0.286447 Time Elapsed: 93.16 seconds
# Epoch: 1 Batch: 222 (16) Train Loss: 0.432034 Time Elapsed: 93.37 seconds
# Epoch: 1 Batch: 223 (16) Train Loss: 0.457843 Time Elapsed: 93.71 seconds
# Epoch: 1 Batch: 224 (16) Train Loss: 0.204510 Time Elapsed: 94.30 seconds
# Epoch: 1 Batch: 225 (16) Train Loss: 0.372116 Time Elapsed: 94.83 seconds
# Epoch: 1 Batch: 226 (16) Train Loss: 0.341033 Time Elapsed: 95.23 seconds
# Epoch: 1 Batch: 227 (16) Train Loss: 0.296289 Time Elapsed: 95.76 seconds
# Epoch: 1 Batch: 228 (16) Train Loss: 0.543679 Time Elapsed: 96.52 seconds
# Epoch: 1 Batch: 229 (16) Train Loss: 0.487831 Time Elapsed: 96.91 seconds
# Epoch: 1 Batch: 230 (16) Train Loss: 0.268020 Time Elapsed: 97.27 seconds
# Epoch: 1 Batch: 231 (16) Train Loss: 0.363358 Time Elapsed: 97.89 seconds
# Epoch: 1 Batch: 232 (16) Train Loss: 0.392321 Time Elapsed: 98.46 seconds
# Epoch: 1 Batch: 233 (16) Train Loss: 0.255658 Time Elapsed: 98.94 seconds
# Epoch: 1 Batch: 234 (16) Train Loss: 0.349812 Time Elapsed: 99.35 seconds
# Epoch: 1 Batch: 235 (16) Train Loss: 0.288500 Time Elapsed: 100.17 seconds
# Epoch: 1 Batch: 236 (16) Train Loss: 0.343758 Time Elapsed: 100.75 seconds
# Epoch: 1 Batch: 237 (16) Train Loss: 0.399122 Time Elapsed: 101.20 seconds
# Epoch: 1 Batch: 238 (16) Train Loss: 0.412290 Time Elapsed: 101.56 seconds
# Epoch: 1 Batch: 239 (16) Train Loss: 0.371049 Time Elapsed: 102.45 seconds
# Epoch: 1 Batch: 240 (16) Train Loss: 0.339323 Time Elapsed: 103.01 seconds
# Epoch: 1 Batch: 241 (16) Train Loss: 0.437107 Time Elapsed: 103.48 seconds
# Epoch: 1 Batch: 242 (16) Train Loss: 0.372648 Time Elapsed: 103.93 seconds
# Epoch: 1 Batch: 243 (16) Train Loss: 0.319757 Time Elapsed: 104.33 seconds
# Epoch: 1 Batch: 244 (16) Train Loss: 0.285497 Time Elapsed: 104.78 seconds
# Epoch: 1 Batch: 245 (16) Train Loss: 0.292787 Time Elapsed: 105.06 seconds
# Epoch: 1 Batch: 246 (16) Train Loss: 0.283570 Time Elapsed: 105.29 seconds
# Epoch: 1 Batch: 247 (16) Train Loss: 0.390913 Time Elapsed: 105.60 seconds
# Epoch: 1 Batch: 248 (16) Train Loss: 0.347994 Time Elapsed: 106.13 seconds
# Epoch: 1 Batch: 249 (16) Train Loss: 0.333660 Time Elapsed: 106.44 seconds
# Epoch: 1 Batch: 250 (16) Train Loss: 0.436841 Time Elapsed: 106.70 seconds
# Epoch: 1 Batch: 251 (16) Train Loss: 0.231213 Time Elapsed: 107.02 seconds
# Epoch: 1 Batch: 252 (16) Train Loss: 0.346369 Time Elapsed: 107.35 seconds
# Epoch: 1 Batch: 253 (16) Train Loss: 0.465713 Time Elapsed: 107.63 seconds
# Epoch: 1 Batch: 254 (16) Train Loss: 0.324304 Time Elapsed: 107.91 seconds
# Epoch: 1 Batch: 255 (16) Train Loss: 0.454631 Time Elapsed: 108.19 seconds
# Epoch: 1 Batch: 256 (16) Train Loss: 0.270433 Time Elapsed: 108.62 seconds
# Epoch: 1 Batch: 257 (16) Train Loss: 0.364633 Time Elapsed: 108.88 seconds
# Epoch: 1 Batch: 258 (16) Train Loss: 0.288138 Time Elapsed: 109.19 seconds
# Epoch: 1 Batch: 259 (16) Train Loss: 0.391570 Time Elapsed: 109.46 seconds
# Epoch: 1 Batch: 260 (16) Train Loss: 0.427925 Time Elapsed: 109.95 seconds
# Epoch: 1 Batch: 261 (16) Train Loss: 0.310907 Time Elapsed: 110.28 seconds
# Epoch: 1 Batch: 262 (16) Train Loss: 0.247996 Time Elapsed: 110.52 seconds
# Epoch: 1 Batch: 263 (16) Train Loss: 0.261879 Time Elapsed: 110.73 seconds
# Epoch: 1 Batch: 264 (16) Train Loss: 0.328390 Time Elapsed: 111.33 seconds
# Epoch: 1 Batch: 265 (16) Train Loss: 0.331206 Time Elapsed: 111.61 seconds
# Epoch: 1 Batch: 266 (16) Train Loss: 0.338938 Time Elapsed: 111.87 seconds
# Epoch: 1 Batch: 267 (16) Train Loss: 0.239480 Time Elapsed: 112.09 seconds
# Epoch: 1 Batch: 268 (16) Train Loss: 0.377317 Time Elapsed: 112.54 seconds
# Epoch: 1 Batch: 269 (16) Train Loss: 0.383723 Time Elapsed: 112.70 seconds
# Epoch: 1 Batch: 270 (16) Train Loss: 0.391937 Time Elapsed: 112.92 seconds
# Epoch: 1 Batch: 271 (16) Train Loss: 0.383031 Time Elapsed: 113.17 seconds
# Epoch: 1 Batch: 272 (16) Train Loss: 0.381819 Time Elapsed: 113.77 seconds
# Epoch: 1 Batch: 273 (16) Train Loss: 0.252698 Time Elapsed: 114.01 seconds
# Epoch: 1 Batch: 274 (16) Train Loss: 0.286687 Time Elapsed: 114.31 seconds
# Epoch: 1 Batch: 275 (16) Train Loss: 0.348912 Time Elapsed: 114.72 seconds
# Epoch: 1 Batch: 276 (16) Train Loss: 0.374280 Time Elapsed: 115.59 seconds
# Epoch: 1 Batch: 277 (16) Train Loss: 0.221493 Time Elapsed: 116.10 seconds
# Epoch: 1 Batch: 278 (16) Train Loss: 0.324936 Time Elapsed: 116.45 seconds
# Epoch: 1 Batch: 279 (16) Train Loss: 0.164438 Time Elapsed: 116.88 seconds
# Epoch: 1 Batch: 280 (16) Train Loss: 0.290446 Time Elapsed: 117.81 seconds
# Epoch: 1 Batch: 281 (16) Train Loss: 0.313103 Time Elapsed: 118.22 seconds
# Epoch: 1 Batch: 282 (16) Train Loss: 0.311074 Time Elapsed: 118.69 seconds
# Epoch: 1 Batch: 283 (16) Train Loss: 0.402210 Time Elapsed: 119.13 seconds
# Epoch: 1 Batch: 284 (16) Train Loss: 0.261186 Time Elapsed: 120.02 seconds
# Epoch: 1 Batch: 285 (16) Train Loss: 0.386053 Time Elapsed: 120.50 seconds
# Epoch: 1 Batch: 286 (16) Train Loss: 0.233967 Time Elapsed: 120.92 seconds
# Epoch: 1 Batch: 287 (16) Train Loss: 0.413507 Time Elapsed: 121.38 seconds
# Epoch: 1 Batch: 288 (16) Train Loss: 0.353443 Time Elapsed: 122.32 seconds
# Epoch: 1 Batch: 289 (16) Train Loss: 0.390651 Time Elapsed: 122.79 seconds
# Epoch: 1 Batch: 290 (16) Train Loss: 0.459330 Time Elapsed: 123.29 seconds
# Epoch: 1 Batch: 291 (16) Train Loss: 0.426301 Time Elapsed: 123.79 seconds
# Epoch: 1 Batch: 292 (16) Train Loss: 0.389285 Time Elapsed: 124.46 seconds
# Epoch: 1 Batch: 293 (16) Train Loss: 0.274662 Time Elapsed: 124.80 seconds
# Epoch: 1 Batch: 294 (16) Train Loss: 0.477900 Time Elapsed: 125.04 seconds
# Epoch: 1 Batch: 295 (16) Train Loss: 0.438851 Time Elapsed: 125.35 seconds
# Epoch: 1 Batch: 296 (16) Train Loss: 0.296008 Time Elapsed: 125.76 seconds
# Epoch: 1 Batch: 297 (16) Train Loss: 0.546346 Time Elapsed: 126.02 seconds
# Epoch: 1 Batch: 298 (16) Train Loss: 0.387680 Time Elapsed: 126.32 seconds
# Epoch: 1 Batch: 299 (16) Train Loss: 0.417755 Time Elapsed: 126.60 seconds
# Epoch: 1 Batch: 300 (16) Train Loss: 0.263246 Time Elapsed: 126.98 seconds
# Epoch: 1 Batch: 301 (16) Train Loss: 0.376556 Time Elapsed: 127.23 seconds
# Epoch: 1 Batch: 302 (16) Train Loss: 0.433814 Time Elapsed: 127.49 seconds
# Epoch: 1 Batch: 303 (16) Train Loss: 0.289860 Time Elapsed: 127.66 seconds
# Epoch: 1 Batch: 304 (16) Train Loss: 0.481508 Time Elapsed: 128.34 seconds
# Epoch: 1 Batch: 305 (16) Train Loss: 0.302265 Time Elapsed: 128.57 seconds
# Epoch: 1 Batch: 306 (16) Train Loss: 0.534436 Time Elapsed: 128.88 seconds
# Epoch: 1 Batch: 307 (16) Train Loss: 0.409161 Time Elapsed: 129.17 seconds
# Epoch: 1 Batch: 308 (16) Train Loss: 0.432386 Time Elapsed: 129.51 seconds
# Epoch: 1 Batch: 309 (16) Train Loss: 0.327834 Time Elapsed: 129.84 seconds
# Epoch: 1 Batch: 310 (16) Train Loss: 0.408912 Time Elapsed: 130.06 seconds
# Epoch: 1 Batch: 311 (16) Train Loss: 0.414055 Time Elapsed: 130.41 seconds
# Epoch: 1 Batch: 312 (16) Train Loss: 0.374803 Time Elapsed: 130.75 seconds
# Epoch: 1 Batch: 313 (16) Train Loss: 0.405497 Time Elapsed: 131.04 seconds
# Epoch: 1 Batch: 314 (16) Train Loss: 0.231276 Time Elapsed: 131.31 seconds
# Epoch: 1 Batch: 315 (16) Train Loss: 0.408861 Time Elapsed: 131.65 seconds
# Epoch: 1 Batch: 316 (16) Train Loss: 0.325441 Time Elapsed: 131.96 seconds
# Epoch: 1 Batch: 317 (16) Train Loss: 0.331556 Time Elapsed: 132.25 seconds
# Epoch: 1 Batch: 318 (16) Train Loss: 0.266629 Time Elapsed: 132.43 seconds
# Epoch: 1 Batch: 319 (16) Train Loss: 0.219587 Time Elapsed: 132.88 seconds
# Epoch: 1 Batch: 320 (16) Train Loss: 0.345747 Time Elapsed: 133.26 seconds
# Epoch: 1 Batch: 321 (16) Train Loss: 0.353352 Time Elapsed: 133.58 seconds
# Epoch: 1 Batch: 322 (16) Train Loss: 0.358734 Time Elapsed: 133.83 seconds
# Epoch: 1 Batch: 323 (16) Train Loss: 0.433080 Time Elapsed: 134.11 seconds
# Epoch: 1 Batch: 324 (16) Train Loss: 0.368894 Time Elapsed: 134.61 seconds
# Epoch: 1 Batch: 325 (16) Train Loss: 0.310142 Time Elapsed: 135.08 seconds
# Epoch: 1 Batch: 326 (16) Train Loss: 0.344560 Time Elapsed: 135.48 seconds
# Epoch: 1 Batch: 327 (16) Train Loss: 0.332534 Time Elapsed: 135.90 seconds
# Epoch: 1 Batch: 328 (16) Train Loss: 0.362353 Time Elapsed: 136.59 seconds
# Epoch: 1 Batch: 329 (16) Train Loss: 0.453342 Time Elapsed: 137.00 seconds
# Epoch: 1 Batch: 330 (16) Train Loss: 0.398086 Time Elapsed: 137.45 seconds
# Epoch: 1 Batch: 331 (16) Train Loss: 0.446788 Time Elapsed: 137.85 seconds
# Epoch: 1 Batch: 332 (16) Train Loss: 0.435467 Time Elapsed: 138.58 seconds
# Epoch: 1 Batch: 333 (16) Train Loss: 0.332994 Time Elapsed: 139.04 seconds
# Epoch: 1 Batch: 334 (16) Train Loss: 0.467067 Time Elapsed: 139.70 seconds
# Epoch: 1 Batch: 335 (16) Train Loss: 0.330857 Time Elapsed: 140.15 seconds
# Epoch: 1 Batch: 336 (16) Train Loss: 0.397068 Time Elapsed: 141.00 seconds
# Epoch: 1 Batch: 337 (16) Train Loss: 0.409740 Time Elapsed: 141.47 seconds
# Epoch: 1 Batch: 338 (16) Train Loss: 0.358075 Time Elapsed: 142.00 seconds
# Epoch: 1 Batch: 339 (16) Train Loss: 0.583259 Time Elapsed: 142.44 seconds
# Epoch: 1 Batch: 340 (16) Train Loss: 0.262562 Time Elapsed: 143.10 seconds
# Epoch: 1 Batch: 341 (16) Train Loss: 0.360189 Time Elapsed: 143.50 seconds
# Epoch: 1 Batch: 342 (16) Train Loss: 0.394423 Time Elapsed: 144.26 seconds
# Epoch: 1 Batch: 343 (16) Train Loss: 0.493406 Time Elapsed: 144.71 seconds
# Epoch: 1 Batch: 344 (16) Train Loss: 0.256612 Time Elapsed: 145.34 seconds
# Epoch: 1 Batch: 345 (16) Train Loss: 0.520581 Time Elapsed: 145.57 seconds
# Epoch: 1 Batch: 346 (16) Train Loss: 0.262054 Time Elapsed: 146.08 seconds
# Epoch: 1 Batch: 347 (16) Train Loss: 0.492414 Time Elapsed: 146.39 seconds
# Epoch: 1 Batch: 348 (16) Train Loss: 0.356803 Time Elapsed: 146.67 seconds
# Epoch: 1 Batch: 349 (16) Train Loss: 0.329542 Time Elapsed: 146.96 seconds
# Epoch: 1 Batch: 350 (16) Train Loss: 0.239190 Time Elapsed: 147.38 seconds
# Epoch: 1 Batch: 351 (16) Train Loss: 0.342690 Time Elapsed: 147.61 seconds
# Epoch: 1 Batch: 352 (16) Train Loss: 0.293294 Time Elapsed: 147.91 seconds
# Epoch: 1 Batch: 353 (16) Train Loss: 0.290065 Time Elapsed: 148.19 seconds
# Epoch: 1 Batch: 354 (16) Train Loss: 0.366290 Time Elapsed: 148.61 seconds
# Epoch: 1 Batch: 355 (16) Train Loss: 0.449656 Time Elapsed: 148.92 seconds
# Epoch: 1 Batch: 356 (16) Train Loss: 0.327373 Time Elapsed: 149.12 seconds
# Epoch: 1 Batch: 357 (16) Train Loss: 0.444036 Time Elapsed: 149.43 seconds
# Epoch: 1 Batch: 358 (16) Train Loss: 0.358580 Time Elapsed: 150.01 seconds
# Epoch: 1 Batch: 359 (16) Train Loss: 0.555543 Time Elapsed: 150.29 seconds
# Epoch: 1 Batch: 360 (16) Train Loss: 0.465683 Time Elapsed: 150.61 seconds
# Epoch: 1 Batch: 361 (16) Train Loss: 0.345529 Time Elapsed: 150.90 seconds
# Epoch: 1 Batch: 362 (16) Train Loss: 0.452585 Time Elapsed: 151.19 seconds
# Epoch: 1 Batch: 363 (16) Train Loss: 0.317062 Time Elapsed: 151.46 seconds
# Epoch: 1 Batch: 364 (16) Train Loss: 0.329245 Time Elapsed: 151.69 seconds
# Epoch: 1 Batch: 365 (16) Train Loss: 0.376721 Time Elapsed: 152.00 seconds
# Epoch: 1 Batch: 366 (16) Train Loss: 0.255534 Time Elapsed: 152.50 seconds
# Epoch: 1 Batch: 367 (16) Train Loss: 0.408103 Time Elapsed: 152.75 seconds
# Epoch: 1 Batch: 368 (16) Train Loss: 0.506766 Time Elapsed: 153.05 seconds
# Epoch: 1 Batch: 369 (16) Train Loss: 0.483939 Time Elapsed: 153.31 seconds
# Epoch: 1 Batch: 370 (16) Train Loss: 0.328942 Time Elapsed: 153.77 seconds
# Epoch: 1 Batch: 371 (16) Train Loss: 0.227465 Time Elapsed: 154.00 seconds
# Epoch: 1 Batch: 372 (16) Train Loss: 0.391917 Time Elapsed: 154.26 seconds
# Epoch: 1 Batch: 373 (16) Train Loss: 0.390968 Time Elapsed: 154.52 seconds
# Epoch: 1 Batch: 374 (16) Train Loss: 0.430793 Time Elapsed: 154.92 seconds
# Epoch: 1 Batch: 375 (16) Train Loss: 0.432698 Time Elapsed: 155.23 seconds
# Epoch: 1 Batch: 376 (16) Train Loss: 0.317271 Time Elapsed: 155.64 seconds
# Epoch: 1 Batch: 377 (16) Train Loss: 0.373194 Time Elapsed: 156.07 seconds
# Epoch: 1 Batch: 378 (16) Train Loss: 0.280328 Time Elapsed: 156.92 seconds
# Epoch: 1 Batch: 379 (16) Train Loss: 0.334266 Time Elapsed: 157.33 seconds
# Epoch: 1 Batch: 380 (16) Train Loss: 0.373887 Time Elapsed: 157.78 seconds
# Epoch: 1 Batch: 381 (16) Train Loss: 0.185370 Time Elapsed: 158.23 seconds
# Epoch: 1 Batch: 382 (16) Train Loss: 0.500126 Time Elapsed: 159.11 seconds
# Epoch: 1 Batch: 383 (16) Train Loss: 0.386691 Time Elapsed: 159.57 seconds
# Epoch: 1 Batch: 384 (16) Train Loss: 0.315813 Time Elapsed: 160.06 seconds
# Epoch: 1 Batch: 385 (16) Train Loss: 0.309869 Time Elapsed: 160.49 seconds
# Epoch: 1 Batch: 386 (16) Train Loss: 0.381300 Time Elapsed: 161.49 seconds
# Epoch: 1 Batch: 387 (16) Train Loss: 0.474538 Time Elapsed: 161.94 seconds
# Epoch: 1 Batch: 388 (16) Train Loss: 0.247798 Time Elapsed: 162.39 seconds
# Epoch: 1 Batch: 389 (16) Train Loss: 0.371081 Time Elapsed: 162.88 seconds
# Epoch: 1 Batch: 390 (16) Train Loss: 0.384292 Time Elapsed: 163.72 seconds
# Epoch: 1 Batch: 391 (16) Train Loss: 0.435683 Time Elapsed: 164.20 seconds
# Epoch: 1 Batch: 392 (16) Train Loss: 0.341567 Time Elapsed: 164.69 seconds
# Epoch: 1 Batch: 393 (16) Train Loss: 0.334507 Time Elapsed: 165.12 seconds
# Epoch: 1 Batch: 394 (16) Train Loss: 0.437680 Time Elapsed: 165.64 seconds
# Epoch: 1 Batch: 395 (16) Train Loss: 0.420257 Time Elapsed: 165.86 seconds
# Epoch: 1 Batch: 396 (16) Train Loss: 0.349928 Time Elapsed: 166.10 seconds
# Epoch: 1 Batch: 397 (16) Train Loss: 0.372728 Time Elapsed: 166.39 seconds
# Epoch: 1 Batch: 398 (16) Train Loss: 0.415802 Time Elapsed: 166.82 seconds
# Epoch: 1 Batch: 399 (16) Train Loss: 0.331013 Time Elapsed: 167.04 seconds
# Epoch: 1 Batch: 400 (16) Train Loss: 0.386919 Time Elapsed: 167.31 seconds
# Epoch: 1 Batch: 401 (16) Train Loss: 0.272552 Time Elapsed: 167.68 seconds
# Epoch: 1 Batch: 402 (16) Train Loss: 0.237334 Time Elapsed: 168.17 seconds
# Epoch: 1 Batch: 403 (16) Train Loss: 0.361693 Time Elapsed: 168.47 seconds
# Epoch: 1 Batch: 404 (16) Train Loss: 0.357884 Time Elapsed: 168.71 seconds
# Epoch: 1 Batch: 405 (16) Train Loss: 0.321829 Time Elapsed: 169.02 seconds
# Epoch: 1 Batch: 406 (16) Train Loss: 0.390305 Time Elapsed: 169.35 seconds
# Epoch: 1 Batch: 407 (16) Train Loss: 0.327325 Time Elapsed: 169.66 seconds
# Epoch: 1 Batch: 408 (16) Train Loss: 0.295240 Time Elapsed: 169.96 seconds
# Epoch: 1 Batch: 409 (16) Train Loss: 0.354027 Time Elapsed: 170.24 seconds
# Epoch: 1 Batch: 410 (16) Train Loss: 0.405719 Time Elapsed: 170.53 seconds
# Epoch: 1 Batch: 411 (16) Train Loss: 0.387654 Time Elapsed: 170.86 seconds
# Epoch: 1 Batch: 412 (16) Train Loss: 0.228346 Time Elapsed: 171.21 seconds
# Epoch: 1 Batch: 413 (16) Train Loss: 0.338684 Time Elapsed: 171.51 seconds
# Epoch: 1 Batch: 414 (16) Train Loss: 0.406298 Time Elapsed: 171.73 seconds
# Epoch: 1 Batch: 415 (16) Train Loss: 0.375890 Time Elapsed: 172.07 seconds
# Epoch: 1 Batch: 416 (16) Train Loss: 0.266389 Time Elapsed: 172.35 seconds
# Epoch: 1 Batch: 417 (16) Train Loss: 0.292713 Time Elapsed: 172.63 seconds
# Epoch: 1 Batch: 418 (16) Train Loss: 0.434561 Time Elapsed: 173.05 seconds
# Epoch: 1 Batch: 419 (16) Train Loss: 0.333777 Time Elapsed: 173.36 seconds
# Epoch: 1 Batch: 420 (16) Train Loss: 0.445204 Time Elapsed: 173.59 seconds
# Epoch: 1 Batch: 421 (16) Train Loss: 0.555597 Time Elapsed: 174.10 seconds
# Epoch: 1 Batch: 422 (16) Train Loss: 0.333591 Time Elapsed: 174.51 seconds
# Epoch: 1 Batch: 423 (16) Train Loss: 0.333949 Time Elapsed: 174.84 seconds
# Epoch: 1 Batch: 424 (16) Train Loss: 0.370049 Time Elapsed: 175.11 seconds
# Epoch: 1 Batch: 425 (16) Train Loss: 0.398637 Time Elapsed: 175.52 seconds
# Epoch: 1 Batch: 426 (16) Train Loss: 0.382457 Time Elapsed: 175.92 seconds
# Epoch: 1 Batch: 427 (16) Train Loss: 0.368270 Time Elapsed: 176.37 seconds
# Epoch: 1 Batch: 428 (16) Train Loss: 0.253312 Time Elapsed: 176.76 seconds
# Epoch: 1 Batch: 429 (16) Train Loss: 0.316770 Time Elapsed: 177.42 seconds
# Epoch: 1 Batch: 430 (16) Train Loss: 0.237159 Time Elapsed: 178.01 seconds
# Epoch: 1 Batch: 431 (16) Train Loss: 0.399331 Time Elapsed: 178.44 seconds
# Epoch: 1 Batch: 432 (16) Train Loss: 0.311807 Time Elapsed: 178.87 seconds
# Epoch: 1 Batch: 433 (16) Train Loss: 0.396052 Time Elapsed: 179.61 seconds
# Epoch: 1 Batch: 434 (16) Train Loss: 0.428737 Time Elapsed: 180.32 seconds
# Epoch: 1 Batch: 435 (16) Train Loss: 0.362928 Time Elapsed: 180.78 seconds
# Epoch: 1 Batch: 436 (16) Train Loss: 0.286527 Time Elapsed: 181.25 seconds
# Epoch: 1 Batch: 437 (16) Train Loss: 0.462856 Time Elapsed: 181.87 seconds
# Epoch: 1 Batch: 438 (16) Train Loss: 0.448951 Time Elapsed: 182.71 seconds
# Epoch: 1 Batch: 439 (16) Train Loss: 0.326543 Time Elapsed: 183.16 seconds
# Epoch: 1 Batch: 440 (16) Train Loss: 0.308254 Time Elapsed: 183.61 seconds
# Epoch: 1 Batch: 441 (16) Train Loss: 0.485959 Time Elapsed: 184.28 seconds
# Epoch: 1 Batch: 442 (16) Train Loss: 0.329543 Time Elapsed: 184.93 seconds
# Epoch: 1 Batch: 443 (16) Train Loss: 0.262589 Time Elapsed: 185.34 seconds
# Epoch: 1 Batch: 444 (16) Train Loss: 0.268232 Time Elapsed: 185.64 seconds
# Epoch: 1 Batch: 445 (16) Train Loss: 0.510293 Time Elapsed: 186.00 seconds
# Epoch: 1 Batch: 446 (16) Train Loss: 0.282540 Time Elapsed: 186.42 seconds
# Epoch: 1 Batch: 447 (16) Train Loss: 0.421244 Time Elapsed: 186.72 seconds
# Epoch: 1 Batch: 448 (16) Train Loss: 0.382474 Time Elapsed: 186.99 seconds
# Epoch: 1 Batch: 449 (16) Train Loss: 0.277462 Time Elapsed: 187.24 seconds
# Epoch: 1 Batch: 450 (16) Train Loss: 0.432021 Time Elapsed: 187.66 seconds
# Epoch: 1 Batch: 451 (16) Train Loss: 0.418534 Time Elapsed: 187.96 seconds
# Epoch: 1 Batch: 452 (16) Train Loss: 0.364747 Time Elapsed: 188.20 seconds
# Epoch: 1 Batch: 453 (16) Train Loss: 0.362002 Time Elapsed: 188.46 seconds
# Epoch: 1 Batch: 454 (16) Train Loss: 0.397129 Time Elapsed: 188.80 seconds
# Epoch: 1 Batch: 455 (16) Train Loss: 0.334486 Time Elapsed: 189.07 seconds
# Epoch: 1 Batch: 456 (16) Train Loss: 0.385747 Time Elapsed: 189.37 seconds
# Epoch: 1 Batch: 457 (16) Train Loss: 0.289365 Time Elapsed: 189.78 seconds
# Epoch: 1 Batch: 458 (16) Train Loss: 0.405427 Time Elapsed: 190.07 seconds
# Epoch: 1 Batch: 459 (16) Train Loss: 0.330572 Time Elapsed: 190.43 seconds
# Epoch: 1 Batch: 460 (16) Train Loss: 0.364614 Time Elapsed: 190.71 seconds
# Epoch: 1 Batch: 461 (16) Train Loss: 0.408063 Time Elapsed: 191.07 seconds
# Epoch: 1 Batch: 462 (16) Train Loss: 0.381668 Time Elapsed: 191.32 seconds
# Epoch: 1 Batch: 463 (16) Train Loss: 0.570677 Time Elapsed: 191.60 seconds
# Epoch: 1 Batch: 464 (16) Train Loss: 0.356278 Time Elapsed: 191.82 seconds
# Epoch: 1 Batch: 465 (16) Train Loss: 0.443462 Time Elapsed: 192.18 seconds
# Epoch: 1 Batch: 466 (16) Train Loss: 0.316393 Time Elapsed: 192.44 seconds
# Epoch: 1 Batch: 467 (16) Train Loss: 0.270754 Time Elapsed: 192.61 seconds
# Epoch: 1 Batch: 468 (16) Train Loss: 0.560089 Time Elapsed: 193.08 seconds
# Epoch: 1 Batch: 469 (16) Train Loss: 0.458539 Time Elapsed: 193.45 seconds
# Epoch: 1 Batch: 470 (16) Train Loss: 0.262703 Time Elapsed: 193.80 seconds
# Epoch: 1 Batch: 471 (16) Train Loss: 0.389036 Time Elapsed: 194.08 seconds
# Epoch: 1 Batch: 472 (16) Train Loss: 0.234034 Time Elapsed: 194.36 seconds
# Epoch: 1 Batch: 473 (16) Train Loss: 0.442452 Time Elapsed: 194.76 seconds
# Epoch: 1 Batch: 474 (16) Train Loss: 0.388773 Time Elapsed: 194.97 seconds
# Epoch: 1 Batch: 475 (16) Train Loss: 0.234429 Time Elapsed: 195.38 seconds
# Epoch: 1 Batch: 476 (16) Train Loss: 0.289381 Time Elapsed: 195.72 seconds
# Epoch: 1 Batch: 477 (16) Train Loss: 0.355148 Time Elapsed: 196.72 seconds
# Epoch: 1 Batch: 478 (16) Train Loss: 0.283016 Time Elapsed: 197.08 seconds
# Epoch: 1 Batch: 479 (16) Train Loss: 0.304505 Time Elapsed: 197.52 seconds
# Epoch: 1 Batch: 480 (16) Train Loss: 0.440384 Time Elapsed: 198.01 seconds
# Epoch: 1 Batch: 481 (16) Train Loss: 0.365179 Time Elapsed: 198.81 seconds
# Epoch: 1 Batch: 482 (16) Train Loss: 0.263962 Time Elapsed: 199.30 seconds
# Epoch: 1 Batch: 483 (16) Train Loss: 0.429903 Time Elapsed: 199.62 seconds
# Epoch: 1 Batch: 484 (16) Train Loss: 0.355676 Time Elapsed: 200.07 seconds
# Epoch: 1 Batch: 485 (16) Train Loss: 0.280818 Time Elapsed: 200.95 seconds
# Epoch: 1 Batch: 486 (16) Train Loss: 0.244389 Time Elapsed: 201.41 seconds
# Epoch: 1 Batch: 487 (16) Train Loss: 0.533157 Time Elapsed: 201.85 seconds
# Epoch: 1 Batch: 488 (16) Train Loss: 0.343688 Time Elapsed: 202.30 seconds
# Epoch: 1 Batch: 489 (16) Train Loss: 0.430314 Time Elapsed: 203.30 seconds
# Epoch: 1 Batch: 490 (16) Train Loss: 0.321011 Time Elapsed: 203.79 seconds
# Epoch: 1 Batch: 491 (16) Train Loss: 0.409093 Time Elapsed: 204.20 seconds
# Epoch: 1 Batch: 492 (16) Train Loss: 0.372859 Time Elapsed: 204.57 seconds
# Epoch: 1 Batch: 493 (16) Train Loss: 0.377438 Time Elapsed: 205.26 seconds
# Epoch: 1 Batch: 494 (16) Train Loss: 0.362335 Time Elapsed: 205.69 seconds
# Epoch: 1 Batch: 495 (16) Train Loss: 0.235970 Time Elapsed: 206.05 seconds
# Epoch: 1 Batch: 496 (16) Train Loss: 0.292172 Time Elapsed: 206.40 seconds
# Epoch: 1 Batch: 497 (16) Train Loss: 0.250950 Time Elapsed: 206.91 seconds
# Epoch: 1 Batch: 498 (16) Train Loss: 0.315444 Time Elapsed: 207.22 seconds
# Epoch: 1 Batch: 499 (16) Train Loss: 0.355098 Time Elapsed: 207.51 seconds
# Epoch: 1 Batch: 500 (16) Train Loss: 0.444517 Time Elapsed: 207.78 seconds
# Epoch: 1 Batch: 501 (16) Train Loss: 0.379470 Time Elapsed: 208.08 seconds
# Epoch: 1 Batch: 502 (16) Train Loss: 0.556575 Time Elapsed: 208.38 seconds
# Epoch: 1 Batch: 503 (16) Train Loss: 0.652545 Time Elapsed: 208.76 seconds
# Epoch: 1 Batch: 504 (16) Train Loss: 0.406360 Time Elapsed: 209.04 seconds
# Epoch: 1 Batch: 505 (16) Train Loss: 0.396282 Time Elapsed: 209.51 seconds
# Epoch: 1 Batch: 506 (16) Train Loss: 0.250390 Time Elapsed: 209.76 seconds
# Epoch: 1 Batch: 507 (16) Train Loss: 0.345156 Time Elapsed: 210.10 seconds
# Epoch: 1 Batch: 508 (16) Train Loss: 0.348404 Time Elapsed: 210.33 seconds
# Epoch: 1 Batch: 509 (16) Train Loss: 0.322688 Time Elapsed: 210.72 seconds
# Epoch: 1 Batch: 510 (16) Train Loss: 0.314333 Time Elapsed: 210.96 seconds
# Epoch: 1 Batch: 511 (16) Train Loss: 0.356258 Time Elapsed: 211.44 seconds
# Epoch: 1 Batch: 512 (16) Train Loss: 0.358333 Time Elapsed: 211.73 seconds
# Epoch: 1 Batch: 513 (16) Train Loss: 0.293945 Time Elapsed: 212.04 seconds
# Epoch: 1 Batch: 514 (16) Train Loss: 0.407035 Time Elapsed: 212.28 seconds
# Epoch: 1 Batch: 515 (16) Train Loss: 0.398368 Time Elapsed: 212.70 seconds
# Epoch: 1 Batch: 516 (16) Train Loss: 0.381052 Time Elapsed: 212.98 seconds
# Epoch: 1 Batch: 517 (16) Train Loss: 0.435453 Time Elapsed: 213.24 seconds
# Epoch: 1 Batch: 518 (16) Train Loss: 0.272918 Time Elapsed: 213.57 seconds
# Epoch: 1 Batch: 519 (16) Train Loss: 0.322259 Time Elapsed: 213.99 seconds
# Epoch: 1 Batch: 520 (16) Train Loss: 0.330514 Time Elapsed: 214.28 seconds
# Epoch: 1 Batch: 521 (16) Train Loss: 0.486247 Time Elapsed: 214.70 seconds
# Epoch: 1 Batch: 522 (16) Train Loss: 0.316586 Time Elapsed: 214.98 seconds
# Epoch: 1 Batch: 523 (16) Train Loss: 0.503226 Time Elapsed: 215.27 seconds
# Epoch: 1 Batch: 524 (16) Train Loss: 0.299557 Time Elapsed: 215.59 seconds
# Epoch: 1 Batch: 525 (16) Train Loss: 0.274925 Time Elapsed: 215.85 seconds
# Epoch: 1 Batch: 526 (16) Train Loss: 0.407461 Time Elapsed: 216.20 seconds
# Epoch: 1 Batch: 527 (16) Train Loss: 0.354370 Time Elapsed: 217.06 seconds
# Epoch: 1 Batch: 528 (16) Train Loss: 0.458021 Time Elapsed: 217.59 seconds
# Epoch: 1 Batch: 529 (16) Train Loss: 0.412074 Time Elapsed: 218.08 seconds
# Epoch: 1 Batch: 530 (16) Train Loss: 0.260876 Time Elapsed: 218.60 seconds
# Epoch: 1 Batch: 531 (16) Train Loss: 0.301584 Time Elapsed: 219.21 seconds
# Epoch: 1 Batch: 532 (16) Train Loss: 0.398095 Time Elapsed: 219.62 seconds
# Epoch: 1 Batch: 533 (16) Train Loss: 0.412403 Time Elapsed: 220.08 seconds
# Epoch: 1 Batch: 534 (16) Train Loss: 0.344287 Time Elapsed: 220.53 seconds
# Epoch: 1 Batch: 535 (16) Train Loss: 0.334175 Time Elapsed: 221.51 seconds
# Epoch: 1 Batch: 536 (16) Train Loss: 0.371079 Time Elapsed: 221.90 seconds
# Epoch: 1 Batch: 537 (16) Train Loss: 0.277838 Time Elapsed: 222.41 seconds
# Epoch: 1 Batch: 538 (16) Train Loss: 0.444482 Time Elapsed: 222.88 seconds
# Epoch: 1 Batch: 539 (16) Train Loss: 0.476609 Time Elapsed: 223.77 seconds
# Epoch: 1 Batch: 540 (16) Train Loss: 0.462105 Time Elapsed: 224.34 seconds
# Epoch: 1 Batch: 541 (16) Train Loss: 0.377815 Time Elapsed: 224.78 seconds
# Epoch: 1 Batch: 542 (16) Train Loss: 0.459442 Time Elapsed: 225.33 seconds
# Epoch: 1 Batch: 543 (16) Train Loss: 0.249980 Time Elapsed: 226.00 seconds
# Epoch: 1 Batch: 544 (16) Train Loss: 0.472998 Time Elapsed: 226.32 seconds
# Epoch: 1 Batch: 545 (16) Train Loss: 0.377468 Time Elapsed: 226.59 seconds
# Epoch: 1 Batch: 546 (16) Train Loss: 0.474035 Time Elapsed: 226.87 seconds
# Epoch: 1 Batch: 547 (16) Train Loss: 0.385563 Time Elapsed: 227.22 seconds
# Epoch: 1 Batch: 548 (16) Train Loss: 0.366624 Time Elapsed: 227.42 seconds
# Epoch: 1 Batch: 549 (16) Train Loss: 0.336723 Time Elapsed: 227.86 seconds
# Epoch: 1 Batch: 550 (16) Train Loss: 0.296952 Time Elapsed: 228.09 seconds
# Epoch: 1 Batch: 551 (16) Train Loss: 0.317127 Time Elapsed: 228.53 seconds
# Epoch: 1 Batch: 552 (16) Train Loss: 0.321529 Time Elapsed: 228.79 seconds
# Epoch: 1 Batch: 553 (16) Train Loss: 0.271992 Time Elapsed: 229.22 seconds
# Epoch: 1 Batch: 554 (16) Train Loss: 0.353674 Time Elapsed: 229.51 seconds
# Epoch: 1 Batch: 555 (16) Train Loss: 0.405760 Time Elapsed: 229.80 seconds
# Epoch: 1 Batch: 556 (16) Train Loss: 0.268033 Time Elapsed: 230.06 seconds
# Epoch: 1 Batch: 557 (16) Train Loss: 0.311524 Time Elapsed: 230.47 seconds
# Epoch: 1 Batch: 558 (16) Train Loss: 0.326534 Time Elapsed: 230.73 seconds
# Epoch: 1 Batch: 559 (16) Train Loss: 0.310681 Time Elapsed: 231.09 seconds
# Epoch: 1 Batch: 560 (16) Train Loss: 0.410493 Time Elapsed: 231.33 seconds
# Epoch: 1 Batch: 561 (16) Train Loss: 0.373323 Time Elapsed: 231.85 seconds
# Epoch: 1 Batch: 562 (16) Train Loss: 0.256601 Time Elapsed: 232.12 seconds
# Epoch: 1 Batch: 563 (16) Train Loss: 0.310104 Time Elapsed: 232.41 seconds
# Epoch: 1 Batch: 564 (16) Train Loss: 0.564647 Time Elapsed: 232.70 seconds
# Epoch: 1 Batch: 565 (16) Train Loss: 0.380259 Time Elapsed: 233.08 seconds
# Epoch: 1 Batch: 566 (16) Train Loss: 0.348556 Time Elapsed: 233.36 seconds
# Epoch: 1 Batch: 567 (16) Train Loss: 0.292093 Time Elapsed: 233.74 seconds
# Epoch: 1 Batch: 568 (16) Train Loss: 0.353498 Time Elapsed: 234.03 seconds
# Epoch: 1 Batch: 569 (16) Train Loss: 0.404926 Time Elapsed: 234.39 seconds
# Epoch: 1 Batch: 570 (16) Train Loss: 0.347885 Time Elapsed: 234.68 seconds
# Epoch: 1 Batch: 571 (16) Train Loss: 0.293031 Time Elapsed: 235.06 seconds
# Epoch: 1 Batch: 572 (16) Train Loss: 0.250902 Time Elapsed: 235.30 seconds
# Epoch: 1 Batch: 573 (16) Train Loss: 0.335225 Time Elapsed: 235.63 seconds
# Epoch: 1 Batch: 574 (16) Train Loss: 0.185426 Time Elapsed: 235.92 seconds
# Epoch: 1 Batch: 575 (16) Train Loss: 0.250947 Time Elapsed: 236.64 seconds
# Epoch: 1 Batch: 576 (16) Train Loss: 0.342658 Time Elapsed: 237.11 seconds
# Epoch: 1 Batch: 577 (16) Train Loss: 0.320029 Time Elapsed: 237.51 seconds
# Epoch: 1 Batch: 578 (16) Train Loss: 0.307450 Time Elapsed: 237.82 seconds
# Epoch: 1 Batch: 579 (16) Train Loss: 0.342545 Time Elapsed: 238.63 seconds
# Epoch: 1 Batch: 580 (16) Train Loss: 0.299326 Time Elapsed: 239.06 seconds
# Epoch: 1 Batch: 581 (16) Train Loss: 0.310154 Time Elapsed: 239.46 seconds
# Epoch: 1 Batch: 582 (16) Train Loss: 0.558755 Time Elapsed: 239.86 seconds
# Epoch: 1 Batch: 583 (16) Train Loss: 0.453269 Time Elapsed: 240.61 seconds
# Epoch: 1 Batch: 584 (16) Train Loss: 0.418074 Time Elapsed: 241.05 seconds
# Epoch: 1 Batch: 585 (16) Train Loss: 0.346656 Time Elapsed: 241.59 seconds
# Epoch: 1 Batch: 586 (16) Train Loss: 0.367150 Time Elapsed: 242.04 seconds
# Epoch: 1 Batch: 587 (16) Train Loss: 0.329197 Time Elapsed: 242.89 seconds
# Epoch: 1 Batch: 588 (16) Train Loss: 0.339897 Time Elapsed: 243.34 seconds
# Epoch: 1 Batch: 589 (16) Train Loss: 0.326733 Time Elapsed: 243.88 seconds
# Epoch: 1 Batch: 590 (16) Train Loss: 0.284323 Time Elapsed: 244.16 seconds
# Epoch: 1 Batch: 591 (16) Train Loss: 0.275196 Time Elapsed: 245.03 seconds
# Epoch: 1 Batch: 592 (16) Train Loss: 0.236152 Time Elapsed: 245.49 seconds
# Epoch: 1 Batch: 593 (16) Train Loss: 0.280691 Time Elapsed: 245.93 seconds
# Epoch: 1 Batch: 594 (16) Train Loss: 0.387453 Time Elapsed: 246.18 seconds
# Epoch: 1 Batch: 595 (16) Train Loss: 0.438790 Time Elapsed: 246.95 seconds
# Epoch: 1 Batch: 596 (16) Train Loss: 0.569081 Time Elapsed: 247.21 seconds
# Epoch: 1 Batch: 597 (16) Train Loss: 0.301919 Time Elapsed: 247.51 seconds
# Epoch: 1 Batch: 598 (16) Train Loss: 0.479593 Time Elapsed: 247.83 seconds
# Epoch: 1 Batch: 599 (16) Train Loss: 0.285744 Time Elapsed: 248.31 seconds
# Epoch: 1 Batch: 600 (16) Train Loss: 0.341674 Time Elapsed: 248.62 seconds
# Epoch: 1 Batch: 601 (16) Train Loss: 0.508224 Time Elapsed: 248.85 seconds
# Epoch: 1 Batch: 602 (16) Train Loss: 0.285876 Time Elapsed: 249.08 seconds
# Epoch: 1 Batch: 603 (16) Train Loss: 0.315146 Time Elapsed: 249.41 seconds
# Epoch: 1 Batch: 604 (16) Train Loss: 0.347336 Time Elapsed: 249.68 seconds
# Epoch: 1 Batch: 605 (16) Train Loss: 0.425476 Time Elapsed: 249.99 seconds
# Epoch: 1 Batch: 606 (16) Train Loss: 0.202063 Time Elapsed: 250.28 seconds
# Epoch: 1 Batch: 607 (16) Train Loss: 0.404580 Time Elapsed: 250.88 seconds
# Epoch: 1 Batch: 608 (16) Train Loss: 0.357969 Time Elapsed: 251.18 seconds
# Epoch: 1 Batch: 609 (16) Train Loss: 0.455188 Time Elapsed: 251.47 seconds
# Epoch: 1 Batch: 610 (16) Train Loss: 0.439334 Time Elapsed: 251.78 seconds
# Epoch: 1 Batch: 611 (16) Train Loss: 0.333344 Time Elapsed: 252.10 seconds
# Epoch: 1 Batch: 612 (16) Train Loss: 0.374418 Time Elapsed: 252.36 seconds
# Epoch: 1 Batch: 613 (16) Train Loss: 0.286834 Time Elapsed: 252.70 seconds
# Epoch: 1 Batch: 614 (16) Train Loss: 0.279338 Time Elapsed: 253.02 seconds
# Epoch: 1 Batch: 615 (16) Train Loss: 0.283622 Time Elapsed: 253.43 seconds
# Epoch: 1 Batch: 616 (16) Train Loss: 0.334677 Time Elapsed: 253.73 seconds
# Epoch: 1 Batch: 617 (16) Train Loss: 0.270946 Time Elapsed: 254.15 seconds
# Epoch: 1 Batch: 618 (16) Train Loss: 0.379388 Time Elapsed: 254.41 seconds
# Epoch: 1 Batch: 619 (16) Train Loss: 0.386867 Time Elapsed: 254.63 seconds
# Epoch: 1 Batch: 620 (16) Train Loss: 0.333327 Time Elapsed: 254.88 seconds
# Epoch: 1 Batch: 621 (16) Train Loss: 0.483501 Time Elapsed: 255.15 seconds
# Epoch: 1 Batch: 622 (16) Train Loss: 0.403454 Time Elapsed: 255.28 seconds
# Epoch: 1 Batch: 623 (16) Train Loss: 0.253387 Time Elapsed: 255.44 seconds
# Epoch: 1 Batch: 624 (16) Train Loss: 0.327998 Time Elapsed: 255.61 seconds
# Training Loss: 0.375704
# Validation Loss: 0.345894
# Class: Nodule Count: 289 PR AUC: 0.2540 ROC AUC: 0.7495 F1: 0.047 Acc: 0.928
# Class: Infiltration Count: 828 PR AUC: 0.4210 ROC AUC: 0.7136 F1: 0.180 Acc: 0.799
# Class: Effusion Count: 665 PR AUC: 0.5734 ROC AUC: 0.8632 F1: 0.554 Acc: 0.870
# Class: Atelectasis Count: 611 PR AUC: 0.3647 ROC AUC: 0.7567 F1: 0.016 Acc: 0.848
# Avg PR AUC: 0.403
# Avg ROC AUC: 0.771
# Avg F1: 0.226
# Validation AUC: PR AUC=0.403, ROC AUC=0.771, F1 Score=0.226
# Class: Nodule Count: 289 PR AUC: 0.2540 ROC AUC: 0.7495 F1: 0.047 Acc: 0.928
# Class: Infiltration Count: 828 PR AUC: 0.4210 ROC AUC: 0.7136 F1: 0.180 Acc: 0.799
# Class: Effusion Count: 665 PR AUC: 0.5734 ROC AUC: 0.8632 F1: 0.554 Acc: 0.870
# Class: Atelectasis Count: 611 PR AUC: 0.3647 ROC AUC: 0.7567 F1: 0.016 Acc: 0.848
# Avg PR AUC: 0.403
# Avg ROC AUC: 0.771
# Avg F1: 0.226
# Epoch 2/10
# ----------
# ...
# Epoch: 9 Batch: 424 (16) Train Loss: 0.032697 Time Elapsed: 171.93 seconds
# Epoch: 9 Batch: 425 (16) Train Loss: 0.032380 Time Elapsed: 172.27 seconds
# Epoch: 9 Batch: 426 (16) Train Loss: 0.022653 Time Elapsed: 172.71 seconds
# Epoch: 9 Batch: 427 (16) Train Loss: 0.015482 Time Elapsed: 173.10 seconds
# Epoch: 9 Batch: 428 (16) Train Loss: 0.029911 Time Elapsed: 173.61 seconds
# Epoch: 9 Batch: 429 (16) Train Loss: 0.030804 Time Elapsed: 174.02 seconds
# Epoch: 9 Batch: 430 (16) Train Loss: 0.019601 Time Elapsed: 174.46 seconds
# Epoch: 9 Batch: 431 (16) Train Loss: 0.009237 Time Elapsed: 174.85 seconds
# Epoch: 9 Batch: 432 (16) Train Loss: 0.015777 Time Elapsed: 175.85 seconds
# Epoch: 9 Batch: 433 (16) Train Loss: 0.016479 Time Elapsed: 176.27 seconds
# Epoch: 9 Batch: 434 (16) Train Loss: 0.016829 Time Elapsed: 176.75 seconds
# Epoch: 9 Batch: 435 (16) Train Loss: 0.018674 Time Elapsed: 177.20 seconds
# Epoch: 9 Batch: 436 (16) Train Loss: 0.013504 Time Elapsed: 178.04 seconds
# Epoch: 9 Batch: 437 (16) Train Loss: 0.063318 Time Elapsed: 178.49 seconds
# Epoch: 9 Batch: 438 (16) Train Loss: 0.014106 Time Elapsed: 178.97 seconds
# Epoch: 9 Batch: 439 (16) Train Loss: 0.015405 Time Elapsed: 179.40 seconds
# Epoch: 9 Batch: 440 (16) Train Loss: 0.014783 Time Elapsed: 180.20 seconds
# Epoch: 9 Batch: 441 (16) Train Loss: 0.015455 Time Elapsed: 180.69 seconds
# Epoch: 9 Batch: 442 (16) Train Loss: 0.017416 Time Elapsed: 181.07 seconds
# Epoch: 9 Batch: 443 (16) Train Loss: 0.070951 Time Elapsed: 181.53 seconds
# Epoch: 9 Batch: 444 (16) Train Loss: 0.048071 Time Elapsed: 182.21 seconds
# Epoch: 9 Batch: 445 (16) Train Loss: 0.024354 Time Elapsed: 182.53 seconds
# Epoch: 9 Batch: 446 (16) Train Loss: 0.026183 Time Elapsed: 182.84 seconds
# Epoch: 9 Batch: 447 (16) Train Loss: 0.013387 Time Elapsed: 183.15 seconds
# Epoch: 9 Batch: 448 (16) Train Loss: 0.014033 Time Elapsed: 183.42 seconds
# Epoch: 9 Batch: 449 (16) Train Loss: 0.012512 Time Elapsed: 183.71 seconds
# Epoch: 9 Batch: 450 (16) Train Loss: 0.011072 Time Elapsed: 183.98 seconds
# Epoch: 9 Batch: 451 (16) Train Loss: 0.017871 Time Elapsed: 184.47 seconds
# Epoch: 9 Batch: 452 (16) Train Loss: 0.027362 Time Elapsed: 184.77 seconds
# Epoch: 9 Batch: 453 (16) Train Loss: 0.035419 Time Elapsed: 185.05 seconds
# Epoch: 9 Batch: 454 (16) Train Loss: 0.010505 Time Elapsed: 185.27 seconds
# Epoch: 9 Batch: 455 (16) Train Loss: 0.026392 Time Elapsed: 185.67 seconds
# Epoch: 9 Batch: 456 (16) Train Loss: 0.036735 Time Elapsed: 185.96 seconds
# Epoch: 9 Batch: 457 (16) Train Loss: 0.028016 Time Elapsed: 186.25 seconds
# Epoch: 9 Batch: 458 (16) Train Loss: 0.028643 Time Elapsed: 186.50 seconds
# Epoch: 9 Batch: 459 (16) Train Loss: 0.023377 Time Elapsed: 186.84 seconds
# Epoch: 9 Batch: 460 (16) Train Loss: 0.021226 Time Elapsed: 187.10 seconds
# Epoch: 9 Batch: 461 (16) Train Loss: 0.013590 Time Elapsed: 187.38 seconds
# Epoch: 9 Batch: 462 (16) Train Loss: 0.021982 Time Elapsed: 187.64 seconds
# Epoch: 9 Batch: 463 (16) Train Loss: 0.017059 Time Elapsed: 188.18 seconds
# Epoch: 9 Batch: 464 (16) Train Loss: 0.012909 Time Elapsed: 188.45 seconds
# Epoch: 9 Batch: 465 (16) Train Loss: 0.053601 Time Elapsed: 188.76 seconds
# Epoch: 9 Batch: 466 (16) Train Loss: 0.013641 Time Elapsed: 188.98 seconds
# Epoch: 9 Batch: 467 (16) Train Loss: 0.022569 Time Elapsed: 189.41 seconds
# Epoch: 9 Batch: 468 (16) Train Loss: 0.014483 Time Elapsed: 189.68 seconds
# Epoch: 9 Batch: 469 (16) Train Loss: 0.018637 Time Elapsed: 189.94 seconds
# Epoch: 9 Batch: 470 (16) Train Loss: 0.011025 Time Elapsed: 190.19 seconds
# Epoch: 9 Batch: 471 (16) Train Loss: 0.019757 Time Elapsed: 190.72 seconds
# Epoch: 9 Batch: 472 (16) Train Loss: 0.019908 Time Elapsed: 191.02 seconds
# Epoch: 9 Batch: 473 (16) Train Loss: 0.039799 Time Elapsed: 191.21 seconds
# Epoch: 9 Batch: 474 (16) Train Loss: 0.026897 Time Elapsed: 191.46 seconds
# Epoch: 9 Batch: 475 (16) Train Loss: 0.052482 Time Elapsed: 191.98 seconds
# Epoch: 9 Batch: 476 (16) Train Loss: 0.048401 Time Elapsed: 192.29 seconds
# Epoch: 9 Batch: 477 (16) Train Loss: 0.025165 Time Elapsed: 192.63 seconds
# Epoch: 9 Batch: 478 (16) Train Loss: 0.014729 Time Elapsed: 193.05 seconds
# Epoch: 9 Batch: 479 (16) Train Loss: 0.008722 Time Elapsed: 193.43 seconds
# Epoch: 9 Batch: 480 (16) Train Loss: 0.040250 Time Elapsed: 193.75 seconds
# Epoch: 9 Batch: 481 (16) Train Loss: 0.018400 Time Elapsed: 194.14 seconds
# Epoch: 9 Batch: 482 (16) Train Loss: 0.021844 Time Elapsed: 194.47 seconds
# Epoch: 9 Batch: 483 (16) Train Loss: 0.026232 Time Elapsed: 195.46 seconds
# Epoch: 9 Batch: 484 (16) Train Loss: 0.016620 Time Elapsed: 195.84 seconds
# Epoch: 9 Batch: 485 (16) Train Loss: 0.010403 Time Elapsed: 196.26 seconds
# Epoch: 9 Batch: 486 (16) Train Loss: 0.039800 Time Elapsed: 196.67 seconds
# Epoch: 9 Batch: 487 (16) Train Loss: 0.021575 Time Elapsed: 197.59 seconds
# Epoch: 9 Batch: 488 (16) Train Loss: 0.025785 Time Elapsed: 198.01 seconds
# Epoch: 9 Batch: 489 (16) Train Loss: 0.012202 Time Elapsed: 198.42 seconds
# Epoch: 9 Batch: 490 (16) Train Loss: 0.013792 Time Elapsed: 198.86 seconds
# Epoch: 9 Batch: 491 (16) Train Loss: 0.037312 Time Elapsed: 199.78 seconds
# Epoch: 9 Batch: 492 (16) Train Loss: 0.035209 Time Elapsed: 200.15 seconds
# Epoch: 9 Batch: 493 (16) Train Loss: 0.013888 Time Elapsed: 200.57 seconds
# Epoch: 9 Batch: 494 (16) Train Loss: 0.048948 Time Elapsed: 200.97 seconds
# Epoch: 9 Batch: 495 (16) Train Loss: 0.026027 Time Elapsed: 202.01 seconds
# Epoch: 9 Batch: 496 (16) Train Loss: 0.057179 Time Elapsed: 202.40 seconds
# Epoch: 9 Batch: 497 (16) Train Loss: 0.034535 Time Elapsed: 202.72 seconds
# Epoch: 9 Batch: 498 (16) Train Loss: 0.035310 Time Elapsed: 203.02 seconds
# Epoch: 9 Batch: 499 (16) Train Loss: 0.033932 Time Elapsed: 203.28 seconds
# Epoch: 9 Batch: 500 (16) Train Loss: 0.032034 Time Elapsed: 203.53 seconds
# Epoch: 9 Batch: 501 (16) Train Loss: 0.024023 Time Elapsed: 203.74 seconds
# Epoch: 9 Batch: 502 (16) Train Loss: 0.013889 Time Elapsed: 204.01 seconds
# Epoch: 9 Batch: 503 (16) Train Loss: 0.048233 Time Elapsed: 204.53 seconds
# Epoch: 9 Batch: 504 (16) Train Loss: 0.034191 Time Elapsed: 204.87 seconds
# Epoch: 9 Batch: 505 (16) Train Loss: 0.032377 Time Elapsed: 205.24 seconds
# Epoch: 9 Batch: 506 (16) Train Loss: 0.025668 Time Elapsed: 205.52 seconds
# Epoch: 9 Batch: 507 (16) Train Loss: 0.033949 Time Elapsed: 206.00 seconds
# Epoch: 9 Batch: 508 (16) Train Loss: 0.035815 Time Elapsed: 206.29 seconds
# Epoch: 9 Batch: 509 (16) Train Loss: 0.103973 Time Elapsed: 206.55 seconds
# Epoch: 9 Batch: 510 (16) Train Loss: 0.011473 Time Elapsed: 206.89 seconds
# Epoch: 9 Batch: 511 (16) Train Loss: 0.011696 Time Elapsed: 207.33 seconds
# Epoch: 9 Batch: 512 (16) Train Loss: 0.017055 Time Elapsed: 207.60 seconds
# Epoch: 9 Batch: 513 (16) Train Loss: 0.017321 Time Elapsed: 207.90 seconds
# Epoch: 9 Batch: 514 (16) Train Loss: 0.012737 Time Elapsed: 208.20 seconds
# Epoch: 9 Batch: 515 (16) Train Loss: 0.058842 Time Elapsed: 208.61 seconds
# Epoch: 9 Batch: 516 (16) Train Loss: 0.029984 Time Elapsed: 208.89 seconds
# Epoch: 9 Batch: 517 (16) Train Loss: 0.043638 Time Elapsed: 209.13 seconds
# Epoch: 9 Batch: 518 (16) Train Loss: 0.044529 Time Elapsed: 209.34 seconds
# Epoch: 9 Batch: 519 (16) Train Loss: 0.034380 Time Elapsed: 209.76 seconds
# Epoch: 9 Batch: 520 (16) Train Loss: 0.034934 Time Elapsed: 210.02 seconds
# Epoch: 9 Batch: 521 (16) Train Loss: 0.017219 Time Elapsed: 210.25 seconds
# Epoch: 9 Batch: 522 (16) Train Loss: 0.020417 Time Elapsed: 210.53 seconds
# Epoch: 9 Batch: 523 (16) Train Loss: 0.020457 Time Elapsed: 211.08 seconds
# Epoch: 9 Batch: 524 (16) Train Loss: 0.048115 Time Elapsed: 211.29 seconds
# Epoch: 9 Batch: 525 (16) Train Loss: 0.034557 Time Elapsed: 211.57 seconds
# Epoch: 9 Batch: 526 (16) Train Loss: 0.045978 Time Elapsed: 211.87 seconds
# Epoch: 9 Batch: 527 (16) Train Loss: 0.025930 Time Elapsed: 212.23 seconds
# Epoch: 9 Batch: 528 (16) Train Loss: 0.033273 Time Elapsed: 212.59 seconds
# Epoch: 9 Batch: 529 (16) Train Loss: 0.054638 Time Elapsed: 213.00 seconds
# Epoch: 9 Batch: 530 (16) Train Loss: 0.033140 Time Elapsed: 213.37 seconds
# Epoch: 9 Batch: 531 (16) Train Loss: 0.013277 Time Elapsed: 214.29 seconds
# Epoch: 9 Batch: 532 (16) Train Loss: 0.012715 Time Elapsed: 214.67 seconds
# Epoch: 9 Batch: 533 (16) Train Loss: 0.022732 Time Elapsed: 215.10 seconds
# Epoch: 9 Batch: 534 (16) Train Loss: 0.010001 Time Elapsed: 215.44 seconds
# Epoch: 9 Batch: 535 (16) Train Loss: 0.009415 Time Elapsed: 216.39 seconds
# Epoch: 9 Batch: 536 (16) Train Loss: 0.014897 Time Elapsed: 216.82 seconds
# Epoch: 9 Batch: 537 (16) Train Loss: 0.026716 Time Elapsed: 217.20 seconds
# Epoch: 9 Batch: 538 (16) Train Loss: 0.027149 Time Elapsed: 217.64 seconds
# Epoch: 9 Batch: 539 (16) Train Loss: 0.024855 Time Elapsed: 218.46 seconds
# Epoch: 9 Batch: 540 (16) Train Loss: 0.014073 Time Elapsed: 218.87 seconds
# Epoch: 9 Batch: 541 (16) Train Loss: 0.025919 Time Elapsed: 219.30 seconds
# Epoch: 9 Batch: 542 (16) Train Loss: 0.072637 Time Elapsed: 219.74 seconds
# Epoch: 9 Batch: 543 (16) Train Loss: 0.039625 Time Elapsed: 220.67 seconds
# Epoch: 9 Batch: 544 (16) Train Loss: 0.022901 Time Elapsed: 221.10 seconds
# Epoch: 9 Batch: 545 (16) Train Loss: 0.017205 Time Elapsed: 221.59 seconds
# Epoch: 9 Batch: 546 (16) Train Loss: 0.017522 Time Elapsed: 222.04 seconds
# Epoch: 9 Batch: 547 (16) Train Loss: 0.014294 Time Elapsed: 222.65 seconds
# Epoch: 9 Batch: 548 (16) Train Loss: 0.020137 Time Elapsed: 222.91 seconds
# Epoch: 9 Batch: 549 (16) Train Loss: 0.018318 Time Elapsed: 223.22 seconds
# Epoch: 9 Batch: 550 (16) Train Loss: 0.054194 Time Elapsed: 223.46 seconds
# Epoch: 9 Batch: 551 (16) Train Loss: 0.038364 Time Elapsed: 223.82 seconds
# Epoch: 9 Batch: 552 (16) Train Loss: 0.026822 Time Elapsed: 224.07 seconds
# Epoch: 9 Batch: 553 (16) Train Loss: 0.018630 Time Elapsed: 224.32 seconds
# Epoch: 9 Batch: 554 (16) Train Loss: 0.019870 Time Elapsed: 224.57 seconds
# Epoch: 9 Batch: 555 (16) Train Loss: 0.030305 Time Elapsed: 225.17 seconds
# Epoch: 9 Batch: 556 (16) Train Loss: 0.030223 Time Elapsed: 225.42 seconds
# Epoch: 9 Batch: 557 (16) Train Loss: 0.026153 Time Elapsed: 225.76 seconds
# Epoch: 9 Batch: 558 (16) Train Loss: 0.024982 Time Elapsed: 226.06 seconds
# Epoch: 9 Batch: 559 (16) Train Loss: 0.031927 Time Elapsed: 226.27 seconds
# Epoch: 9 Batch: 560 (16) Train Loss: 0.030157 Time Elapsed: 226.55 seconds
# Epoch: 9 Batch: 561 (16) Train Loss: 0.012849 Time Elapsed: 226.86 seconds
# Epoch: 9 Batch: 562 (16) Train Loss: 0.018893 Time Elapsed: 227.10 seconds
# Epoch: 9 Batch: 563 (16) Train Loss: 0.012369 Time Elapsed: 227.63 seconds
# Epoch: 9 Batch: 564 (16) Train Loss: 0.019759 Time Elapsed: 227.95 seconds
# Epoch: 9 Batch: 565 (16) Train Loss: 0.022652 Time Elapsed: 228.13 seconds
# Epoch: 9 Batch: 566 (16) Train Loss: 0.010619 Time Elapsed: 228.39 seconds
# Epoch: 9 Batch: 567 (16) Train Loss: 0.020135 Time Elapsed: 228.81 seconds
# Epoch: 9 Batch: 568 (16) Train Loss: 0.075572 Time Elapsed: 229.05 seconds
# Epoch: 9 Batch: 569 (16) Train Loss: 0.024438 Time Elapsed: 229.30 seconds
# Epoch: 9 Batch: 570 (16) Train Loss: 0.027180 Time Elapsed: 229.58 seconds
# Epoch: 9 Batch: 571 (16) Train Loss: 0.021683 Time Elapsed: 230.01 seconds
# Epoch: 9 Batch: 572 (16) Train Loss: 0.035247 Time Elapsed: 230.27 seconds
# Epoch: 9 Batch: 573 (16) Train Loss: 0.010427 Time Elapsed: 230.54 seconds
# Epoch: 9 Batch: 574 (16) Train Loss: 0.011600 Time Elapsed: 230.88 seconds
# Epoch: 9 Batch: 575 (16) Train Loss: 0.026975 Time Elapsed: 231.27 seconds
# Epoch: 9 Batch: 576 (16) Train Loss: 0.059106 Time Elapsed: 231.56 seconds
# Epoch: 9 Batch: 577 (16) Train Loss: 0.054741 Time Elapsed: 231.86 seconds
# Epoch: 9 Batch: 578 (16) Train Loss: 0.034597 Time Elapsed: 232.15 seconds
# Epoch: 9 Batch: 579 (16) Train Loss: 0.041489 Time Elapsed: 232.68 seconds
# Epoch: 9 Batch: 580 (16) Train Loss: 0.033025 Time Elapsed: 233.01 seconds
# Epoch: 9 Batch: 581 (16) Train Loss: 0.019210 Time Elapsed: 233.32 seconds
# Epoch: 9 Batch: 582 (16) Train Loss: 0.025302 Time Elapsed: 233.66 seconds
# Epoch: 9 Batch: 583 (16) Train Loss: 0.017677 Time Elapsed: 234.66 seconds
# Epoch: 9 Batch: 584 (16) Train Loss: 0.026588 Time Elapsed: 234.99 seconds
# Epoch: 9 Batch: 585 (16) Train Loss: 0.013331 Time Elapsed: 235.42 seconds
# Epoch: 9 Batch: 586 (16) Train Loss: 0.042006 Time Elapsed: 235.78 seconds
# Epoch: 9 Batch: 587 (16) Train Loss: 0.027258 Time Elapsed: 236.77 seconds
# Epoch: 9 Batch: 588 (16) Train Loss: 0.052240 Time Elapsed: 237.26 seconds
# Epoch: 9 Batch: 589 (16) Train Loss: 0.013587 Time Elapsed: 237.70 seconds
# Epoch: 9 Batch: 590 (16) Train Loss: 0.015437 Time Elapsed: 238.16 seconds
# Epoch: 9 Batch: 591 (16) Train Loss: 0.013591 Time Elapsed: 239.13 seconds
# Epoch: 9 Batch: 592 (16) Train Loss: 0.007665 Time Elapsed: 239.58 seconds
# Epoch: 9 Batch: 593 (16) Train Loss: 0.033799 Time Elapsed: 239.98 seconds
# Epoch: 9 Batch: 594 (16) Train Loss: 0.017563 Time Elapsed: 240.42 seconds
# Epoch: 9 Batch: 595 (16) Train Loss: 0.028934 Time Elapsed: 241.29 seconds
# Epoch: 9 Batch: 596 (16) Train Loss: 0.022414 Time Elapsed: 241.73 seconds
# Epoch: 9 Batch: 597 (16) Train Loss: 0.023316 Time Elapsed: 242.13 seconds
# Epoch: 9 Batch: 598 (16) Train Loss: 0.025578 Time Elapsed: 242.43 seconds
# Epoch: 9 Batch: 599 (16) Train Loss: 0.010018 Time Elapsed: 243.10 seconds
# Epoch: 9 Batch: 600 (16) Train Loss: 0.018545 Time Elapsed: 243.37 seconds
# Epoch: 9 Batch: 601 (16) Train Loss: 0.014884 Time Elapsed: 243.67 seconds
# Epoch: 9 Batch: 602 (16) Train Loss: 0.024895 Time Elapsed: 243.91 seconds
# Epoch: 9 Batch: 603 (16) Train Loss: 0.014035 Time Elapsed: 244.31 seconds
# Epoch: 9 Batch: 604 (16) Train Loss: 0.028541 Time Elapsed: 244.61 seconds
# Epoch: 9 Batch: 605 (16) Train Loss: 0.030506 Time Elapsed: 244.89 seconds
# Epoch: 9 Batch: 606 (16) Train Loss: 0.020706 Time Elapsed: 245.18 seconds
# Epoch: 9 Batch: 607 (16) Train Loss: 0.023267 Time Elapsed: 245.57 seconds
# Epoch: 9 Batch: 608 (16) Train Loss: 0.048571 Time Elapsed: 245.80 seconds
# Epoch: 9 Batch: 609 (16) Train Loss: 0.019235 Time Elapsed: 246.06 seconds
# Epoch: 9 Batch: 610 (16) Train Loss: 0.011594 Time Elapsed: 246.32 seconds
# Epoch: 9 Batch: 611 (16) Train Loss: 0.082270 Time Elapsed: 246.80 seconds
# Epoch: 9 Batch: 612 (16) Train Loss: 0.025486 Time Elapsed: 247.03 seconds
# Epoch: 9 Batch: 613 (16) Train Loss: 0.027470 Time Elapsed: 247.31 seconds
# Epoch: 9 Batch: 614 (16) Train Loss: 0.018937 Time Elapsed: 247.58 seconds
# Epoch: 9 Batch: 615 (16) Train Loss: 0.015375 Time Elapsed: 248.07 seconds
# Epoch: 9 Batch: 616 (16) Train Loss: 0.008474 Time Elapsed: 248.34 seconds
# Epoch: 9 Batch: 617 (16) Train Loss: 0.026721 Time Elapsed: 248.67 seconds
# Epoch: 9 Batch: 618 (16) Train Loss: 0.018957 Time Elapsed: 248.99 seconds
# Epoch: 9 Batch: 619 (16) Train Loss: 0.011572 Time Elapsed: 249.19 seconds
# Epoch: 9 Batch: 620 (16) Train Loss: 0.034716 Time Elapsed: 249.42 seconds
# Epoch: 9 Batch: 621 (16) Train Loss: 0.012248 Time Elapsed: 249.60 seconds
# Epoch: 9 Batch: 622 (16) Train Loss: 0.015274 Time Elapsed: 249.75 seconds
# Epoch: 9 Batch: 623 (16) Train Loss: 0.024190 Time Elapsed: 249.91 seconds
# Epoch: 9 Batch: 624 (16) Train Loss: 0.016970 Time Elapsed: 250.08 seconds
# Training Loss: 0.027619
# Validation Loss: 0.325133
# Class: Nodule Count: 289 PR AUC: 0.6740 ROC AUC: 0.8473 F1: 0.686 Acc: 0.962
# Class: Infiltration Count: 828 PR AUC: 0.7093 ROC AUC: 0.8396 F1: 0.627 Acc: 0.865
# Class: Effusion Count: 665 PR AUC: 0.8024 ROC AUC: 0.9224 F1: 0.745 Acc: 0.920
# Class: Atelectasis Count: 611 PR AUC: 0.7207 ROC AUC: 0.8647 F1: 0.653 Acc: 0.901
# Avg PR AUC: 0.727
# Avg ROC AUC: 0.870
# Avg F1: 0.673
# Validation AUC: PR AUC=0.727, ROC AUC=0.870, F1 Score=0.673
# Class: Nodule Count: 289 PR AUC: 0.6740 ROC AUC: 0.8473 F1: 0.686 Acc: 0.962
# Class: Infiltration Count: 828 PR AUC: 0.7093 ROC AUC: 0.8396 F1: 0.627 Acc: 0.865
# Class: Effusion Count: 665 PR AUC: 0.8024 ROC AUC: 0.9224 F1: 0.745 Acc: 0.920
# Class: Atelectasis Count: 611 PR AUC: 0.7207 ROC AUC: 0.8647 F1: 0.653 Acc: 0.901
# Avg PR AUC: 0.727
# Avg ROC AUC: 0.870
# Avg F1: 0.673
# Best Validation Loss: 0.29960194

# %% [markdown]
# ### Predict

# %%
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/female
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/female/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/male
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/male/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/young
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/young/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/middle
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/middle/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/old
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/old/predictions

# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/female
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/female/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/male
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/male/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/young
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/young/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/middle
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/middle/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/old
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/old/predictions

# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/female
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/female/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/male
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/male/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/young
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/young/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/middle
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/middle/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/old
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/old/predictions

# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/female
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/female/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/male
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/male/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/young
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/young/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/middle
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/middle/predictions
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/old
# ! mkdir /content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/old/predictions

# %%
from __future__ import division
from __future__ import print_function
import numpy as np
import torch
import time
import os
import json
import argparse
import itertools
from sklearn import metrics
#import util
#from train import transform_data, DenseNet
from joblib import Memory


memory = Memory(location='./cache', verbose=0)


# convert dictionary to object
class Struct:
    def __init__(self, **entries):
        self.__dict__.update(entries)


def load_model(args, load_path, nclasses):
    print(args)
    model = DenseNet_train(args, nclasses)
    model.load_state_dict(torch.load(load_path))
    model.load_state_dict(torch.load(load_path))
    model = model.cuda()
    model.eval()
    return model


@memory.cache
def get_model_predictions(args_dict, model_path, loader):

    args = Struct(**args_dict)

    model = load_model(args, model_path, loader.dataset.n_classes)
    outs = []
    # gather predictions for all images in the validation set
    for i, (inputs, labels) in enumerate(loader):
        inputs, _ = transform_data((inputs, labels), use_gpu=True)
        outputs = model(inputs)
        out = torch.sigmoid(outputs).data.cpu().numpy()
        outs.append(out)
    outs = np.concatenate(outs, axis=0)
    return outs


@memory.cache
def get_loader_on_split(args_dict, split):

    if "tag" not in args_dict:
        args_dict["tag"] = args_dict["size"]

    args = Struct(**args_dict)

    dataset = Dataset(args, split)

    loader = torch.utils.data.DataLoader(
                    dataset, batch_size=args.batch_size, shuffle=False,
                    num_workers=args.workers, pin_memory=False)
    return loader


def optimal_threshold_compute(labels, probs):
    thresholds = []
    for i in range(probs.shape[1]):
        p, r, t = metrics.precision_recall_curve(labels[:, i], probs[:, i])
        f1_scores = np.where((p + r) == 0, 0, 2 * p * r / (p + r)) #防止/0
        threshold = t[np.nanargmax(f1_scores)]
        thresholds.append(threshold)
    thresholds = np.array(thresholds)
    print("Optimal thresholds at ", thresholds)
    return thresholds

def predict_for_split(args_dicts, model_paths, split):
    loaders = [get_loader_on_split(args_dict, split) for args_dict in args_dicts]
    all_model_probs = [get_model_predictions(args_dict, model_path, loader) \
            for args_dict, model_path, loader in zip(args_dicts, model_paths, loaders)]
    probs = np.mean(all_model_probs, axis=0)
    # labels should be the same across all models
    labels = loaders[0].dataset.labels

    if 'valid' in split:
        thresholds = optimal_threshold_compute(labels, probs)
        #print(loaders[0].dataset.pathologies)
        auc = metrics.roc_auc_score(labels, probs)
        print("AUC", auc)
        name = str(auc) + '-' + split
    else:
        name = split
        thresholds = None

    return probs, thresholds, name


def predict(model_paths, split="valid_young", save=True):

    def get_model_params(model_path):
        #params = json.load(open(
        #    os.path.dirname(model_path) + '/params.txt', 'r'))
        params = json.load(open('/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/params.txt', 'r'))
        return params

    model_args_dicts = [get_model_params(model_path) for model_path in model_paths]

    folder_name = '/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/young/predictions' + str(int(round(time.time() * 1000)))

    probs, thresholds, name = predict_for_split(model_args_dicts, model_paths, split)

    if save:
        if not os.path.exists(folder_name):
            os.makedirs(folder_name)
        np.save(folder_name + '/' + name, probs)

        try:
            loaded_probs = np.load(folder_name + '/' + name + ".npy", allow_pickle=True)
            print("Loaded probs shape:", loaded_probs.shape)
        except Exception as e:
            print("Error loading .npy file:", e)

        print("Predictions saved to ", folder_name)

        params = {"model_paths": model_paths,
                  "num_models" : len(model_paths)}
        with open(folder_name + '/params.json', 'w') as outfile:
            json.dump(params, outfile)

        return folder_name + '/' + name + ".npy"

    else:

        return probs, thresholds


if __name__ == "__main__":
    """
    Usage
        python predict.py model1 model2 ... modelN
    """

    """
    parser = util.get_parser()
    parser.add_argument(
        'model_paths',
        nargs='+',
        help="path to models")
    args = parser.parse_args()
    """

    args = argparse.Namespace(
        model_paths=["/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.276692_train0.304059_epoch1","/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.262023_train0.267144_epoch2","/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.237520_train0.243476_epoch3","/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.228785_train0.211695_epoch4","/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.205620_train0.163654_epoch5","/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.215539_train0.109086_epoch6","/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.220947_train0.071413_epoch7","/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.187284_train0.035033_epoch8","/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.188101_train0.021869_epoch9","/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/run_dir/val0.193619_train0.015704_epoch10"])
    predict(args.model_paths, save=True)
# Out:
# <__main__.Struct object at 0x78d8c12092a0>
# <ipython-input-16-842b8b6deb3f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(load_path))
# <ipython-input-16-842b8b6deb3f>:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(load_path))
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# <__main__.Struct object at 0x78d8c13f6b60>
# <__main__.Struct object at 0x78d8c12141f0>
# <__main__.Struct object at 0x78d8c1295a80>
# <__main__.Struct object at 0x78d8c0b78f40>
# <__main__.Struct object at 0x78d99bd5afe0>
# <__main__.Struct object at 0x78d8d9b803a0>
# <__main__.Struct object at 0x78d8d9b803a0>
# <__main__.Struct object at 0x78d8d9b803a0>
# <__main__.Struct object at 0x78d8d9b803a0>
# Optimal thresholds at  [0.38284844 0.46058702 0.4600233  0.4011343 ]
# AUC 0.927858775074568
# Loaded probs shape: (4000, 4)
# Predictions saved to  /content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/young/predictions1732908849427

# %% [markdown]
# 預測驗證集中每個病例在各病徵的機率

# %%
import numpy as np

file_path = '/content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/middle/predictions/1732349921323/0.8196511379037413-valid_middle.npy'
try:
    data = np.load("/content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/middle/predictions/1732349921323/0.8196511379037413-valid_middle.npy")
    print(data)
except Exception as e:
    print("Error loading .npy file:", e)
# Out:
# [[0.0217714  0.05644109 0.01077197 0.01043232]
#  [0.00402132 0.18066278 0.00602409 0.04929465]
#  [0.01110394 0.06398945 0.01037403 0.01892748]
#  ...
#  [0.00888881 0.05041039 0.03848803 0.24960095]
#  [0.00678826 0.02450747 0.00566591 0.01319692]
#  [0.02958343 0.03869548 0.01167619 0.03409648]]

# %% [markdown]
# **Model_1-ROC**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

csv_path = '/content/drive/MyDrive/ML/data/valid_F.csv'
df = pd.read_csv(csv_path)

true_labels = df.iloc[:, 1:].values

probs = np.load('/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/female/predictions/1732374997769/0.8291619762265146-valid_F.npy', allow_pickle=True)

class_names = df.columns[1:]

def plot_multiclass_roc(true_labels, probs, class_names):
    plt.figure(figsize=(10, 8))

    for i in range(len(class_names)):
        fpr, tpr, _ = roc_curve(true_labels[:, i], probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f"{class_names[i]} (AUC = {roc_auc:.2f})")

    #plot total roc curve
    #start
    fpr, tpr, _ = roc_curve(true_labels.reshape(-1), probs.reshape(-1))
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f"Total (AUC = {roc_auc:.2f})")
    #end

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("ROC AUC Curves for Train_female Each Symptom in Model_CheXneXt")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

plot_multiclass_roc(true_labels, probs, class_names)

# %% [markdown]
# **Model_2-ROC**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

csv_path = '/content/drive/MyDrive/ML/data/valid_F.csv'
probs_csv_path = '/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_F_1120_0143/roc_F_pre.csv'

df = pd.read_csv(csv_path)
true_labels = df.iloc[:, 1:].values
class_names = df.columns[1:]

probs = pd.read_csv(probs_csv_path).values

def plot_multiclass_roc(true_labels, probs, class_names):
    plt.figure(figsize=(10, 8))

    for i in range(len(class_names)):
        fpr, tpr, _ = roc_curve(true_labels[:, i], probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f"{class_names[i]} (AUC = {roc_auc:.2f})")

    fpr, tpr, _ = roc_curve(true_labels.ravel(), probs.ravel())
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f"Total (AUC = {roc_auc:.2f})")

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("ROC AUC Curves for Train_female Each Symptom in Model_Xception")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

plot_multiclass_roc(true_labels, probs, class_names)

# %% [markdown]
# 10 條 ROC 曲線，分別對應 5 個客群的 Xception 模型 和 CheXneXt 模型

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# 路徑設定
data_paths = {
    "Female": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_F.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/female/predictions/1732374997769/0.8291619762265146-valid_F.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_F_1120_0143/roc_F_pre.csv"
    },
    "Male": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_M.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/male/predictions/1732380203052/0.8276335029453044-valid_M.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_M_1119_2327/roc_M_pre.csv"
    },
    "Young": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_young.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/young/predictions/1732372765129/0.927858775074568-valid_young.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_young__1122_1701/roc_young_pre.csv"
    },
    "Middle": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_middle.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/middle/predictions/1732349921323/0.8196511379037413-valid_middle.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_middle__1122_2205/roc_middle_pre.csv"
    },
    "Old": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_old.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_age/old/ep_10/predict/old/predictions/1732285693842/0.8736757582492061-valid_old.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_old__1123_0057/roc_old_pre.csv"
    }
}

# 繪製多模型 ROC 曲線
def plot_10_model_roc(data_paths):
    plt.figure(figsize=(12, 10))

    # 顏色設定
    colors = {
        "Female": "blue",
        "Male": "green",
        "Young": "orange",
        "Middle": "purple",
        "Old": "red"
    }

    for group, paths in data_paths.items():
        # 讀取真實標籤
        df = pd.read_csv(paths["true_csv"])
        true_labels = df.iloc[:, 1:].values

        # 讀取 CheXneXt 預測值
        chexnext_probs = np.load(paths["chexnext_probs"], allow_pickle=True)

        # 讀取 Xception 預測值
        xception_probs = pd.read_csv(paths["xception_probs"]).values

        # 繪製 CheXneXt 的總 ROC 曲線（實線）
        fpr, tpr, _ = roc_curve(true_labels.ravel(), chexnext_probs.ravel())
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, linestyle='-', color=colors[group], label=f"CheXneXt {group} (AUC = {roc_auc:.2f})")

        # 繪製 Xception 的總 ROC 曲線（虛線）
        fpr, tpr, _ = roc_curve(true_labels.ravel(), xception_probs.ravel())
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, linestyle='--', color=colors[group], label=f"Xception {group} (AUC = {roc_auc:.2f})")

    # 添加圖例與參考線
    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("TOTAL ROC AUC for CheXneXt and Xception Across Groups")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

# 繪製曲線
plot_10_model_roc(data_paths)

# %% [markdown]
# 10個model的全預測線(每張圖5條)_Model1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

groups = {
    "Female": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_F.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/female/predictions/1732379111661/0.7556504091210221-valid_F.npy",
    },
    "Male": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_M.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/male/predictions/1732380203052/0.8276335029453044-valid_M.npy",
    },
    "Middle": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_middle.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/middle/predictions/1732381048158/0.7938877349467963-valid_middle.npy",
    },
    "Old": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_old.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/old/predictions/1732382123865/0.7663979892214088-valid_old.npy",
    },
    "Young": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_young.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/young/predictions/1732382952584/0.805614894052909-valid_young.npy",
    },
}

def plot_total_roc(groups):
    plt.figure(figsize=(10, 8))

    for group_name, paths in groups.items():
        df = pd.read_csv(paths["csv_path"])
        true_labels = df.iloc[:, 1:].values
        probs = np.load(paths["npy_path"], allow_pickle=True)

        fpr, tpr, _ = roc_curve(true_labels.ravel(), probs.ravel())
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr, tpr, lw=2, label=f"{group_name} (AUC = {roc_auc:.2f})")

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("Total ROC AUC Curves for Train_male Groups")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

plot_total_roc(groups)

# %% [markdown]
# 10個model的全預測線(每張圖5條)_Model2

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

groups = {
    "Female": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_F.csv",
        "start_column": 6,
    },
    "Male": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_M.csv",
        "start_column": 1,
    },
    "Middle": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_middle.csv",
        "start_column": 16,
    },
    "Old": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_old.csv",
        "start_column": 21,
    },
    "Young": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_young.csv",
        "start_column": 11,
    },
}

prediction_csv_path = "/content/drive/MyDrive/Machine-learning-project/Xception/1122_result/F/F_prediction.csv"

def plot_total_roc(groups, prediction_csv_path):
    plt.figure(figsize=(10, 8))

    pred_data = pd.read_csv(prediction_csv_path, skiprows=1)

    for group_name, paths in groups.items():
        true_data = pd.read_csv(paths["true_csv_path"])
        true_labels = true_data.iloc[:, 1:].values

        start_col = paths["start_column"]
        pred_probs = pred_data.iloc[:, start_col : start_col + 4].values

        min_samples = min(true_labels.shape[0], pred_probs.shape[0])
        true_labels = true_labels[:min_samples, :]
        pred_probs = pred_probs[:min_samples, :]

        fpr, tpr, _ = roc_curve(true_labels.ravel(), pred_probs.ravel())
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr, tpr, lw=2, label=f"{group_name} (AUC = {roc_auc:.2f})")

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("Total ROC AUC Curves for Train_female Groups")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

plot_total_roc(groups, prediction_csv_path)

# %% [markdown]
# 10個model的全預測線(每張圖5條)_Model2_2

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

groups = {
    "Female": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_F.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_old__1123_0057/roc_F_pre.csv",
    },
    "Male": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_M.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_old__1123_0057/roc_M_pre.csv",
    },
    "Middle": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_middle.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_old__1123_0057/roc_middle_pre.csv",
    },
    "Old": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_old.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_old__1123_0057/roc_old_pre.csv",
    },
    "Young": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_young.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_old__1123_0057/roc_young_pre.csv",
    },
}

def plot_total_roc(groups):
    plt.figure(figsize=(10, 8))

    for group_name, paths in groups.items():
        true_data = pd.read_csv(paths["true_csv_path"])
        true_labels = true_data.iloc[:, 1:].values

        pred_data = pd.read_csv(paths["pred_csv_path"], skiprows=0)
        pred_probs = pred_data.values

        min_samples = min(true_labels.shape[0], pred_probs.shape[0])
        true_labels = true_labels[:min_samples, :]
        pred_probs = pred_probs[:min_samples, :]

        fpr, tpr, _ = roc_curve(true_labels.ravel(), pred_probs.ravel())
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr, tpr, lw=2, label=f"{group_name} (AUC = {roc_auc:.2f})")

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("Total ROC AUC Curves for Train_old Groups")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

plot_total_roc(groups)

# %% [markdown]
# 同客群不同model的比較(5張圖)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

csv_path = '/content/drive/MyDrive/ML/data/valid_F.csv'
chexnext_probs_path = '/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/female/predictions/1732374997769/0.8291619762265146-valid_F.npy'
xception_probs_path = '/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_F_1120_0143/roc_F_pre.csv'

df = pd.read_csv(csv_path)
true_labels = df.iloc[:, 1:].values
class_names = df.columns[1:]

chexnext_probs = np.load(chexnext_probs_path, allow_pickle=True)
xception_probs = pd.read_csv(xception_probs_path).values

def plot_multiclass_roc(true_labels, chexnext_probs, xception_probs, class_names):
    plt.figure(figsize=(12, 10))

    for i in range(len(class_names)):
        fpr, tpr, _ = roc_curve(true_labels[:, i], chexnext_probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, linestyle='--', label=f"CheXneXt {class_names[i]} (AUC = {roc_auc:.2f})")

    fpr, tpr, _ = roc_curve(true_labels.ravel(), chexnext_probs.ravel())
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=3, linestyle='-', label=f"CheXneXt Total (AUC = {roc_auc:.2f})")

    for i in range(len(class_names)):
        fpr, tpr, _ = roc_curve(true_labels[:, i], xception_probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, linestyle='--', label=f"Xception {class_names[i]} (AUC = {roc_auc:.2f})")

    fpr, tpr, _ = roc_curve(true_labels.ravel(), xception_probs.ravel())
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=3, linestyle='-', label=f"Xception Total (AUC = {roc_auc:.2f})")

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("ROC AUC Curves for CheXneXt and Xception in female_Group")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

plot_multiclass_roc(true_labels, chexnext_probs, xception_probs, class_names)

# %% [markdown]
# 同Model_1不同客群的比較

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

groups = {
    "Female": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_F.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/female/predictions/1732374997769/0.8291619762265146-valid_F.npy",
    },
    "Male": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_M.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/male/predictions/1732380203052/0.8276335029453044-valid_M.npy",
    },
    "Middle": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_middle.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/middle/predictions/1732349921323/0.8196511379037413-valid_middle.npy",
    },
    "Old": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_old.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_age/old/ep_10/predict/old/predictions/1732285693842/0.8736757582492061-valid_old.npy",
    },
    "Young": {
        "csv_path": "/content/drive/MyDrive/ML/data/valid_young.csv",
        "npy_path": "/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/young/predictions/1732372765129/0.927858775074568-valid_young.npy",
    },
}

def plot_total_roc(groups):
    plt.figure(figsize=(10, 8))

    for group_name, paths in groups.items():
        df = pd.read_csv(paths["csv_path"])
        true_labels = df.iloc[:, 1:].values
        probs = np.load(paths["npy_path"], allow_pickle=True)

        fpr, tpr, _ = roc_curve(true_labels.ravel(), probs.ravel())
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr, tpr, lw=2, label=f"{group_name} (AUC = {roc_auc:.2f})")

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("Total ROC AUC Curves for Xception each Groups")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

plot_total_roc(groups)

# %% [markdown]
# 同Model_2不同客群的比較

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

groups = {
    "Female": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_F.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_F_1120_0143/roc_F_pre.csv",
    },
    "Male": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_M.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_M_1119_2327/roc_M_pre.csv",
    },
    "Middle": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_middle.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_middle__1122_2205/roc_middle_pre.csv",
    },
    "Old": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_old.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_old__1123_0057/roc_old_pre.csv",
    },
    "Young": {
        "true_csv_path": "/content/drive/MyDrive/ML/data/valid_young.csv",
        "pred_csv_path": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_young__1122_1701/roc_young_pre.csv",
    },
}

def plot_total_roc(groups):
    plt.figure(figsize=(10, 8))

    for group_name, paths in groups.items():
        true_data = pd.read_csv(paths["true_csv_path"])
        true_labels = true_data.iloc[:, 1:].values

        pred_data = pd.read_csv(paths["pred_csv_path"], skiprows=0)
        pred_probs = pred_data.values

        min_samples = min(true_labels.shape[0], pred_probs.shape[0])
        true_labels = true_labels[:min_samples, :]
        pred_probs = pred_probs[:min_samples, :]

        fpr, tpr, _ = roc_curve(true_labels.ravel(), pred_probs.ravel())
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr, tpr, lw=2, label=f"{group_name} (AUC = {roc_auc:.2f})")

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("Total ROC AUC Curves for Xception each Groups")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

plot_total_roc(groups)

# %% [markdown]
# 對於不同種客群兩個model在四個病徵中的比較

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

data_paths = {
    "Female": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_F.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Female/ep_10/predict/female/predictions/1732374997769/0.8291619762265146-valid_F.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_F_1120_0143/roc_F_pre.csv"
    },
    "Male": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_M.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/predict/male/predictions/1732380203052/0.8276335029453044-valid_M.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_M_1119_2327/roc_M_pre.csv"
    },
    "Young": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_young.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_age/young/ep_10/predict/young/predictions/1732372765129/0.927858775074568-valid_young.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_young__1122_1701/roc_young_pre.csv"
    },
    "Middle": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_middle.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_age/middle/ep_10/predict/middle/predictions/1732349921323/0.8196511379037413-valid_middle.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_middle__1122_2205/roc_middle_pre.csv"
    },
    "Old": {
        "true_csv": "/content/drive/MyDrive/ML/data/valid_old.csv",
        "chexnext_probs": "/content/drive/MyDrive/ML/history_model/CheXneXt_age/old/ep_10/predict/old/predictions/1732285693842/0.8736757582492061-valid_old.npy",
        "xception_probs": "/content/drive/MyDrive/Machine-learning-project/Xception/result/10_Epochs_old__1123_0057/roc_old_pre.csv"
    }
}

def plot_nodule_roc(data_paths):
    plt.figure(figsize=(12, 10))

    colors = {
        "Female": "blue",
        "Male": "green",
        "Young": "orange",
        "Middle": "purple",
        "Old": "red"
    }

    for group, paths in data_paths.items():
        df = pd.read_csv(paths["true_csv"])
        true_labels = df.iloc[:, 1:].values

        chexnext_probs = np.load(paths["chexnext_probs"], allow_pickle=True)
        xception_probs = pd.read_csv(paths["xception_probs"]).values

        fpr, tpr, _ = roc_curve(true_labels[:, 3], chexnext_probs[:, 3])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, linestyle='-', color=colors[group], label=f"CheXneXt {group} (AUC = {roc_auc:.2f})")
        fpr, tpr, _ = roc_curve(true_labels[:, 3], xception_probs[:, 3])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, linestyle='--', color=colors[group], label=f"Xception {group} (AUC = {roc_auc:.2f})")

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random (AUC = 0.50)')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("Atelectasis ROC AUC for CheXneXt and Xception")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

plot_nodule_roc(data_paths)

# %% [markdown]
# **grad cam**

# %%
! pip install grad-cam
# Out:
# Collecting grad-cam
#   Downloading grad-cam-1.5.4.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 75.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from grad-cam) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from grad-cam) (11.0.0)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from grad-cam) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from grad-cam) (0.20.1+cu121)
# Collecting ttach (from grad-cam)
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from grad-cam) (4.66.6)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from grad-cam) (4.10.0.84)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from grad-cam) (3.8.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from grad-cam) (1.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.7.1->grad-cam) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam) (2.8.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.1->grad-cam) (3.0.2)
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.5.4-py3-none-any.whl size=39588 sha256=190debe10cc6c884ff8290a4fc504fe3f3c2fa82ba16ea9fbf57e80db04a8cad
#   Stored in directory: /root/.cache/pip/wheels/50/b0/82/1f97b5348c7fe9f0ce0ba18497202cafa5dec4562bd5292680
# Successfully built grad-cam
# Installing collected packages: ttach, grad-cam
# Successfully installed grad-cam-1.5.4 ttach-0.0.3

# %%
import os
import torch
import numpy as np
from torchvision.models import densenet121
from torchvision.transforms import transforms
from PIL import Image
import matplotlib.pyplot as plt

def preprocess_image(image_path, target_size=(224, 224)):
    preprocess = transforms.Compose([
        transforms.Resize(target_size),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    image = Image.open(image_path).convert("RGB")
    return preprocess(image).unsqueeze(0)

def generate_grad_cam_pytorch(model, image_tensor, target_layer):
    model.eval()
    activations = []
    gradients = []

    def forward_hook(module, input, output):
        activations.append(output)

    def backward_hook(module, grad_in, grad_out):
        gradients.append(grad_out[0])

    handle_forward = target_layer.register_forward_hook(forward_hook)
    handle_backward = target_layer.register_backward_hook(backward_hook)

    output = model(image_tensor)
    target_class = torch.argmax(output, dim=1)
    loss = output[:, target_class]

    model.zero_grad()
    loss.backward()

    gradient = gradients[0].cpu().data.numpy()
    activation = activations[0].cpu().data.numpy()

    weights = np.mean(gradient, axis=(2, 3))
    cam = np.zeros(activation.shape[2:], dtype=np.float32)

    for i, w in enumerate(weights[0]):
        cam += w * activation[0, i, :, :]

    cam = np.maximum(cam, 0)
    cam = cam / np.max(cam)
    cam = np.uint8(255 * cam)

    handle_forward.remove()
    handle_backward.remove()

    return cam

def overlay_grad_cam_high_res(image_path, heatmap, alpha=0.4):
    original_img = Image.open(image_path).convert("RGB")
    original_size = original_img.size

    heatmap_resized = Image.fromarray(heatmap).resize(original_size, Image.BILINEAR)
    heatmap_resized = np.array(heatmap_resized)

    heatmap_color = plt.cm.jet(heatmap_resized / 255.0)[:, :, :3]
    heatmap_color = (heatmap_color * 255).astype(np.uint8)

    overlay = np.array(original_img) / 255.0
    overlay = (1 - alpha) * overlay + alpha * (heatmap_color / 255.0)
    overlay = (overlay * 255).astype(np.uint8)

    return overlay

def process_and_save_grad_cam(model, image_path, target_layer, save_path):
    image_tensor = preprocess_image(image_path)
    heatmap = generate_grad_cam_pytorch(model, image_tensor, target_layer)
    overlay = overlay_grad_cam_high_res(image_path, heatmap)

    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    Image.fromarray(overlay).save(save_path)

    plt.figure(figsize=(10, 10))
    plt.imshow(overlay)
    plt.axis("off")
    plt.title("High-Resolution Grad-CAM Overlay")
    plt.show()

model_paths = [
    "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/run_dir/val0.315201_train0.347674_epoch1",
    "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/run_dir/val0.305339_train0.308090_epoch2",
    "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/run_dir/val0.306597_train0.281822_epoch3",
    "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/run_dir/val0.316875_train0.245489_epoch4",
    "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/run_dir/val0.300346_train0.157751_epoch5",
    "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/run_dir/val0.312949_train0.113909_epoch6",
    "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/run_dir/val0.329378_train0.086568_epoch7",
    "/content/drive/MyDrive/ML/history_model/CheXneXt_gender/Male/ep_10/run_dir/val0.329106_train0.066263_epoch8"
]

image_paths = {
    "Atelectasis": [
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00000072_000.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00000086_002.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00000119_001.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00000120_000.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00000248_008.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00000307_000.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00000324_015.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00000421_000.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00000963_011.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Atelectasis/00001088_008.png",
    ],
    "Effusion": [
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000041_006.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000071_007.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000116_008.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000116_011.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000127_004.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000250_008.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000506_012.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000572_001.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000591_014.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Effusion/00000848_000.png",
    ],
    "Healthy": [
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00000049_002.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00000547_007.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00000627_001.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00000646_007.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00000652_018.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00000756_005.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00000820_020.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00000857_001.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00000980_004.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Healthy/00001027_001.png",
    ],
    "Infiltration": [
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00000125_000.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00000181_009.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00000376_010.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00000506_003.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00000548_001.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00000652_012.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00000796_009.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00000873_000.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00001001_002.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Infiltration/00001075_005.png",
    ],
    "Nodule": [
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00000105_004.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00000157_000.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00000250_003.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00000336_000.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00000415_000.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00000459_017.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00000634_004.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00000640_001.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00000744_001.png",
        "/content/drive/MyDrive/Machine-learning-project/Xception/image/Nodule/00001012_000.png",
    ],
}

save_dirs = {
    "Atelectasis": "/content/drive/MyDrive/Machine-learning-project/Xception/image/grad_cam_output_model1/M/Atelectasis",
    "Effusion": "/content/drive/MyDrive/Machine-learning-project/Xception/image/grad_cam_output_model1/M/Effusion",
    "Healthy": "/content/drive/MyDrive/Machine-learning-project/Xception/image/grad_cam_output_model1/M/Healthy",
    "Infiltration": "/content/drive/MyDrive/Machine-learning-project/Xception/image/grad_cam_output_model1/M/Infiltration",
    "Nodule": "/content/drive/MyDrive/Machine-learning-project/Xception/image/grad_cam_output_model1/M/Nodule",
}

if __name__ == "__main__":
    model = densenet121(pretrained=True)
    target_layer = model.features.denseblock4.denselayer16.conv2

    for class_name, img_list in image_paths.items():
        save_dir = save_dirs[class_name]
        for img_path in img_list:
            output_save_path = os.path.join(save_dir, os.path.basename(img_path))
            process_and_save_grad_cam(model, img_path, target_layer, output_save_path)

# %% [markdown]
# Get best model

# %%
from __future__ import print_function
import glob
import os
import sys
import argparse
import json
import itertools

def print_helper(seq, verbose, n_print, reverse=False):
    for i, model_info in enumerate(sorted(seq, reverse=reverse)):
        if verbose:
            print(model_info)
        else:
            print(model_info[1], end=" ")
        if i == n_print:
            break


def get_best_predictions(path, n_print, verbose):
    predictions = []
    for timestamp in glob.glob(path + "/*"):
        for validation_file in glob.glob(timestamp + "/*-valid_1.npy"):
            basename = os.path.basename(validation_file)
            dirname = os.path.dirname(validation_file)
            with open(dirname + '/params.json') as json_data:
                params = json.load(json_data)
                num_models = params["num_models"]
            end_index = basename.find("-valid_1")
            AUC = float(basename[:end_index])
            predictions.append((AUC, dirname, num_models))
    print_helper(predictions, verbose, n_print, reverse=True)


def get_best_models(path, n, verbose, ungrouped):
    # from https://stackoverflow.com/questions/3368969/find-string-between-two-substrings
    def find_between(s, first, last):
        try:
            start = s.index(first ) + len( first )
            end = s.index( last, start )
            return s[start:end]
        except ValueError:
            return ""

    models = []
    for checkpoint_path in glob.glob(path + "/**/*epoch*"):
        val_loss = float(find_between(
            checkpoint_path, 'val', '_train'))
        models.append((val_loss, checkpoint_path))

    groups = itertools.groupby(models,
                lambda x: os.path.dirname(x[1]))

    models_group_best = []
    if ungrouped is True:
        models_group_best = models
    else:
        for _, model in groups:
            models_group_best.append(sorted(list(model))[0])

    return sorted(models_group_best)[:n]


if __name__ == '__main__':

    """
    parser = argparse.ArgumentParser()
    parser.add_argument(
        'selection_type',
        choices={'model', 'prediction'},
        help="Whether to get the best models or best predictions")
    parser.add_argument(
        'folder',
        help="path to get best from")
    parser.add_argument('-n', '--n', type=int, default=20)
    parser.add_argument('--verbose', action="store_true")
    parser.add_argument('--ungrouped', action="store_true")
    args = parser.parse_args()
    """
    args = argparse.Namespace(
        selection_type="model",
        #selection_type="prediction",
        folder="/content/drive/MyDrive/ML/history_model",
        n=5,
        verbose=False,
        ungrouped=False
    )

    if args.selection_type == 'model':
        models_group_best = get_best_models(args.folder, args.n, args.verbose, args.ungrouped)
        print_helper(models_group_best, args.verbose, args.n, reverse=False)
    elif args.selection_type == 'prediction':
        get_best_predictions(args.folder, args.n, args.verbose)
# Out:
# /content/drive/MyDrive/ML/history_model/run_dir/val0.296334_train0.239879_epoch4
